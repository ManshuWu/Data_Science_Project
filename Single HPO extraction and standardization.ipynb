# %%
import json
from pathlib import Path

INPUT_DIR = Path("/kaggle/input/fullfull/annotations")
OUTPUT_FILE = Path("merged_spans_with_entities.jsonl")

merged = []

for span_path in sorted(INPUT_DIR.glob("*_spans.jsonl")):
    filename = span_path.name
    with span_path.open("r", encoding="utf-8") as f:
        for lineno, line in enumerate(f, start=1):
            line = line.strip()
            if not line:
                print(f"Skipping empty line at {filename}:{lineno}")
                continue
            try:
                rec = json.loads(line)
            except json.JSONDecodeError as e:
                print(f"JSON decode error at {filename}:{lineno} — {e}")
                continue

            spans = rec.get("spans", [])
            if not spans:
                continue

            entry = {
                "text": rec.get("text", ""),
                "tokens": rec.get("tokens", []),
                "spans": spans,
            }
            merged.append(entry)

with OUTPUT_FILE.open("w", encoding="utf-8") as fw:
    for entry in merged:
        fw.write(json.dumps(entry, ensure_ascii=False) + "\n")

print(f"Merged and saved {len(merged)} entity-containing records to: {OUTPUT_FILE.resolve()}")
# Out:
# Skipping empty line at polg_16919951_spans.jsonl:1
# JSON decode error at polg_16919951_spans.jsonl:2 — Expecting value: line 1 column 1 (char 0)
# Skipping empty line at polg_16919951_spans.jsonl:3
# Merged and saved 675 entity-containing records to: /kaggle/working/merged_spans_with_entities.jsonl

# %%
# !pip install seqeval evaluate torchcrf
# Out:
# Collecting seqeval
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting evaluate
#   Downloading evaluate-0.4.5-py3-none-any.whl.metadata (9.5 kB)
# Collecting torchcrf
#   Downloading TorchCRF-1.1.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from seqeval) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.11/dist-packages (from seqeval) (1.2.2)
# Requirement already satisfied: datasets>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.6.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.32.4)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.16)
# Requirement already satisfied: fsspec>=2021.05.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (2025.5.1)
# Requirement already satisfied: huggingface-hub>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.33.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from evaluate) (25.0)
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from torchcrf) (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (19.0.1)
# Collecting fsspec>=2021.05.0 (from fsspec[http]>=2021.05.0->evaluate)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.0.0->evaluate) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.05.0->evaluate) (3.12.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.7.0->evaluate) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.14.0->seqeval) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->evaluate) (2025.6.15)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.15.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (1.5.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.21.3->seqeval) (3.6.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.0.0->torchcrf)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.0.0->torchcrf) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.0.0->torchcrf) (1.3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2021.05.0->evaluate) (1.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->evaluate) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.0.0->torchcrf) (3.0.2)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.0->seqeval) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.14.0->seqeval) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.14.0->seqeval) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.14.0->seqeval) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.14.0->seqeval) (2024.2.0)
# Downloading evaluate-0.4.5-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.4 MB/s eta 0:00:00
# Downloading TorchCRF-1.1.0-py3-none-any.whl (5.2 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 7.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 69.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 69.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 8.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.8 MB/s eta 0:00:00:00:0100:01
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=e257d036c1a614ca944edc79b449db36f7e3c7f18044930aaab9f9371537fa84
#   Stored in directory: /root/.cache/pip/wheels/bc/92/f0/243288f899c2eacdfa8c5f9aede4c71a9bad0ee26a01dc5ead
# Successfully built seqeval
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, fsspec, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torchcrf, seqeval, evaluate
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.5.1
#     Uninstalling fsspec-2025.5.1:
#       Successfully uninstalled fsspec-2025.5.1
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.8.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# bigframes 2.8.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.31.0, but you have google-cloud-bigquery 3.25.0 which is incompatible.
# bigframes 2.8.0 requires rich<14,>=12.4.4, but you have rich 14.0.0 which is incompatible.
# Successfully installed evaluate-0.4.5 fsspec-2025.3.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 seqeval-1.2.2 torchcrf-1.1.0

# %% [markdown]
# No silver data

# %%
import json
from pathlib import Path
from sklearn.model_selection import train_test_split

# Constants & Paths
FILE_MERGED = Path("/kaggle/working/merged_spans_with_entities.jsonl")
OUT_DIR     = Path("/kaggle/working/bio_outputs")
OUT_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_FILE = OUT_DIR / "train.jsonl"
DEV_FILE   = OUT_DIR / "dev.jsonl"
TEST_FILE  = OUT_DIR / "test.jsonl"

ENTITY_TYPES = {
    "AGE_ONSET", "AGE_FOLLOWUP", "AGE_DEATH",
    "PATIENT", "HPO_TERM", "GENE", "GENE_VARIANT"
}

# Utility Functions
def iter_jsonl(path: Path):
    with path.open("r", encoding="utf-8") as fh:
        for line in fh:
            line = line.strip()
            if not line:
                continue
            try:
                yield json.loads(line)
            except json.JSONDecodeError:
                continue

def filter_valid_entities(rec):
    spans = [s for s in rec.get("spans", []) if s.get("label") in ENTITY_TYPES]
    if spans:
        return {
            "text": rec["text"],
            "spans": spans
        }
    return None

def dump_jsonl(path: Path, data):
    with path.open("w", encoding="utf-8") as fh:
        for obj in data:
            fh.write(json.dumps(obj, ensure_ascii=False) + "\n")

# Load and filter gold data
print(">> Loading gold data …")
merged_filtered = []
for rec in iter_jsonl(FILE_MERGED):
    filtered = filter_valid_entities(rec)
    if filtered:
        merged_filtered.append(filtered)
print(f"Total valid records in gold: {len(merged_filtered)}")

# Split into train/dev/test (80/10/10)
train_dev, test_set = train_test_split(
    merged_filtered,
    test_size=0.20,
    random_state=42
)
train_set, dev_set = train_test_split(
    train_dev,
    test_size=0.25,
    random_state=42
)
print(f"Split sizes – TRAIN: {len(train_set)}, DEV: {len(dev_set)}, TEST: {len(test_set)}")


# Save to disk
dump_jsonl(TRAIN_FILE, train_set)
dump_jsonl(DEV_FILE, dev_set)
dump_jsonl(TEST_FILE, test_set)

print(f"\nSaved to:")
print(f"  ➜ {TRAIN_FILE}")
print(f"  ➜ {DEV_FILE}")
print(f"  ➜ {TEST_FILE}")
# Out:
# >> Loading gold data …
# Total valid records in gold: 675
# Split sizes – TRAIN: 405, DEV: 135, TEST: 135
#
# Saved to:
#   ➜ /kaggle/working/bio_outputs/train.jsonl
#   ➜ /kaggle/working/bio_outputs/dev.jsonl
#   ➜ /kaggle/working/bio_outputs/test.jsonl

# %%
import json
from pathlib import Path
from datasets import Dataset, DatasetDict
from transformers import (
    AutoTokenizer,
    AutoModelForTokenClassification,
    DataCollatorForTokenClassification,
    TrainingArguments,
    Trainer,
)
import evaluate

# === 1. Load pre-split data with silver already included ===
BIO_DIR = Path("/kaggle/working/bio_outputs")

def load_jsonl(path: Path):
    with path.open(encoding="utf-8") as f:
        return [json.loads(line) for line in f if line.strip()]

train_data = load_jsonl(BIO_DIR / "train.jsonl")
dev_data   = load_jsonl(BIO_DIR / "dev.jsonl")
test_data  = load_jsonl(BIO_DIR / "test.jsonl")

ds_raw = DatasetDict({
    "train": Dataset.from_list(train_data),
    "validation": Dataset.from_list(dev_data),
    "test": Dataset.from_list(test_data),
})
print("Loaded dataset sizes:", {k: len(v) for k, v in ds_raw.items()})

# === 2. Tokenizer and label mappings ===
tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract",
    use_fast=True
)

label_list = ["O", "B-HPO_TERM", "I-HPO_TERM"]
label2id = {label: idx for idx, label in enumerate(label_list)}
id2label = {idx: label for label, idx in label2id.items()}

# === 3. Span-to-token label encoder ===
def encode_and_align_labels(example):
    text = example["text"]
    spans = example["spans"]

    # 仅使用 HPO_TERM 的 span 构建标签
    hpo_spans = [(s["start"], s["end"]) for s in spans if s["label"] == "HPO_TERM"]

    # Tokenize 带 offset，用于将 span 映射到 token 层
    encoding = tokenizer(
        text,
        return_offsets_mapping=True,
        truncation=True,
        max_length=512,
    )

    labels = []
    for offset in encoding["offset_mapping"]:
        if offset == (0, 0):
            labels.append("O")
            continue

        tag = "O"
        for start, end in hpo_spans:
            if offset[0] >= start and offset[1] <= end:
                tag = "B-HPO_TERM" if offset[0] == start else "I-HPO_TERM"
                break

        labels.append(tag)

    encoding["labels"] = [label2id[tag] for tag in labels]
    return encoding

# === 4. Encode all splits ===
ds_encoded = ds_raw.map(
    encode_and_align_labels,
    batched=False,
    remove_columns=["text", "spans"]
)
print("Encoding complete.")

# === 5. Load model ===
model = AutoModelForTokenClassification.from_pretrained(
    "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract",
    num_labels=len(label_list),
    id2label=id2label,
    label2id=label2id,
)

# === 6. Evaluation metrics ===
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    preds = p.predictions.argmax(-1)
    labels = p.label_ids
    true_labels = [
        [id2label[lid] for lid in seq if lid != -100]
        for seq in labels
    ]
    pred_labels = [
        [id2label[pid] for pid, lid in zip(pred_seq, label_seq) if lid != -100]
        for pred_seq, label_seq in zip(preds, labels)
    ]
    result = seqeval.compute(predictions=pred_labels, references=true_labels)
    return {
        "overall_precision": result["overall_precision"],
        "overall_recall":    result["overall_recall"],
        "overall_f1":        result["overall_f1"],
        "overall_accuracy":  result["overall_accuracy"],
    }

# === 7. Training configuration ===
training_args = TrainingArguments(
    output_dir="ner_pubmedbert",
    eval_strategy="steps",
    eval_steps=50,
    save_steps=500,
    logging_strategy="steps",
    logging_steps=50,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    learning_rate=3e-5,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="overall_f1",
    greater_is_better=True,
    report_to=["none"],
    save_total_limit=1,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds_encoded["train"],
    eval_dataset=ds_encoded["validation"],
    tokenizer=tokenizer,
    data_collator=DataCollatorForTokenClassification(tokenizer),
    compute_metrics=compute_metrics,
)

# === 8. Train and evaluate ===
trainer.train()
trainer.evaluate()

# === 9. Predict on test set ===
print("\n--- Predicting on test set ---")
pred_output = trainer.predict(ds_encoded["test"])
preds = pred_output.predictions.argmax(-1)
labels = pred_output.label_ids

true_labels = [
    [id2label[lid] for lid in seq if lid != -100]
    for seq in labels
]
pred_labels = [
    [id2label[pid] for pid, lid in zip(pred_seq, label_seq) if lid != -100]
    for pred_seq, label_seq in zip(preds, labels)
]

detailed_result = seqeval.compute(predictions=pred_labels, references=true_labels)

print("\n HPO_TERM classification report:")
for label, metrics in detailed_result.items():
    if label == "HPO_TERM":
        print(f"{label:20} | Precision: {metrics['precision']:.3f} | Recall: {metrics['recall']:.3f} | F1: {metrics['f1']:.3f}")
# Out:
# 2025-09-05 04:54:47.595486: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1757048087.975777      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1757048088.087212      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ✅ Loaded dataset sizes: {'train': 405, 'validation': 135, 'test': 135}
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Map:   0%|          | 0/405 [00:00<?, ? examples/s]
# Map:   0%|          | 0/135 [00:00<?, ? examples/s]
# Map:   0%|          | 0/135 [00:00<?, ? examples/s]
# ✅ Encoding complete.
# pytorch_model.bin:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading builder script: 0.00B [00:00, ?B/s]
# /tmp/ipykernel_37/3048018043.py:132: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='255' max='255' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [255/255 01:25, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.297400</td>
#       <td>0.178670</td>
#       <td>0.368146</td>
#       <td>0.567404</td>
#       <td>0.446556</td>
#       <td>0.927922</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.140300</td>
#       <td>0.154322</td>
#       <td>0.449527</td>
#       <td>0.573441</td>
#       <td>0.503979</td>
#       <td>0.943191</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.092400</td>
#       <td>0.158061</td>
#       <td>0.489431</td>
#       <td>0.605634</td>
#       <td>0.541367</td>
#       <td>0.946278</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.063000</td>
#       <td>0.171512</td>
#       <td>0.495868</td>
#       <td>0.603622</td>
#       <td>0.544465</td>
#       <td>0.948467</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.045300</td>
#       <td>0.181366</td>
#       <td>0.484663</td>
#       <td>0.635815</td>
#       <td>0.550044</td>
#       <td>0.948917</td>
#     </tr>
#   </tbody>
# </table><p>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# --- Predicting on test set ---
#
#  HPO_TERM classification report:
# HPO_TERM             | Precision: 0.476 | Recall: 0.608 | F1: 0.534

# %% [markdown]
# Add silver data

# %%
import json
from pathlib import Path
from sklearn.model_selection import train_test_split

# Constants & Paths
FILE_MERGED = Path("/kaggle/working/merged_spans_with_entities.jsonl")
DIR_SILVER  = Path("/kaggle/input/hpo-only")
OUT_DIR     = Path("/kaggle/working/bio_outputs")
OUT_DIR.mkdir(parents=True, exist_ok=True)

TRAIN_FILE = OUT_DIR / "train.jsonl"
DEV_FILE   = OUT_DIR / "dev.jsonl"
TEST_FILE  = OUT_DIR / "test.jsonl"

ENTITY_TYPES = {
    "AGE_ONSET", "AGE_FOLLOWUP", "AGE_DEATH",
    "PATIENT", "HPO_TERM", "GENE", "GENE_VARIANT"
}

# Utility Functions
def iter_jsonl(path: Path):
    with path.open("r", encoding="utf-8") as fh:
        for line in fh:
            line = line.strip()
            if not line:
                continue
            try:
                yield json.loads(line)
            except json.JSONDecodeError:
                continue

def filter_valid_entities(rec):
    spans = [s for s in rec.get("spans", []) if s.get("label") in ENTITY_TYPES]
    if spans:
        return {
            "text": rec["text"],
            "spans": spans
        }
    return None

def dump_jsonl(path: Path, data):
    with path.open("w", encoding="utf-8") as fh:
        for obj in data:
            fh.write(json.dumps(obj, ensure_ascii=False) + "\n")

def load_filtered_silver(path: Path):
    extra = []
    for rec in iter_jsonl(path):
        rec = filter_valid_entities(rec)
        if rec:
            extra.append(rec)
    return extra

# Step 1: Load and convert gold data
print(">> Loading gold data …")
merged_filtered = []
for rec in iter_jsonl(FILE_MERGED):
    filtered = filter_valid_entities(rec)
    if filtered:
        merged_filtered.append(filtered)
print(f"Total valid records in gold: {len(merged_filtered)}")

# Step 2: Split gold into train/dev/test
train_dev, test_set = train_test_split(
    merged_filtered,
    test_size=0.20,
    random_state=42
)
train_set, dev_set = train_test_split(
    train_dev,
    test_size=0.25,
    random_state=42
)
print(f"Split sizes – TRAIN: {len(train_set)}, DEV: {len(dev_set)}, TEST: {len(test_set)}")

# Step 3: Add silver data to train set
extra_train = []
if DIR_SILVER.exists():
    print(">> Loading silver data from hpo-only/")
    for jf in sorted(DIR_SILVER.glob("*.jsonl")):
        print(f"  - {jf.name}")
        extra_train.extend(load_filtered_silver(jf))
else:
    print(">> Silver data directory not found.")

train_final = train_set + extra_train
print(f"Final train size: {len(train_final)} (including {len(extra_train)} silver records)")

# Step 4: Save to disk
dump_jsonl(TRAIN_FILE, train_final)
dump_jsonl(DEV_FILE, dev_set)
dump_jsonl(TEST_FILE, test_set)

print(f"\nSaved to:")
print(f"  ➜ {TRAIN_FILE}")
print(f"  ➜ {DEV_FILE}")
print(f"  ➜ {TEST_FILE}")
# Out:
# >> Loading gold data …
# Total valid records in gold: 675
# Split sizes – TRAIN: 405, DEV: 135, TEST: 135
# >> Loading silver data from hpo-only/
#   - HPO.jsonl
#   - HPO_only.jsonl
# Final train size: 9331 (including 8926 silver records)
#
# Saved to:
#   ➜ /kaggle/working/bio_outputs/train.jsonl
#   ➜ /kaggle/working/bio_outputs/dev.jsonl
#   ➜ /kaggle/working/bio_outputs/test.jsonl

# %%
import json
from pathlib import Path
from datasets import Dataset, DatasetDict
from transformers import (
    AutoTokenizer,
    AutoModelForTokenClassification,
    DataCollatorForTokenClassification,
    TrainingArguments,
    Trainer,
)
import evaluate

# === 1. Load pre-split data with silver already included ===
BIO_DIR = Path("/kaggle/working/bio_outputs")

def load_jsonl(path: Path):
    with path.open(encoding="utf-8") as f:
        return [json.loads(line) for line in f if line.strip()]

train_data = load_jsonl(BIO_DIR / "train.jsonl")
dev_data   = load_jsonl(BIO_DIR / "dev.jsonl")
test_data  = load_jsonl(BIO_DIR / "test.jsonl")

ds_raw = DatasetDict({
    "train": Dataset.from_list(train_data),
    "validation": Dataset.from_list(dev_data),
    "test": Dataset.from_list(test_data),
})
print(" Loaded dataset sizes:", {k: len(v) for k, v in ds_raw.items()})

# === 2. Tokenizer and label mappings ===
tokenizer = AutoTokenizer.from_pretrained(
    "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract",
    use_fast=True
)

label_list = ["O", "B-HPO_TERM", "I-HPO_TERM"]
label2id = {label: idx for idx, label in enumerate(label_list)}
id2label = {idx: label for label, idx in label2id.items()}

# === 3. Span-to-token label encoder ===
def encode_and_align_labels(example):
    text = example["text"]
    spans = example["spans"]

    hpo_spans = [(s["start"], s["end"]) for s in spans if s["label"] == "HPO_TERM"]

    # Tokenize 
    encoding = tokenizer(
        text,
        return_offsets_mapping=True,
        truncation=True,
        max_length=512,
    )

    labels = []
    for offset in encoding["offset_mapping"]:
        if offset == (0, 0):
            labels.append("O")
            continue

        tag = "O"
        for start, end in hpo_spans:
            if offset[0] >= start and offset[1] <= end:
                tag = "B-HPO_TERM" if offset[0] == start else "I-HPO_TERM"
                break

        labels.append(tag)

    encoding["labels"] = [label2id[tag] for tag in labels]
    return encoding

# === 4. Encode all splits ===
ds_encoded = ds_raw.map(
    encode_and_align_labels,
    batched=False,
    remove_columns=["text", "spans"]
)
print(" Encoding complete.")

# === 5. Load model ===
model = AutoModelForTokenClassification.from_pretrained(
    "microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract",
    num_labels=len(label_list),
    id2label=id2label,
    label2id=label2id,
)

# === 6. Evaluation metrics ===
seqeval = evaluate.load("seqeval")

def compute_metrics(p):
    preds = p.predictions.argmax(-1)
    labels = p.label_ids
    true_labels = [
        [id2label[lid] for lid in seq if lid != -100]
        for seq in labels
    ]
    pred_labels = [
        [id2label[pid] for pid, lid in zip(pred_seq, label_seq) if lid != -100]
        for pred_seq, label_seq in zip(preds, labels)
    ]
    result = seqeval.compute(predictions=pred_labels, references=true_labels)
    return {
        "overall_precision": result["overall_precision"],
        "overall_recall":    result["overall_recall"],
        "overall_f1":        result["overall_f1"],
        "overall_accuracy":  result["overall_accuracy"],
    }

# === 7. Training configuration ===
training_args = TrainingArguments(
    output_dir="ner_pubmedbert",
    eval_strategy="steps",
    eval_steps=50,
    save_steps=500,
    logging_strategy="steps",
    logging_steps=50,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=8,
    num_train_epochs=5,
    learning_rate=3e-5,
    weight_decay=0.01,
    load_best_model_at_end=True,
    metric_for_best_model="overall_f1",
    greater_is_better=True,
    report_to=["none"],
    save_total_limit=1,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=ds_encoded["train"],
    eval_dataset=ds_encoded["validation"],
    tokenizer=tokenizer,
    data_collator=DataCollatorForTokenClassification(tokenizer),
    compute_metrics=compute_metrics,
)

# === 8. Train and evaluate ===
trainer.train()
trainer.evaluate()

# === 9. Predict on test set ===
print("\n--- Predicting on test set ---")
pred_output = trainer.predict(ds_encoded["test"])
preds = pred_output.predictions.argmax(-1)
labels = pred_output.label_ids

true_labels = [
    [id2label[lid] for lid in seq if lid != -100]
    for seq in labels
]
pred_labels = [
    [id2label[pid] for pid, lid in zip(pred_seq, label_seq) if lid != -100]
    for pred_seq, label_seq in zip(preds, labels)
]

detailed_result = seqeval.compute(predictions=pred_labels, references=true_labels)

print("\n HPO_TERM classification report:")
for label, metrics in detailed_result.items():
    if label == "HPO_TERM":
        print(f"{label:20} | Precision: {metrics['precision']:.3f} | Recall: {metrics['recall']:.3f} | F1: {metrics['f1']:.3f}")
# Out:
#  Loaded dataset sizes: {'train': 9331, 'validation': 135, 'test': 135}
# Map:   0%|          | 0/9331 [00:00<?, ? examples/s]
# Map:   0%|          | 0/135 [00:00<?, ? examples/s]
# Map:   0%|          | 0/135 [00:00<?, ? examples/s]
#  Encoding complete.
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at microsoft/BiomedNLP-PubMedBERT-base-uncased-abstract and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /tmp/ipykernel_37/1455502626.py:132: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
#     <div>
#
#       <progress value='5835' max='5835' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5835/5835 24:48, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Overall Precision</th>
#       <th>Overall Recall</th>
#       <th>Overall F1</th>
#       <th>Overall Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.415400</td>
#       <td>0.259372</td>
#       <td>0.036866</td>
#       <td>0.016097</td>
#       <td>0.022409</td>
#       <td>0.900696</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.302300</td>
#       <td>0.220026</td>
#       <td>0.150000</td>
#       <td>0.078471</td>
#       <td>0.103038</td>
#       <td>0.911474</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.272200</td>
#       <td>0.201136</td>
#       <td>0.263158</td>
#       <td>0.281690</td>
#       <td>0.272109</td>
#       <td>0.918828</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.260800</td>
#       <td>0.188201</td>
#       <td>0.380531</td>
#       <td>0.432596</td>
#       <td>0.404896</td>
#       <td>0.930616</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.241400</td>
#       <td>0.191155</td>
#       <td>0.421384</td>
#       <td>0.404427</td>
#       <td>0.412731</td>
#       <td>0.932300</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.241700</td>
#       <td>0.186311</td>
#       <td>0.382766</td>
#       <td>0.384306</td>
#       <td>0.383534</td>
#       <td>0.933255</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.233300</td>
#       <td>0.182933</td>
#       <td>0.427105</td>
#       <td>0.418511</td>
#       <td>0.422764</td>
#       <td>0.937016</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.231100</td>
#       <td>0.167323</td>
#       <td>0.379245</td>
#       <td>0.404427</td>
#       <td>0.391431</td>
#       <td>0.938419</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.195500</td>
#       <td>0.153104</td>
#       <td>0.456113</td>
#       <td>0.585513</td>
#       <td>0.512775</td>
#       <td>0.944706</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.216800</td>
#       <td>0.143694</td>
#       <td>0.434716</td>
#       <td>0.569416</td>
#       <td>0.493031</td>
#       <td>0.948131</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.216800</td>
#       <td>0.138589</td>
#       <td>0.477346</td>
#       <td>0.593561</td>
#       <td>0.529148</td>
#       <td>0.949197</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.210900</td>
#       <td>0.140795</td>
#       <td>0.500000</td>
#       <td>0.619718</td>
#       <td>0.553459</td>
#       <td>0.950039</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.224200</td>
#       <td>0.141715</td>
#       <td>0.477172</td>
#       <td>0.651911</td>
#       <td>0.551020</td>
#       <td>0.947794</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.195700</td>
#       <td>0.141439</td>
#       <td>0.485099</td>
#       <td>0.589537</td>
#       <td>0.532243</td>
#       <td>0.948692</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.201200</td>
#       <td>0.132803</td>
#       <td>0.504732</td>
#       <td>0.643863</td>
#       <td>0.565871</td>
#       <td>0.950039</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.182000</td>
#       <td>0.131883</td>
#       <td>0.482192</td>
#       <td>0.708249</td>
#       <td>0.573757</td>
#       <td>0.949310</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.195100</td>
#       <td>0.112776</td>
#       <td>0.542345</td>
#       <td>0.670020</td>
#       <td>0.599460</td>
#       <td>0.959638</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.184500</td>
#       <td>0.115115</td>
#       <td>0.563140</td>
#       <td>0.663984</td>
#       <td>0.609418</td>
#       <td>0.961435</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.201400</td>
#       <td>0.105969</td>
#       <td>0.612844</td>
#       <td>0.672032</td>
#       <td>0.641075</td>
#       <td>0.963343</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.178700</td>
#       <td>0.106570</td>
#       <td>0.581315</td>
#       <td>0.676056</td>
#       <td>0.625116</td>
#       <td>0.963793</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.197600</td>
#       <td>0.105315</td>
#       <td>0.584288</td>
#       <td>0.718310</td>
#       <td>0.644404</td>
#       <td>0.963512</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.193100</td>
#       <td>0.103284</td>
#       <td>0.575658</td>
#       <td>0.704225</td>
#       <td>0.633484</td>
#       <td>0.963231</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.192800</td>
#       <td>0.102148</td>
#       <td>0.589844</td>
#       <td>0.607646</td>
#       <td>0.598612</td>
#       <td>0.962782</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.179100</td>
#       <td>0.106449</td>
#       <td>0.564489</td>
#       <td>0.678068</td>
#       <td>0.616088</td>
#       <td>0.961210</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.147600</td>
#       <td>0.101803</td>
#       <td>0.561350</td>
#       <td>0.736419</td>
#       <td>0.637076</td>
#       <td>0.960088</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.166900</td>
#       <td>0.101110</td>
#       <td>0.612521</td>
#       <td>0.728370</td>
#       <td>0.665441</td>
#       <td>0.964859</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.146400</td>
#       <td>0.101974</td>
#       <td>0.601318</td>
#       <td>0.734406</td>
#       <td>0.661232</td>
#       <td>0.965477</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.157900</td>
#       <td>0.098281</td>
#       <td>0.633205</td>
#       <td>0.659960</td>
#       <td>0.646305</td>
#       <td>0.966262</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.157900</td>
#       <td>0.095937</td>
#       <td>0.573620</td>
#       <td>0.752515</td>
#       <td>0.651001</td>
#       <td>0.965140</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.137500</td>
#       <td>0.088786</td>
#       <td>0.651327</td>
#       <td>0.740443</td>
#       <td>0.693032</td>
#       <td>0.970641</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.148200</td>
#       <td>0.095593</td>
#       <td>0.616279</td>
#       <td>0.746479</td>
#       <td>0.675159</td>
#       <td>0.966824</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.137700</td>
#       <td>0.084896</td>
#       <td>0.652406</td>
#       <td>0.736419</td>
#       <td>0.691871</td>
#       <td>0.972830</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.157200</td>
#       <td>0.082256</td>
#       <td>0.685499</td>
#       <td>0.732394</td>
#       <td>0.708171</td>
#       <td>0.974121</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.147800</td>
#       <td>0.089965</td>
#       <td>0.665461</td>
#       <td>0.740443</td>
#       <td>0.700952</td>
#       <td>0.972437</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.147500</td>
#       <td>0.081763</td>
#       <td>0.674912</td>
#       <td>0.768612</td>
#       <td>0.718721</td>
#       <td>0.973785</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.146900</td>
#       <td>0.080749</td>
#       <td>0.694444</td>
#       <td>0.754527</td>
#       <td>0.723240</td>
#       <td>0.974514</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.145700</td>
#       <td>0.083665</td>
#       <td>0.631579</td>
#       <td>0.772636</td>
#       <td>0.695023</td>
#       <td>0.972381</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.147400</td>
#       <td>0.074070</td>
#       <td>0.664418</td>
#       <td>0.792757</td>
#       <td>0.722936</td>
#       <td>0.976816</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.149200</td>
#       <td>0.085324</td>
#       <td>0.623256</td>
#       <td>0.808853</td>
#       <td>0.704028</td>
#       <td>0.971539</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.140700</td>
#       <td>0.071389</td>
#       <td>0.724951</td>
#       <td>0.742455</td>
#       <td>0.733598</td>
#       <td>0.978556</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.136900</td>
#       <td>0.066392</td>
#       <td>0.718284</td>
#       <td>0.774648</td>
#       <td>0.745402</td>
#       <td>0.979567</td>
#     </tr>
#     <tr>
#       <td>2100</td>
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torch/nn/parallel/_functions.py:70: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn(
# --- Predicting on test set ---
#
#  HPO_TERM classification report:
# HPO_TERM             | Precision: 0.793 | Recall: 0.823 | F1: 0.808

# %%
from collections import defaultdict

def extract_entities(labels):
    spans = []
    start = None
    current_label = None
    for i, lab_id in enumerate(labels):
        label = id2label.get(lab_id, "O")
        if label.startswith("B-HPO_TERM"):
            if current_label:
                spans.append((start, i - 1, current_label))
            start = i
            current_label = "HPO_TERM"
        elif label.startswith("I-HPO_TERM") and current_label:
            continue
        else:
            if current_label:
                spans.append((start, i - 1, current_label))
                current_label = None
                start = None
    if current_label:
        spans.append((start, len(labels) - 1, current_label))
    return spans

def iou(a, b):
    inter = max(0, min(a[1], b[1]) - max(a[0], b[0]) + 1)
    union = max(a[1], b[1]) - min(a[0], b[0]) + 1
    return inter / union

def relaxed_match(pred_span, true_span):
    ps, pe, plabel = pred_span
    ts, te, tlabel = true_span
    if plabel != tlabel:
        return False
    if abs(ps - ts) <= 1 and abs(pe - te) <= 1:
        return True
    if iou((ps, pe), (ts, te)) >= 0.5:
        return True
    return False

def relaxed_compute_metrics(preds, refs):
    tp, fp, fn = 0, 0, 0
    label_metrics = defaultdict(lambda: {"tp": 0, "fp": 0, "fn": 0})

    for pred_seq, ref_seq in zip(preds, refs):
        pred_ents = extract_entities(pred_seq)
        true_ents = extract_entities(ref_seq)
        matched = set()

        for pred_ent in pred_ents:
            match_found = False
            for i, true_ent in enumerate(true_ents):
                if i in matched:
                    continue
                if relaxed_match(pred_ent, true_ent):
                    tp += 1
                    label_metrics["HPO_TERM"]["tp"] += 1
                    matched.add(i)
                    match_found = True
                    break
            if not match_found:
                fp += 1
                label_metrics["HPO_TERM"]["fp"] += 1

        for i, true_ent in enumerate(true_ents):
            if i not in matched:
                fn += 1
                label_metrics["HPO_TERM"]["fn"] += 1

    precision = tp / (tp + fp + 1e-10)
    recall    = tp / (tp + fn + 1e-10)
    f1        = 2 * precision * recall / (precision + recall + 1e-10)

    print("\nRelaxed Per-label HPO_TERM classification report:")
    for label, m in label_metrics.items():
        lp = m["tp"] / (m["tp"] + m["fp"] + 1e-10)
        lr = m["tp"] / (m["tp"] + m["fn"] + 1e-10)
        lf1 = 2 * lp * lr / (lp + lr + 1e-10)
        print(f"{label:20} | Precision: {lp:.3f} | Recall: {lr:.3f} | F1: {lf1:.3f}")

    return {
        "precision": precision,
        "recall": recall,
        "f1": f1,
    }

filtered_preds = []
filtered_labels = []

for pred_seq, label_seq in zip(preds, labels):
    filtered_pred = [p for p, l in zip(pred_seq, label_seq) if l != -100]
    filtered_label = [l for l in label_seq if l != -100]
    filtered_preds.append(filtered_pred)
    filtered_labels.append(filtered_label)

print("\n Running relaxed evaluation on test set...")
relaxed_metrics = relaxed_compute_metrics(filtered_preds, filtered_labels)
print("\n Relaxed HPO_TERM test set metrics:", relaxed_metrics)
# Out:
#  Running relaxed evaluation on test set...
#
# Relaxed Per-label HPO_TERM classification report:
#
#  Relaxed HPO_TERM test set metrics: {'precision': 0.0, 'recall': 0.0, 'f1': 0.0}

# %%
trainer.save_model("ner_pubmedbert_saved_HPO")
tokenizer.save_pretrained("ner_pubmedbert_saved_HPO")
# Out:
# ('ner_pubmedbert_saved_HPO/tokenizer_config.json',
#  'ner_pubmedbert_saved_HPO/special_tokens_map.json',
#  'ner_pubmedbert_saved_HPO/vocab.txt',
#  'ner_pubmedbert_saved_HPO/added_tokens.json',
#  'ner_pubmedbert_saved_HPO/tokenizer.json')

# %%
pip install transformers obonet rapidfuzz
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.52.4)
# Collecting obonet
#   Downloading obonet-1.1.1-py3-none-any.whl.metadata (6.7 kB)
# Collecting rapidfuzz
#   Downloading rapidfuzz-3.14.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.33.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.11/dist-packages (from transformers) (4.67.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from obonet) (3.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.5)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.17->transformers) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->transformers) (2025.6.15)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.17->transformers) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.17->transformers) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.17->transformers) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.17->transformers) (2024.2.0)
# Downloading obonet-1.1.1-py3-none-any.whl (9.2 kB)
# Downloading rapidfuzz-3.14.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: rapidfuzz, obonet
# Successfully installed obonet-1.1.1 rapidfuzz-3.14.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# As long as two strings are 85% similar, they will be considered as an acceptable match.

# %%
import re
import json
from pathlib import Path
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process

# === Config ===
MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUT_FILE  = Path("/kaggle/working/bio_outputs/mapped_mentions.jsonl")
MAX_LENGTH = 512
DEVICE = 0  # use -1 for CPU

# === Step 1: Load test data ===
print(">> Loading test data")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]
orig_sentences = [ex["text"] for ex in test_data]

# === Step 2: Load model and tokenizer with pipeline ===
print(">> Loading model and tokenizer")
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=DEVICE
)

# === Step 3: Load HPO terms from hp.obo
print(">> Loading HPO terms from obo")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
graph = obonet.read_obo(obo_url)
hpo_map = {}
for node_id, data in graph.nodes(data=True):
    name = data.get("name")
    if name:
        hpo_map.setdefault(name.lower(), []).append(node_id)
    for syn in data.get("synonym", []):
        match = re.search(r'"(.+?)"', syn)
        if match:
            hpo_map.setdefault(match.group(1).lower(), []).append(node_id)

def normalize_mention(text: str):
    key = text.lower()
    if key in hpo_map:
        return hpo_map[key][0]
    match = process.extractOne(key, hpo_map.keys(), score_cutoff=85)
    if match:
        return hpo_map[match[0]][0]
    return None

# === Step 4: Run NER + Normalize (No Noise Filtering)
print(">> Running NER and normalization")
mapped_mentions = []
unmapped_mentions = []
normalized_mentions = []

for idx, sentence in enumerate(orig_sentences):
    results = ner_pipeline(sentence)
    for ent in results:
        if ent["entity_group"] != "HPO_TERM":
            continue
        mention = ent["word"].strip()
        hpo_id = normalize_mention(mention)
        (mapped_mentions if hpo_id else unmapped_mentions).append((mention, hpo_id))
        normalized_mentions.append({
            "sentence_id": idx,
            "mention": mention,
            "hpo_id": hpo_id
        })

total  = len(normalized_mentions)
mapped = sum(1 for r in normalized_mentions if r["hpo_id"] is not None)
print(f"\nTotal mentions:  {total}")
print(f"Mapped to HP ID: {mapped} ({mapped/total:.1%})")
print(f"Failed to map:   {total - mapped} ({(total - mapped)/total:.1%})")

with OUT_FILE.open("w", encoding="utf-8") as fout:
    for rec in normalized_mentions:
        fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"\n Mapped Mentions ({len(mapped_mentions)}):")
for mention, hpo_id in mapped_mentions:
    print(f"{mention} --> {hpo_id}")

print(f"\n Unmapped Mentions ({len(unmapped_mentions)}):")
for mention, _ in unmapped_mentions:
    print(mention)
# Out:
# >> Loading test data
# >> Loading model and tokenizer
# Device set to use cuda:0
# >> Loading HPO terms from obo
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Running NER and normalization
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# Total mentions:  644
# Mapped to HP ID: 630 (97.8%)
# Failed to map:   14 (2.2%)
#
#  Mapped Mentions (630):
# cytochrome c oxidase negative muscle fibers --> HP:0003688
# reduction of activities of complex i and iv --> HP:0000002
# lower extremities were diffusely thin --> HP:0020034
# power to be 0 / 5 at wrist ﬂexors and extensors --> HP:0000152
# 0 / 5 at biceps --> HP:0000062
# 5 / 5 at deltoid muscles --> HP:0000062
# / 5 at --> HP:0000062
# was 5 / 5 in --> HP:0000027
# / 5 at tibialis anterior --> HP:0000062
# absent reﬂexes in upper extremities --> HP:0000027
# polyneuropathy --> HP:0001271
# neuropathic pain --> HP:6000040
# ragged - red fibers --> HP:0003200
# dyskinesia --> HP:0100660
# severe stand - ing tremor --> HP:0001337
# dysphagia --> HP:0002015
# loss of weight --> HP:0001824
# malnutrition --> HP:0004395
# ventilatory failure --> HP:0000198
# mechanical ventilation --> HP:0004887
# serum ck level remains high --> HP:0000218
# high serum pyruvate and lactate levels --> HP:0000093
# low vitamin b12 and 25 - hydroxyvitamin d levels --> HP:0000093
# t2 hyperintensities in the --> HP:6000416
# cerebellar white matter --> HP:0000591
# atrophy of the left parieto - occipital lobe --> HP:0000002
# neurological deterioration --> HP:0002344
# tetraparesis --> HP:0002273
# hypotonia --> HP:0001252
# cognitive impairment --> HP:0100543
# multifocal myoclonus --> HP:0001336
# refractory partial seizures --> HP:0001250
# t2 / flair hyperintensities --> HP:0007183
# bilateral cerebellum --> HP:0012832
# frontal cortex --> HP:0006913
# bilateral parietal cortex --> HP:0012832
# hypersignals in thalami --> HP:0000121
# lactate doublet peak --> HP:0000349
# elevated lactate concentration --> HP:0410199
# partial status epilepticus --> HP:0002133
# progressive cognitive dysfunction --> HP:0003676
# psychotic features --> HP:0000280
# progressive external ophthalmoplegia --> HP:0000590
# resting tremor --> HP:0002322
# myoclonic jerks --> HP:0001336
# bilateral foot drop --> HP:0009027
# absence of sensory response in both arms and legs --> HP:0000002
# neurogenic motor units --> HP:0001270
# cerebellar and cerebral atrophy --> HP:0002059
# spongiform changes in the cerebrum --> HP:0000027
# white matter spongiosis of the cerebellum --> HP:6001166
# brainstem bleeding --> HP:0000132
# multiple lacunar ischaemic cortical infarcts --> HP:0000191
# mtdna depletion --> HP:0003387
# cox - negative areas --> HP:0001074
# dystonic ulnar deviation --> HP:0000497
# intermittent facial and jaw opening dystonia --> HP:0001332
# postural instability --> HP:0002172
# trunk ataxia --> HP:0002078
# severe dysarthria --> HP:0001260
# incomplete horizontal and vertical external ophthalmoplegia --> HP:0000544
# ataxia --> HP:0001251
# stand assisted --> HP:0004887
# sensory ataxic neuropathy --> HP:0003434
# cerebellar --> HP:0001251
# weakness --> HP:0025406
# visual disturbances --> HP:0001195
# diplopia --> HP:0000651
# dysarthria --> HP:0001260
# dysphasia --> HP:0032696
# multiple deletions of mitochondrial dna --> HP:0003689
# dorsal spinocerebellar tract degeneration --> HP:0002503
# degeneration of dorsal root ganglia --> HP:0000005
# nucleus --> HP:0002339
# sensory peripheral neuropathy --> HP:0000763
# neuronal loss --> HP:0002529
# gliosis in substantia nigra --> HP:0011960
# cox - negative ﬁbres --> HP:0003203
# ragged - red ” ﬁbres --> HP:0000179
# 3 - methylglutaconic acid --> HP:0003535
# cytochrome c oxidase ( cox ) - negative fibres --> HP:0002932
# myopathic --> HP:0002058
# muscles --> HP:0000211
# axonal neuropathy --> HP:0003477
# blood pyruvate was 172 μmol / litre --> HP:0000524
# cortical atrophy --> HP:0002120
# hypoketotic hypoglycaemia --> HP:0001985
# lethargy --> HP:0001254
# glycaemia --> HP:0000825
# mild ketonuria --> HP:0001658
# non - syndromic ovarian dysfunction --> HP:0000137
# elevation of cerebrospinal ﬂuid ( csf ) lactate --> HP:0000002
# content of mtdna was slightly reduced in muscle --> HP:0000002
# alpers syndrome --> HP:0031353
# epilepsia partialis continua --> HP:0012847
# right - sided focal motor seizures --> HP:0001250
# right - sided hemiparesis --> HP:0001269
# mental status deteriorated --> HP:0001249
# disoriented --> HP:0025237
# dysphasia --> HP:0032696
# acalculia --> HP:0002442
# cortical occipital lesions --> HP:0000803
# leftsided pulvinar thalamic abnormalities --> HP:0000078
# syndrome --> HP:0000012
# upper limb mixed rest and --> HP:0000097
# tremor --> HP:0001337
# hyperglycemia --> HP:0003074
# percutaneous gastrostomy tube --> HP:0012883
# progressively blurred vision --> HP:0000622
# diplopia --> HP:0000651
# bilateral ptosis --> HP:0001488
# choking episodes --> HP:0030842
# fatigue --> HP:0012378
# shortness of breath --> HP:0002094
# serum creatine kinase was mildly elevated --> HP:0003236
# baseline lactate was high --> HP:0000218
# axonal, and sensory polyneuropathy --> HP:0001271
# myopathic --> HP:0002058
# neuropathic --> HP:6000040
# subsarcolemmal accumulation of mitochondria --> HP:0001427
# cox - negative muscle fibers --> HP:0001252
# nuclear cl --> HP:0041043
# fiber type grouping --> HP:0033685
# lumbosacral radiculopathy --> HP:0025292
# progressive balance disturbance --> HP:0003676
# trouble walking heel - to - toe --> HP:0000011
# hopping --> HP:5200134
# reduced vibration sensation --> HP:0000217
# pinprick sensation ( reduced to the mid - calves --> HP:0000013
# supranuclear vertical gaze paresis --> HP:0000511
# right internuclear ophthalmoparesis --> HP:0000597
# reduced sensory amplitudes --> HP:0000654
# chronic denervation in distal muscles --> HP:0011010
# had worsened --> HP:0025286
# denervation --> HP:0003444
# hypotonia --> HP:0001252
# developmental delay --> HP:0001263
# hepatopathy --> HP:0001410
# elevated csf lactate --> HP:0000843
# seizures --> HP:0001250
# micronodular cirrhosis --> HP:0001413
# bile ductular proliferation --> HP:0001408
# nasogastric feeding --> HP:0040288
# refractory mixed type seizures --> HP:0001250
# psychomotor regression --> HP:0002376
# hepatopathy --> HP:0001410
# acute liver failure --> HP:0006554
# elevated csf protein --> HP:0002922
# abnormal eeg --> HP:0002353
# high amplitude slow wave activity --> HP:0000218
# polyspike discharges --> HP:0002392
# liver enzymatic respiratory chain defects --> HP:0000078
# complex iv showed a decreased activity --> HP:0000117
# bradykinesia --> HP:0002067
# cognitive impairment --> HP:0100543
# executive dysfunction --> HP:0100639
# language domain impairment --> HP:0002463
# mild apraxia --> HP:0001370
# moderate --> HP:0012826
# enlargement of the ventricles --> HP:0000005
# diffuse brain atrophy --> HP:0002283
# bilateral striatal dopamine deﬁciency --> HP:0012832
# ragged red ﬁbres --> HP:0001370
# multiple mtdna deletions --> HP:0003689
# fatigue --> HP:0012378
# bilateral eyelid drooping --> HP:0012832
# numbness in both feet --> HP:0033748
# left - sided ptosis --> HP:0000508
# complete ophthalmoplegia --> HP:0007824
# proximal muscle weakness --> HP:0003701
# parkinsonian --> HP:0001300
# rigidity --> HP:0002063
# tremor --> HP:0001337
# bradykinesia --> HP:0002067
# difficulty performing fine motor tasks --> HP:0000019
# cognitive impairment --> HP:0100543
# increasing dysphagia --> HP:0002015
# dysarthria --> HP:0001260
# dysphonia --> HP:0001618
# proximal myopathy --> HP:0003198
# sensorimotor neuropathy --> HP:0007141
# dysphagia --> HP:0002015
# peg tube --> HP:0000698
# recurrent aspiration --> HP:0002100
# pneumonia --> HP:0002090
# sensory – ataxic neuropathy --> HP:0003434
# ophthalmoplegia --> HP:0000602
# dysarthria --> HP:0001260
# gastroparesis --> HP:0002578
# epileptic event --> HP:0002123
# severe epilepsy --> HP:0001250
# infectious process --> HP:0000264
# igm antiborrellia titers were high --> HP:0000218
# insect bite --> HP:0020139
# secondarily generalized focal crisis --> HP:0012837
# hypertonia --> HP:0001276
# myoclonus --> HP:0001336
# secondarily generalized focal crisis --> HP:0012837
# motor deterioration --> HP:0002333
# high blood lactate value --> HP:0000218
# increase of the subarachnoid space --> HP:0000005
# atrophy of the left hemisphere --> HP:0012835
# pale eye fundus --> HP:0000286
# motor focal seizures --> HP:0007359
# upper extremity myoclonus --> HP:0001336
# encephalopathy --> HP:0001298
# motor disturbances --> HP:0000733
# inexpressive facies --> HP:0000274
# facial hypomimia --> HP:0000338
# axial hypotonia --> HP:0008936
# hypo / areflexia --> HP:0001284
# distal limb increased tone --> HP:0012839
# right tetraparesis --> HP:0002273
# lost deambulation --> HP:0000458
# difficulties in handling objects --> HP:0000027
# drooling --> HP:0002307
# electroencephalogram disclosed spontaneously slow and poorly organized trace --> HP:0000097
# frequent paroxysmal outbreaks of highvoltage delta waves --> HP:0040282
# right predominance activated during sleep --> HP:0001708
# deep cerebral folate deficiency 3 nmol / l ( --> HP:0012446
# myofibers were abnormally small --> HP:0000013
# subsarcolemmal collections of mitochondria --> HP:0001427
# cox - negative ﬁbres --> HP:0003203
# raggedred ﬁbres --> HP:0001370
# stage atrophy in gastrocnemius --> HP:0000029
# peo --> HP:0000544
# bilateral ptosis --> HP:0001488
# dysarthria --> HP:0001260
# ataxia --> HP:0001251
# neuropathy --> HP:0009830
# basal ganglia show hyperintense and swollen deep grey matter nuclei --> HP:0000097
# hyperintensity and swelling of the cortical grey and subcortical white matter --> HP:0000002
# fed through a --> HP:0000567
# g - tube --> HP:0004315
# dysphagia --> HP:0002015
# wheelchair bound --> HP:0500001
# aspiration pneumonia --> HP:0011951
# bilateral hand contractures --> HP:0012832
# failing to thrive --> HP:0000011
# depression --> HP:0000716
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# selective rod on - bipolar cell dysfunction --> HP:0000092
# external ophthalmoplegia --> HP:0000544
# saccadic pursuit --> HP:0001152
# writhing tongue movements --> HP:0000157
# dysarthria --> HP:0001260
# bilateral dysdiadochokinesis --> HP:0002075
# dysmetria --> HP:0001310
# poor --> HP:0000009
# heel - toe walking --> HP:0030051
# tremor --> HP:0001337
# myoclonic --> HP:0001327
# choreic --> HP:0002072
# dystonic posturing --> HP:0007166
# striatal toes --> HP:0001156
# peripheral neuropathy --> HP:0009830
# electronegative erg --> HP:0007984
# generalized rod on - bipolar dysfunction --> HP:0012837
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# generalized epilepsy --> HP:0001250
# long - standing learning difﬁculties --> HP:0000040
# acute liver failure --> HP:0006554
# migraines --> HP:0002076
# epilepsia partialis continua --> HP:0012847
# myoclonic arm jerks --> HP:0001336
# pancerebellar syndrome --> HP:0031353
# progressive cognitive impairment --> HP:0003676
# intractable epilepsy --> HP:0001250
# liver disease --> HP:0001392
# respiratory chain defect --> HP:0200125
# parkinsonism --> HP:0001300
# sando syndrome --> HP:0031353
# sensory ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoparesis --> HP:0000597
# t2 - hyperintense, oedemic lesions in the left thalamus --> HP:0000013
# parieto - occipital region --> HP:0000290
# headaches --> HP:0002315
# aphasia --> HP:0002381
# visual aura --> HP:0011165
# homonymous right - sided visual ﬁeld defect --> HP:0000114
# lesions in the right striatal area --> HP:0012834
# inferior colliculi --> HP:0000915
# leigh ’ s encephalopathy --> HP:0001298
# bilateral ptosis --> HP:0001488
# severe external ophthalmoplegia --> HP:0000544
# parkinsonism --> HP:0001300
# peo --> HP:0000544
# ptosis --> HP:0000508
# focal slowing --> HP:0030650
# epileptic spikes --> HP:0001351
# status epilepticus --> HP:0002133
# vision problems --> HP:0000529
# bilateral cataracts --> HP:0000518
# delayed ﬁne motor skills --> HP:0002194
# inability to use both of her hands --> HP:0000005
# atrophy of arm and hand muscles --> HP:0000005
# absent menarche --> HP:0000042
# ovarian dysgenesis --> HP:0000138
# seizure like episode --> HP:0001250
# cerebellar atrophy --> HP:0001272
# hyperintense lesions in left inferior olivary nucleus --> HP:0000027
# dystonic toe curling --> HP:0001765
# action tremor --> HP:0002345
# facial masking --> HP:0000276
# stiffness --> HP:0025262
# parkinsonism --> HP:0001300
# numbness in her feet --> HP:0033748
# parkinsonism --> HP:0001300
# bradykinesia --> HP:0002067
# stooped posture --> HP:0025403
# rigidity --> HP:0002063
# peripheral neuropathy --> HP:0009830
# sensorimotor, predominantly sensory --> HP:0000738
# generalized cerebral and cerebellar atrophy --> HP:0001272
# partial motor status epilepticus --> HP:0002133
# abnormal liver function tests --> HP:0002910
# focal area of restricted diffusion --> HP:0030650
# subtle gyral swelling --> HP:0001004
# continuous paroxysmal lateralizing epileptiform discharges --> HP:0000740
# encephalopathic --> HP:0001298
# focal status --> HP:0030650
# seizures --> HP:0001250
# enlarged mitochondria --> HP:0001427
# mitochondria with tubular cristae formations --> HP:0001427
# myopathy --> HP:0003198
# peo --> HP:0000544
# ptosis --> HP:0000508
# alpers syndrome --> HP:0031353
# gait instability --> HP:0002317
# near falls --> HP:0000001
# proximal arm weakness --> HP:0012840
# ﬁber size variability --> HP:0000350
# central nuclei --> HP:0003687
# ragged red --> HP:0001370
# ragged blue ( succinate dehydrogenase – positive ) ﬁbers --> HP:0000552
# cytochrome c oxidase ( cox ) - negative ﬁbers --> HP:0002932
# abnormally swollen mitochondria and paracrystalline inclusions --> HP:0000097
# increased --> HP:0001899
# cytochrome - c - oxidase ( cox - ) activity was deficient --> HP:0000135
# cognition was mildly affected --> HP:0012825
# anxiety and obsessive disorder --> HP:0000739
# creatine kinase levels were 217 u / l --> HP:0002720
# myoglobin was 360 u / l --> HP:0005484
# cortical atrophy --> HP:0002120
# bilateral peo --> HP:0012832
# ptosis --> HP:0000508
# myopathic --> HP:0002058
# mitochondrial myopathy --> HP:0003737
# proximal and distal weakness in lower limbs --> HP:0012839
# sensory ataxia --> HP:0010871
# demyelinating sensorymotor neuropathy --> HP:0011402
# anxiety - mood disorders --> HP:0000739
# ragged blue --> HP:0001370
# cortical and subcortical hyperintensities --> HP:0000152
# dystonia --> HP:0001332
# dystonic ulnar deviation --> HP:0000497
# jerky wrist and ﬁnger movements --> HP:0000230
# polymini - myoclonus --> HP:0031986
# cox - deficient fibers --> HP:0002486
# subsarcolemmal accumulation of abnormal mitochondria --> HP:0003548
# multiple mitochondrial dna ( mtdna ) deletions --> HP:0003689
# progressive sensory ataxic neuropathy --> HP:0003434
# ptosis --> HP:0000508
# dysarthria --> HP:0001260
# dysphagia --> HP:0002015
# external ophthalmoparesis --> HP:0000597
# ragged - red ” ﬁbres --> HP:0000179
# cytochrome oxidase - negative ﬁbres --> HP:0003688
# cytochrome c oxidase --> HP:0003688
# multiple mtdna deletions --> HP:0003689
# mtdna depletion --> HP:0003387
# palatal tremor --> HP:0010530
# inferior olivary nuclei --> HP:0000915
# reduced dopamine transporter levels in the putamen --> HP:0000013
# alpers syndrome --> HP:0031353
# early age of onset --> HP:0003674
# fatal --> HP:0006583
# intractable seizures --> HP:0001250
# hepatic failure --> HP:0001399
# global neurological deterioration --> HP:0001268
# high signal intensity within occipital and temporal lobes --> HP:0012824
# palatal tremor --> HP:0010530
# facial dyskinesia --> HP:0002310
# decreased complex iii activity --> HP:0002928
# multiple mtdna deletions --> HP:0003689
# dramatic weight loss --> HP:0001824
# gastroparesis --> HP:0002578
# ptosis --> HP:0000508
# ophthalmoplegia --> HP:0000602
# peripheral neuropathy --> HP:0009830
# sensory ataxia --> HP:0010871
# sensory – ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoplegia --> HP:0000602
# hypoxia --> HP:0012418
# ascites --> HP:0001541
# tachycardia --> HP:0001649
# intermittent fevers --> HP:0001954
# sepsis --> HP:0100806
# cirrhosis --> HP:0001394
# steatosis --> HP:0001397
# focal necrosis --> HP:0003338
# complex iii deﬁciency --> HP:0000694
# severely cytochrome oxidase - deﬁcient muscle --> HP:0012828
# deﬁciencies in all etc complexes --> HP:0000027
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# distance visual acuity was 0. 50 and 0. 40 logmar --> HP:0000152
# speech disorder --> HP:0006977
# left side weakness --> HP:0012835
# progressive bilateral ptosis --> HP:0000508
# hearing loss --> HP:0000365
# difficulties in swallowing --> HP:0002015
# bilateral ptosis --> HP:0001488
# bilateral hearing loss --> HP:0000365
# mild dysphagia --> HP:0001658
# myopathic pattern --> HP:0000650
# mild --> HP:0012825
# increase in cholesterol levels --> HP:0000093
# bilateral ptosis --> HP:0001488
# severe ophthalmoparesis --> HP:0000597
# hearing loss --> HP:0000365
# dysarthria --> HP:0001260
# left facial nerve palsy --> HP:0010628
# left side hemiparesis --> HP:0001269
# right pre - rolandic hyperintensity --> HP:0012824
# acute ischaemic lesion --> HP:0011009
# bilateral focal hyperintensities, --> HP:0012832
# lesions --> HP:0002833
# increased level of serum creatine kinase --> HP:0003236
# moderate --> HP:0012826
# sensorimotor bilateral hypoacusia --> HP:0012832
# myopathic --> HP:0002058
# bilateral ptosis --> HP:0001488
# lateral rectus palsies --> HP:0025275
# horizontal diplopia --> HP:0000651
# nasal, ﬂaccid dysarthria --> HP:0001260
# facial weakness --> HP:0030319
# tongue weakness --> HP:0000183
# power was reduced in both deltoid muscles --> HP:0000027
# loss of pigmented neurons in the substantia nigra --> HP:0000002
# gliosis --> HP:0002171
# gliosis --> HP:0002171
# ventrolateral posterior nuclei of the thalamus --> HP:0025275
# nucleus --> HP:0002339
# loss of the purkinje cells in the superior cerebellar vermis --> HP:0007001
# ptosis --> HP:0000508
# bilateral ptosis --> HP:0001488
# vertical and --> HP:0000097
# horizontal ophthalmoplegia --> HP:0000602
# bifacial weakness --> HP:0030319
# weakness in the proximal and distal upper --> HP:0012839
# lower --> HP:0000178
# left - sided intention tremor --> HP:0001337
# electromyography --> HP:0001370
# myopathy --> HP:0003198
# ##illation potentials --> HP:0002326
# moderate ﬁber size --> HP:0012826
# atrophic and hypertrophic ﬁbers --> HP:0000230
# increased internal nuclei --> HP:0008151
# fatty replacement of endomysial connective tissue --> HP:0000002
# ragged red ﬁbers --> HP:0001370
# dehydrogenase --> HP:0002928
# ragged blue --> HP:0001370
# reduced --> HP:0000217
# absent cytochrome c oxidase ( cox ) activity --> HP:0000027
# demyelination --> HP:0011096
# cataracts --> HP:0000518
# ovarian dysgenesis --> HP:0000138
# - onset --> HP:0003674
# distal muscle weakness --> HP:0002460
# microvesicular steatosis --> HP:0001414
# cerebral cortex showing activated astrocytes --> HP:0000935
# multiple mtdna deletions --> HP:0003689
# progressive cognitive deﬁcits --> HP:0003676
# cognitive deﬁcits --> HP:0100543
# epileptic seizures --> HP:0001250
# recurrent headaches --> HP:0002315
# mild --> HP:0012825
# personality changes --> HP:0000751
# movement disorder --> HP:0100022
# action - triggered myoclonus --> HP:0001336
# dystonic ulnar deviation --> HP:0000497
# progressive cerebellar ataxia --> HP:0002073
# wheel - chair bound --> HP:0011621
# incomplete --> HP:0000376
# chronic progressive external ophthalmoplegia --> HP:0000544
# peo --> HP:0000544
# severe axonal sensorimotor neuropathy --> HP:0007141
# cox - negative fibers --> HP:0002486
# ragged red fibers --> HP:0003200
# hepat --> HP:0001394
# lower limb --> HP:0001258
# dystonia --> HP:0001332
# peripheral neuropathy --> HP:0009830
# dystonia --> HP:0001332
# accumulation of lipids --> HP:0034787
# mitochondria were enlarged --> HP:0001427
# irregular cristae of a tubular --> HP:0000005
# complete horizontal gaze palsy --> HP:0000511
# severe ataxia --> HP:0001251
# reflexes were absent --> HP:0001284
# choreoathetotic --> HP:0001266
# complete absence of proprioceptive sensation --> HP:0000002
# somnolent --> HP:0005335
# loss of extraocular movement --> HP:0000597
# spasticity --> HP:0001257
# hyperreflexia --> HP:0001347
# t2 prolongation --> HP:0007183
# frontoparietal subcortical white matter --> HP:0000555
# genu of the corpus callosum --> HP:0001274
# genu of the right internal capsule --> HP:0012834
# anterior thalamus --> HP:0000236
# bilateral cerebellar hemispheres --> HP:0012832
# bilateral cerebellar peduncles --> HP:0012832
# subacute hemorrhage --> HP:0011009
# thalamus --> HP:0000864
# putamen --> HP:0031982
# showed an --> HP:0000802
# elevated lactate level --> HP:0011969
# depressed n - acetylaspartate level --> HP:0000272
# elevated choline level in --> HP:0012706
# basal ganglia --> HP:0006799
# gliotic white matter --> HP:0000591
# foamy histiocytes --> HP:0003651
# cells --> HP:0001404
# loss of myelin --> HP:0003380
# reactive astrocytes --> HP:0003203
# glial fibrillary acidic protein --> HP:0032650
# active demyelinating process --> HP:0000264
# adult - onset --> HP:0003581
# progressive external ophthalmoplegia --> HP:0000590
# peo --> HP:0000544
# progressive encephalopathy --> HP:0002448
# cox - deficient --> HP:0003213
# ragged - red fibres --> HP:0003200
# coagulopathy --> HP:0003256
# elevated liver enzymes --> HP:0002910
# seizures --> HP:0001250
# abnormalities in thalamus and basal ganglia --> HP:0000027
# alpers syndrome --> HP:0031353
# hepatic failure --> HP:0001399
# hand tremor --> HP:0002378
# hand tremor --> HP:0002378
# slurred speech --> HP:0001350
# increase in vanillate levels --> HP:0000093
# myelin basic protein level was higher than 1000 ng / ml --> HP:0000093
# oligoclonal bands were present --> HP:0003852
# serum lactate level was slightly high --> HP:0000218
# epilepsy --> HP:0001250
# eeg showed sharp and slow wave focus in the right posterior quadrant --> HP:0000009
# serum ck level was 1. 5 normal --> HP:0001975
# electromyography was myopathic --> HP:0002058
# myopathic --> HP:0002058
# cox - negative ragged red fibers --> HP:0000230
# lactate peak in cerebrospinal fluid detected on spectroscopy --> HP:0000027
# fat deposition was prominent in superficial muscles --> HP:0012830
# microvesicular --> HP:0001414
# cholestasis --> HP:0001396
# chronic myopathy --> HP:0003198
# severe sensory neuropathy --> HP:0000763
# dysm --> HP:0000641
# hypogonadism --> HP:0000135
# hypothyroidism --> HP:0000821
# osteopenia --> HP:0000938
# ragged - red fibers --> HP:0003200
# variation of fiber caliber --> HP:0000008
# nuclear centralization --> HP:0030645
# reduced --> HP:0000217
# absent reactivity to cytochrome c oxidase --> HP:0000027
# alpers syndrome --> HP:0031353
# mtdna depletion --> HP:0003387
# hypomimia --> HP:0000338
# bilateral bradykinesia --> HP:0002067
# right - sided resting tremor --> HP:0001337
# forced anteroflexion of --> HP:0000008
# reduced cox activity --> HP:0008321
# focal convulsions --> HP:0030650
# convulsions --> HP:0002069
# post - ) ictal paresis --> HP:0001604
# dysphasia --> HP:0032696
# focal occipital epileptic discharges --> HP:0030650
# irregular menstrual cycles --> HP:0000858
# portal tracts were enlarged --> HP:0000040
# proliferation of bile ductules --> HP:0000005
# bile plugs --> HP:0034294
# brainstem auditory evoked potential showed increased i – iii latency --> HP:0000016
# decreased sensory and motor nerve conduct velocity --> HP:0003448
# progressive proximal limb weakness --> HP:0003676
# continuous 2 hz polyspike - and - slow waves --> HP:0000152
# asymmetric ptosis --> HP:0000508
# muscle atrophy --> HP:0003202
# pectus excavatum ( --> HP:0000767
# funnel breast --> HP:0000769
# muscle atrophy --> HP:0003202
# ragged red fibers --> HP:0003200
# mitochondrial myopathy --> HP:0003737
# deficient in the mtdna - encoded cytochrome c oxidase ( cox --> HP:0000009
# multiple mtdna deletions --> HP:0003689
# extra - pyramidal rigidity --> HP:0002063
# cogwheel sign --> HP:0002403
# postural instability --> HP:0002172
# hypomimic face --> HP:0000338
# hypophonia --> HP:0001621
# bilateral ptosis --> HP:0001488
# ophthalmoplegia --> HP:0000602
# proximal muscle weak - ness --> HP:0003701
# oligomenorrhea --> HP:0000876
# subsarcolemmal accumulation of mitochondria --> HP:0001427
# mitochondria with abnormal concentric cristae --> HP:0001427
# depletion of mtdna --> HP:0000008
#
#  Unmapped Mentions (14):
# percutaneous endoscopic gastrostomy
# ##et alpers
# died
# ##v
# laterocollis
# sando
# sando
# syncopal episode
# rrf
# ﬁbers
# died
# sando
# ##ar
# bilirubinostasis

# %% [markdown]
# For the HPO _ TERM entity text identified by the model, firstly, the autocomplete interface of Monarch Initiative v3 API is called to find the most relevant HPO_TERM in the category of PhenotypicFeature and return their HP: ID; If Monarch doesn't have a matching result, call the ClinicalTables HPO API to search by keyword, and get the first ID that meets the HP: prefix; If the two steps don't hit, go back to the locally loaded hp.obo file, and do lowercase exact matching first. If it still doesn't hit, do fuzzy matching (similarity threshold is 85%) to find the closest term ID. Finally returns the first HP:ID found, otherwise returns None.

# %% [markdown]
# Without fine screening

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process

# === Config ===
MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUT_FILE  = Path("/kaggle/working/bio_outputs/mapped_mentions.jsonl")
MAX_LENGTH = 512  
DEVICE = 0  # use -1 for CPU

# Monarch v3 API & ClinicalTables
MONARCH_BASE = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"

FUZZY_CUTOFF = 85

# === HTTP session with retries ===
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# === Step 1: Load test data ===
print(">> Loading test data")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]
orig_sentences = [ex["text"] for ex in test_data]

# === Step 2: Load model and tokenizer with pipeline ===
print(">> Loading model and tokenizer")
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=DEVICE
)

# === Step 3: Load HPO terms from hp.obo
print(">> Loading HPO terms from obo")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (will still try online normalization): {e}")
    graph = None

hpo_map = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

# === Online normalizers (Monarch v3 -> ClinicalTables) ===
@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None
        for it in items:
            curie = it.get("id") or it.get("curie")
            cats  = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    return curie
    except Exception:
        return None
    return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        # 格式通常为 [ids[], names[], ...]
        if isinstance(data, list) and len(data) >= 2:
            ids = data[0]
            for hp_id in ids:
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    return hp_id
    except Exception:
        return None
    return None

# === Your original normalize_mention, upgraded with online -> local fallback ===
def normalize_mention(text: str):
    # 1) Monarch v3
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    # 2) ClinicalTables
    curie = normalize_via_ct(text)
    if curie:
        return curie
    # 3) Local exact + fuzzy
    key = text.lower()
    if key in hpo_map:
        return hpo_map[key][0]
    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        return hpo_map[match[0]][0]
    return None

# === Step 4: Run NER + Normalize (No Noise Filtering)
print(">> Running NER and normalization")
mapped_mentions = []
unmapped_mentions = []
normalized_mentions = []

for idx, sentence in enumerate(orig_sentences):
    #truncation/max_length
    results = ner_pipeline(sentence)
    for ent in results:
        if ent["entity_group"] != "HPO_TERM":
            continue
        mention = ent["word"].strip()
        hpo_id = normalize_mention(mention)
        (mapped_mentions if hpo_id else unmapped_mentions).append((mention, hpo_id))
        normalized_mentions.append({
            "sentence_id": idx,
            "mention": mention,
            "hpo_id": hpo_id
        })


total  = len(normalized_mentions)
mapped = sum(1 for r in normalized_mentions if r["hpo_id"] is not None)
print(f"\nTotal mentions:  {total}")
print(f"Mapped to HP ID: {mapped} ({mapped/total:.1%})" if total else "Mapped to HP ID: 0 (n/a)")
print(f"Failed to map:   {total - mapped} ({(total - mapped)/total:.1%})" if total else "Failed to map: 0 (n/a)")

OUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with OUT_FILE.open("w", encoding="utf-8") as fout:
    for rec in normalized_mentions:
        fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"\n Mapped Mentions ({len(mapped_mentions)}):")
for mention, hpo_id in mapped_mentions:
    print(f"{mention} --> {hpo_id}")

print(f"\n Unmapped Mentions ({len(unmapped_mentions)}):")
for mention, _ in unmapped_mentions:
    print(mention)
# Out:
# Device set to use cuda:0
# >> Loading test data
# >> Loading model and tokenizer
# >> Loading HPO terms from obo
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Running NER and normalization
#
# Total mentions:  644
# Mapped to HP ID: 632 (98.1%)
# Failed to map:   12 (1.9%)
#
#  Mapped Mentions (632):
# cytochrome c oxidase negative muscle fibers --> HP:0003688
# reduction of activities of complex i and iv --> HP:0000002
# lower extremities were diffusely thin --> HP:0020034
# power to be 0 / 5 at wrist ﬂexors and extensors --> HP:0000152
# 0 / 5 at biceps --> HP:0000062
# 5 / 5 at deltoid muscles --> HP:0000062
# / 5 at --> HP:0000062
# was 5 / 5 in --> HP:0000027
# / 5 at tibialis anterior --> HP:0000062
# absent reﬂexes in upper extremities --> HP:0000027
# polyneuropathy --> HP:0001271
# neuropathic pain --> HP:6000040
# ragged - red fibers --> HP:0003200
# dyskinesia --> HP:0100660
# severe stand - ing tremor --> HP:0001337
# dysphagia --> HP:0002015
# loss of weight --> HP:0001824
# malnutrition --> HP:0004395
# ventilatory failure --> HP:0000198
# mechanical ventilation --> HP:0004887
# serum ck level remains high --> HP:0000218
# high serum pyruvate and lactate levels --> HP:0002151
# low vitamin b12 and 25 - hydroxyvitamin d levels --> HP:0000093
# t2 hyperintensities in the --> HP:0033249
# cerebellar white matter --> HP:0007033
# atrophy of the left parieto - occipital lobe --> HP:0000002
# neurological deterioration --> HP:0002344
# tetraparesis --> HP:0002273
# hypotonia --> HP:0001252
# cognitive impairment --> HP:0100543
# multifocal myoclonus --> HP:0040148
# refractory partial seizures --> HP:0001250
# t2 / flair hyperintensities --> HP:0012128
# bilateral cerebellum --> HP:0012832
# frontal cortex --> HP:0031421
# bilateral parietal cortex --> HP:0032393
# hypersignals in thalami --> HP:0000121
# lactate doublet peak --> HP:0000349
# elevated lactate concentration --> HP:0002151
# partial status epilepticus --> HP:0032662
# progressive cognitive dysfunction --> HP:0003676
# psychotic features --> HP:0000725
# progressive external ophthalmoplegia --> HP:0000590
# resting tremor --> HP:0002322
# myoclonic jerks --> HP:0007000
# bilateral foot drop --> HP:0009027
# absence of sensory response in both arms and legs --> HP:0000002
# neurogenic motor units --> HP:0003445
# cerebellar and cerebral atrophy --> HP:0002059
# spongiform changes in the cerebrum --> HP:0000027
# white matter spongiosis of the cerebellum --> HP:6001166
# brainstem bleeding --> HP:6001255
# multiple lacunar ischaemic cortical infarcts --> HP:0000191
# mtdna depletion --> HP:0003387
# cox - negative areas --> HP:0001074
# dystonic ulnar deviation --> HP:0000497
# intermittent facial and jaw opening dystonia --> HP:0001332
# postural instability --> HP:0002172
# trunk ataxia --> HP:0002078
# severe dysarthria --> HP:0001260
# incomplete horizontal and vertical external ophthalmoplegia --> HP:0000544
# ataxia --> HP:0001251
# stand assisted --> HP:0004887
# sensory ataxic neuropathy --> HP:0003434
# cerebellar --> HP:0001251
# weakness --> HP:0031108
# visual disturbances --> HP:0034773
# diplopia --> HP:0000651
# dysarthria --> HP:0001260
# dysphasia --> HP:0032696
# multiple deletions of mitochondrial dna --> HP:0003689
# dorsal spinocerebellar tract degeneration --> HP:0002503
# degeneration of dorsal root ganglia --> HP:0000005
# nucleus --> HP:0002339
# sensory peripheral neuropathy --> HP:0007067
# neuronal loss --> HP:0200147
# gliosis in substantia nigra --> HP:0011960
# cox - negative ﬁbres --> HP:0003203
# ragged - red ” ﬁbres --> HP:0000179
# 3 - methylglutaconic acid --> HP:0003535
# cytochrome c oxidase ( cox ) - negative fibres --> HP:0002932
# myopathic --> HP:0002058
# muscles --> HP:0000211
# axonal neuropathy --> HP:0007002
# blood pyruvate was 172 μmol / litre --> HP:0000524
# cortical atrophy --> HP:0007112
# hypoketotic hypoglycaemia --> HP:0001985
# lethargy --> HP:0001254
# glycaemia --> HP:0000825
# mild ketonuria --> HP:0001658
# non - syndromic ovarian dysfunction --> HP:0000137
# elevation of cerebrospinal ﬂuid ( csf ) lactate --> HP:0000002
# content of mtdna was slightly reduced in muscle --> HP:0000002
# alpers syndrome --> HP:0031353
# epilepsia partialis continua --> HP:0012847
# right - sided focal motor seizures --> HP:0001250
# right - sided hemiparesis --> HP:0001269
# mental status deteriorated --> HP:0001249
# disoriented --> HP:0025237
# dysphasia --> HP:0032696
# acalculia --> HP:0032691
# cortical occipital lesions --> HP:0000803
# leftsided pulvinar thalamic abnormalities --> HP:0000078
# syndrome --> HP:0000012
# upper limb mixed rest and --> HP:0000097
# tremor --> HP:0001337
# hyperglycemia --> HP:0003074
# percutaneous gastrostomy tube --> HP:0012883
# progressively blurred vision --> HP:0000622
# diplopia --> HP:0000651
# bilateral ptosis --> HP:0001488
# choking episodes --> HP:0030842
# fatigue --> HP:0012378
# shortness of breath --> HP:0002094
# serum creatine kinase was mildly elevated --> HP:0003236
# baseline lactate was high --> HP:0000218
# axonal, and sensory polyneuropathy --> HP:0007131
# myopathic --> HP:0002058
# neuropathic --> HP:0002821
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# cox - negative muscle fibers --> HP:0001252
# nuclear cl --> HP:0100018
# fiber type grouping --> HP:0033685
# lumbosacral radiculopathy --> HP:0025292
# progressive balance disturbance --> HP:0003676
# trouble walking heel - to - toe --> HP:0000011
# hopping --> HP:5200134
# reduced vibration sensation --> HP:0000217
# pinprick sensation ( reduced to the mid - calves --> HP:0000013
# supranuclear vertical gaze paresis --> HP:0000511
# right internuclear ophthalmoparesis --> HP:0000597
# reduced sensory amplitudes --> HP:0007108
# chronic denervation in distal muscles --> HP:0011010
# had worsened --> HP:0025286
# denervation --> HP:0009109
# hypotonia --> HP:0001252
# developmental delay --> HP:0001263
# hepatopathy --> HP:0001410
# elevated csf lactate --> HP:0000843
# seizures --> HP:0001250
# ##v --> HP:0025536
# micronodular cirrhosis --> HP:0001413
# bile ductular proliferation --> HP:0001408
# nasogastric feeding --> HP:0040288
# refractory mixed type seizures --> HP:0001250
# psychomotor regression --> HP:0002376
# hepatopathy --> HP:0001410
# acute liver failure --> HP:0006554
# elevated csf protein --> HP:6000205
# abnormal eeg --> HP:0002353
# high amplitude slow wave activity --> HP:0000218
# polyspike discharges --> HP:0025644
# liver enzymatic respiratory chain defects --> HP:0000078
# complex iv showed a decreased activity --> HP:0000117
# bradykinesia --> HP:0002067
# cognitive impairment --> HP:0100543
# executive dysfunction --> HP:0100639
# language domain impairment --> HP:0002463
# mild apraxia --> HP:0001370
# moderate --> HP:0012826
# enlargement of the ventricles --> HP:4000141
# diffuse brain atrophy --> HP:0002283
# bilateral striatal dopamine deﬁciency --> HP:0012832
# ragged red ﬁbres --> HP:0003200
# multiple mtdna deletions --> HP:0003689
# fatigue --> HP:0012378
# bilateral eyelid drooping --> HP:0001488
# numbness in both feet --> HP:0033748
# left - sided ptosis --> HP:0000508
# complete ophthalmoplegia --> HP:0007824
# proximal muscle weakness --> HP:0003701
# parkinsonian --> HP:0001300
# rigidity --> HP:0002063
# tremor --> HP:0001337
# bradykinesia --> HP:0002067
# difficulty performing fine motor tasks --> HP:0000019
# cognitive impairment --> HP:0100543
# increasing dysphagia --> HP:0002015
# dysarthria --> HP:0001260
# dysphonia --> HP:0001618
# proximal myopathy --> HP:0003198
# sensorimotor neuropathy --> HP:0007141
# dysphagia --> HP:0002015
# peg tube --> HP:0011471
# recurrent aspiration --> HP:0002100
# pneumonia --> HP:0002090
# sensory – ataxic neuropathy --> HP:0003434
# ophthalmoplegia --> HP:0000602
# dysarthria --> HP:0001260
# gastroparesis --> HP:0002578
# epileptic event --> HP:0033346
# severe epilepsy --> HP:0001250
# infectious process --> HP:0000264
# igm antiborrellia titers were high --> HP:0000218
# insect bite --> HP:0410339
# secondarily generalized focal crisis --> HP:0012837
# hypertonia --> HP:0001276
# myoclonus --> HP:0001336
# secondarily generalized focal crisis --> HP:0012837
# motor deterioration --> HP:0002333
# high blood lactate value --> HP:0000218
# increase of the subarachnoid space --> HP:0012704
# atrophy of the left hemisphere --> HP:0012835
# pale eye fundus --> HP:0000286
# motor focal seizures --> HP:0011153
# upper extremity myoclonus --> HP:0001336
# encephalopathy --> HP:0001298
# motor disturbances --> HP:0100021
# inexpressive facies --> HP:0000274
# facial hypomimia --> HP:0000338
# axial hypotonia --> HP:0008936
# hypo / areflexia --> HP:0002600
# distal limb increased tone --> HP:0012839
# right tetraparesis --> HP:0002273
# lost deambulation --> HP:0000458
# difficulties in handling objects --> HP:0000027
# drooling --> HP:0002307
# electroencephalogram disclosed spontaneously slow and poorly organized trace --> HP:0000097
# frequent paroxysmal outbreaks of highvoltage delta waves --> HP:0040282
# right predominance activated during sleep --> HP:0001708
# deep cerebral folate deficiency 3 nmol / l ( --> HP:0012446
# myofibers were abnormally small --> HP:0000013
# subsarcolemmal collections of mitochondria --> HP:0001427
# cox - negative ﬁbres --> HP:0003203
# raggedred ﬁbres --> HP:0001370
# stage atrophy in gastrocnemius --> HP:0000029
# peo --> HP:6001120
# bilateral ptosis --> HP:0001488
# dysarthria --> HP:0001260
# ataxia --> HP:0001251
# neuropathy --> HP:0009830
# basal ganglia show hyperintense and swollen deep grey matter nuclei --> HP:0000097
# hyperintensity and swelling of the cortical grey and subcortical white matter --> HP:0000002
# fed through a --> HP:0000567
# g - tube --> HP:0004315
# dysphagia --> HP:0002015
# wheelchair bound --> HP:0500001
# aspiration pneumonia --> HP:0011951
# bilateral hand contractures --> HP:0012832
# failing to thrive --> HP:0000011
# depression --> HP:0000716
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# selective rod on - bipolar cell dysfunction --> HP:0000092
# external ophthalmoplegia --> HP:0000544
# saccadic pursuit --> HP:0001152
# writhing tongue movements --> HP:0000157
# dysarthria --> HP:0001260
# bilateral dysdiadochokinesis --> HP:0002075
# dysmetria --> HP:0001310
# poor --> HP:0004396
# heel - toe walking --> HP:0030051
# tremor --> HP:0001337
# myoclonic --> HP:0033054
# choreic --> HP:0002072
# dystonic posturing --> HP:0007166
# striatal toes --> HP:0001156
# peripheral neuropathy --> HP:0009830
# electronegative erg --> HP:0007984
# generalized rod on - bipolar dysfunction --> HP:0012837
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# generalized epilepsy --> HP:0001250
# long - standing learning difﬁculties --> HP:0000040
# acute liver failure --> HP:0006554
# migraines --> HP:0002076
# epilepsia partialis continua --> HP:0012847
# myoclonic arm jerks --> HP:0001336
# pancerebellar syndrome --> HP:0031353
# progressive cognitive impairment --> HP:0003676
# intractable epilepsy --> HP:0001250
# liver disease --> HP:0006557
# respiratory chain defect --> HP:0200125
# parkinsonism --> HP:0001300
# sando syndrome --> HP:0031353
# sensory ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoparesis --> HP:0000597
# t2 - hyperintense, oedemic lesions in the left thalamus --> HP:0000013
# parieto - occipital region --> HP:0000290
# headaches --> HP:0002315
# aphasia --> HP:0002381
# visual aura --> HP:0002077
# homonymous right - sided visual ﬁeld defect --> HP:0000114
# lesions in the right striatal area --> HP:0012834
# inferior colliculi --> HP:0000915
# leigh ’ s encephalopathy --> HP:0001298
# bilateral ptosis --> HP:0001488
# severe external ophthalmoplegia --> HP:0000544
# parkinsonism --> HP:0001300
# peo --> HP:6001120
# ptosis --> HP:0000508
# focal slowing --> HP:0030650
# epileptic spikes --> HP:0031491
# status epilepticus --> HP:0002133
# vision problems --> HP:0000529
# bilateral cataracts --> HP:0000519
# delayed ﬁne motor skills --> HP:0002194
# inability to use both of her hands --> HP:0000005
# atrophy of arm and hand muscles --> HP:0000005
# absent menarche --> HP:0000042
# ovarian dysgenesis --> HP:0000138
# seizure like episode --> HP:0002401
# cerebellar atrophy --> HP:0001272
# hyperintense lesions in left inferior olivary nucleus --> HP:0000027
# dystonic toe curling --> HP:0001765
# action tremor --> HP:0002345
# facial masking --> HP:0000276
# stiffness --> HP:0030965
# parkinsonism --> HP:0001300
# numbness in her feet --> HP:0033748
# parkinsonism --> HP:0001300
# bradykinesia --> HP:0002067
# stooped posture --> HP:0025403
# rigidity --> HP:0002063
# peripheral neuropathy --> HP:0009830
# sensorimotor, predominantly sensory --> HP:0000738
# generalized cerebral and cerebellar atrophy --> HP:0001272
# partial motor status epilepticus --> HP:0032662
# abnormal liver function tests --> HP:0200148
# focal area of restricted diffusion --> HP:0030650
# subtle gyral swelling --> HP:0001004
# continuous paroxysmal lateralizing epileptiform discharges --> HP:0000740
# encephalopathic --> HP:0001298
# focal status --> HP:0032663
# seizures --> HP:0001250
# enlarged mitochondria --> HP:0001427
# mitochondria with tubular cristae formations --> HP:0001427
# myopathy --> HP:0003198
# peo --> HP:6001120
# ptosis --> HP:0000508
# alpers syndrome --> HP:0031353
# gait instability --> HP:0006962
# near falls --> HP:0000001
# proximal arm weakness --> HP:0003701
# ﬁber size variability --> HP:0003557
# central nuclei --> HP:0003687
# ragged red --> HP:0003200
# ragged blue ( succinate dehydrogenase – positive ) ﬁbers --> HP:0000552
# cytochrome c oxidase ( cox ) - negative ﬁbers --> HP:0002932
# abnormally swollen mitochondria and paracrystalline inclusions --> HP:0000097
# increased --> HP:0033373
# cytochrome - c - oxidase ( cox - ) activity was deficient --> HP:0000135
# cognition was mildly affected --> HP:0012825
# anxiety and obsessive disorder --> HP:0000739
# creatine kinase levels were 217 u / l --> HP:0002720
# myoglobin was 360 u / l --> HP:0005484
# cortical atrophy --> HP:0007112
# bilateral peo --> HP:0012832
# ptosis --> HP:0000508
# myopathic --> HP:0002058
# mitochondrial myopathy --> HP:0003737
# proximal and distal weakness in lower limbs --> HP:0012839
# sensory ataxia --> HP:0010871
# demyelinating sensorymotor neuropathy --> HP:0011402
# anxiety - mood disorders --> HP:0000739
# ragged blue --> HP:0001370
# cortical and subcortical hyperintensities --> HP:0000152
# dystonia --> HP:0001332
# dystonic ulnar deviation --> HP:0000497
# jerky wrist and ﬁnger movements --> HP:0000230
# polymini - myoclonus --> HP:0031986
# cox - deficient fibers --> HP:0002486
# subsarcolemmal accumulation of abnormal mitochondria --> HP:0003548
# multiple mitochondrial dna ( mtdna ) deletions --> HP:0003689
# progressive sensory ataxic neuropathy --> HP:0003434
# ptosis --> HP:0000508
# dysarthria --> HP:0001260
# dysphagia --> HP:0002015
# external ophthalmoparesis --> HP:0000597
# ragged - red ” ﬁbres --> HP:0000179
# cytochrome oxidase - negative ﬁbres --> HP:0003688
# cytochrome c oxidase --> HP:0003688
# multiple mtdna deletions --> HP:0003689
# mtdna depletion --> HP:0003387
# palatal tremor --> HP:0010530
# inferior olivary nuclei --> HP:0006955
# reduced dopamine transporter levels in the putamen --> HP:0000013
# alpers syndrome --> HP:0031353
# early age of onset --> HP:0011152
# fatal --> HP:0006583
# intractable seizures --> HP:0001250
# hepatic failure --> HP:0001399
# global neurological deterioration --> HP:0001268
# high signal intensity within occipital and temporal lobes --> HP:0012824
# palatal tremor --> HP:0010530
# facial dyskinesia --> HP:0002310
# decreased complex iii activity --> HP:0011924
# multiple mtdna deletions --> HP:0003689
# dramatic weight loss --> HP:0001824
# gastroparesis --> HP:0002578
# ptosis --> HP:0000508
# ophthalmoplegia --> HP:0000602
# peripheral neuropathy --> HP:0009830
# sensory ataxia --> HP:0010871
# sensory – ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoplegia --> HP:0000602
# hypoxia --> HP:0012418
# ascites --> HP:0001541
# tachycardia --> HP:0001649
# intermittent fevers --> HP:0001954
# sepsis --> HP:0100806
# cirrhosis --> HP:0001394
# steatosis --> HP:0001397
# focal necrosis --> HP:0003338
# complex iii deﬁciency --> HP:0000694
# severely cytochrome oxidase - deﬁcient muscle --> HP:0012828
# deﬁciencies in all etc complexes --> HP:0000027
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# distance visual acuity was 0. 50 and 0. 40 logmar --> HP:0000152
# speech disorder --> HP:0006977
# left side weakness --> HP:0012835
# progressive bilateral ptosis --> HP:0000590
# hearing loss --> HP:0000365
# difficulties in swallowing --> HP:0002015
# bilateral ptosis --> HP:0001488
# bilateral hearing loss --> HP:0008619
# mild dysphagia --> HP:0001658
# myopathic pattern --> HP:0003458
# mild --> HP:0012825
# increase in cholesterol levels --> HP:0031211
# bilateral ptosis --> HP:0001488
# severe ophthalmoparesis --> HP:0000597
# hearing loss --> HP:0000365
# dysarthria --> HP:0001260
# left facial nerve palsy --> HP:0010628
# left side hemiparesis --> HP:0001269
# right pre - rolandic hyperintensity --> HP:0012824
# acute ischaemic lesion --> HP:0011009
# bilateral focal hyperintensities, --> HP:0012832
# lesions --> HP:0002833
# increased level of serum creatine kinase --> HP:0003236
# moderate --> HP:0012826
# sensorimotor bilateral hypoacusia --> HP:0012832
# myopathic --> HP:0002058
# bilateral ptosis --> HP:0001488
# lateral rectus palsies --> HP:0006897
# horizontal diplopia --> HP:0006897
# nasal, ﬂaccid dysarthria --> HP:0001260
# facial weakness --> HP:0030319
# tongue weakness --> HP:0000183
# power was reduced in both deltoid muscles --> HP:0000027
# loss of pigmented neurons in the substantia nigra --> HP:0000002
# gliosis --> HP:0002171
# gliosis --> HP:0002171
# ventrolateral posterior nuclei of the thalamus --> HP:0025275
# nucleus --> HP:0002339
# loss of the purkinje cells in the superior cerebellar vermis --> HP:0007001
# ptosis --> HP:0000508
# bilateral ptosis --> HP:0001488
# vertical and --> HP:0500074
# horizontal ophthalmoplegia --> HP:0030773
# bifacial weakness --> HP:0030319
# weakness in the proximal and distal upper --> HP:0012839
# lower --> HP:0000178
# left - sided intention tremor --> HP:0001337
# electromyography --> HP:0003457
# myopathy --> HP:0003198
# ##illation potentials --> HP:0002326
# moderate ﬁber size --> HP:0012826
# atrophic and hypertrophic ﬁbers --> HP:0000230
# increased internal nuclei --> HP:0031237
# fatty replacement of endomysial connective tissue --> HP:0000002
# ragged red ﬁbers --> HP:0003200
# ﬁbers --> HP:0100305
# dehydrogenase --> HP:0002928
# ragged blue --> HP:0001370
# reduced --> HP:0031851
# absent cytochrome c oxidase ( cox ) activity --> HP:0000027
# demyelination --> HP:0011096
# cataracts --> HP:0000518
# ovarian dysgenesis --> HP:0000138
# - onset --> HP:0003674
# distal muscle weakness --> HP:0002460
# microvesicular steatosis --> HP:0001414
# cerebral cortex showing activated astrocytes --> HP:0000935
# multiple mtdna deletions --> HP:0003689
# progressive cognitive deﬁcits --> HP:0200134
# cognitive deﬁcits --> HP:0100543
# epileptic seizures --> HP:0033052
# recurrent headaches --> HP:0002331
# mild --> HP:0012825
# personality changes --> HP:0000751
# movement disorder --> HP:0007153
# action - triggered myoclonus --> HP:0001336
# dystonic ulnar deviation --> HP:0000497
# progressive cerebellar ataxia --> HP:0002073
# wheel - chair bound --> HP:0011621
# incomplete --> HP:0010861
# chronic progressive external ophthalmoplegia --> HP:0000544
# peo --> HP:6001120
# severe axonal sensorimotor neuropathy --> HP:0007141
# cox - negative fibers --> HP:0002486
# ragged red fibers --> HP:0003200
# hepat --> HP:0001394
# lower limb --> HP:0007210
# dystonia --> HP:0001332
# peripheral neuropathy --> HP:0009830
# dystonia --> HP:0001332
# accumulation of lipids --> HP:0034787
# mitochondria were enlarged --> HP:0001427
# irregular cristae of a tubular --> HP:0000005
# complete horizontal gaze palsy --> HP:0000511
# severe ataxia --> HP:0001251
# reflexes were absent --> HP:0001284
# choreoathetotic --> HP:0001266
# complete absence of proprioceptive sensation --> HP:0000002
# somnolent --> HP:0005335
# loss of extraocular movement --> HP:0000597
# spasticity --> HP:0001257
# hyperreflexia --> HP:0001347
# t2 prolongation --> HP:0007183
# frontoparietal subcortical white matter --> HP:0000555
# genu of the corpus callosum --> HP:0006989
# genu of the right internal capsule --> HP:0012834
# anterior thalamus --> HP:0000236
# bilateral cerebellar hemispheres --> HP:0012832
# bilateral cerebellar peduncles --> HP:0012832
# subacute hemorrhage --> HP:0011009
# thalamus --> HP:0000864
# putamen --> HP:0031982
# showed an --> HP:0000802
# elevated lactate level --> HP:6000467
# depressed n - acetylaspartate level --> HP:0000272
# elevated choline level in --> HP:0012706
# basal ganglia --> HP:0012697
# gliotic white matter --> HP:0000591
# foamy histiocytes --> HP:0003651
# cells --> HP:0001404
# loss of myelin --> HP:0003387
# reactive astrocytes --> HP:0003203
# glial fibrillary acidic protein --> HP:0032650
# active demyelinating process --> HP:0000264
# adult - onset --> HP:0003581
# progressive external ophthalmoplegia --> HP:0000590
# peo --> HP:6001120
# progressive encephalopathy --> HP:0002448
# cox - deficient --> HP:0003213
# ragged - red fibres --> HP:0003200
# coagulopathy --> HP:0003256
# elevated liver enzymes --> HP:0002910
# seizures --> HP:0001250
# abnormalities in thalamus and basal ganglia --> HP:0000027
# alpers syndrome --> HP:0031353
# hepatic failure --> HP:0001399
# hand tremor --> HP:0002378
# hand tremor --> HP:0002378
# slurred speech --> HP:0001350
# increase in vanillate levels --> HP:0000093
# myelin basic protein level was higher than 1000 ng / ml --> HP:0000093
# oligoclonal bands were present --> HP:0003852
# serum lactate level was slightly high --> HP:0000218
# epilepsy --> HP:0001250
# eeg showed sharp and slow wave focus in the right posterior quadrant --> HP:0000009
# serum ck level was 1. 5 normal --> HP:0001975
# electromyography was myopathic --> HP:0002058
# myopathic --> HP:0002058
# cox - negative ragged red fibers --> HP:0000230
# lactate peak in cerebrospinal fluid detected on spectroscopy --> HP:0000027
# fat deposition was prominent in superficial muscles --> HP:0012830
# microvesicular --> HP:0001414
# cholestasis --> HP:0001396
# chronic myopathy --> HP:0009071
# severe sensory neuropathy --> HP:0000763
# dysm --> HP:0000641
# hypogonadism --> HP:0000135
# hypothyroidism --> HP:0000821
# osteopenia --> HP:0000938
# ragged - red fibers --> HP:0003200
# variation of fiber caliber --> HP:0000008
# nuclear centralization --> HP:0030645
# reduced --> HP:0031851
# absent reactivity to cytochrome c oxidase --> HP:0000027
# alpers syndrome --> HP:0031353
# mtdna depletion --> HP:0003387
# hypomimia --> HP:0000338
# bilateral bradykinesia --> HP:0002067
# right - sided resting tremor --> HP:0001337
# forced anteroflexion of --> HP:0000008
# reduced cox activity --> HP:0008321
# focal convulsions --> HP:0011172
# convulsions --> HP:0002069
# post - ) ictal paresis --> HP:0011172
# dysphasia --> HP:0032696
# focal occipital epileptic discharges --> HP:0030650
# irregular menstrual cycles --> HP:0000858
# portal tracts were enlarged --> HP:0000040
# proliferation of bile ductules --> HP:0000005
# bile plugs --> HP:0034294
# brainstem auditory evoked potential showed increased i – iii latency --> HP:0000016
# decreased sensory and motor nerve conduct velocity --> HP:0003448
# progressive proximal limb weakness --> HP:0003676
# continuous 2 hz polyspike - and - slow waves --> HP:0000152
# asymmetric ptosis --> HP:0000508
# muscle atrophy --> HP:0003202
# pectus excavatum ( --> HP:0000767
# funnel breast --> HP:0000769
# muscle atrophy --> HP:0003202
# ragged red fibers --> HP:0003200
# mitochondrial myopathy --> HP:0003737
# deficient in the mtdna - encoded cytochrome c oxidase ( cox --> HP:0000009
# multiple mtdna deletions --> HP:0003689
# extra - pyramidal rigidity --> HP:0002063
# cogwheel sign --> HP:0002403
# postural instability --> HP:0002172
# hypomimic face --> HP:0000338
# hypophonia --> HP:0001621
# bilateral ptosis --> HP:0001488
# ophthalmoplegia --> HP:0000602
# proximal muscle weak - ness --> HP:0003701
# oligomenorrhea --> HP:0000876
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# mitochondria with abnormal concentric cristae --> HP:0001427
# depletion of mtdna --> HP:0000008
#
#  Unmapped Mentions (12):
# percutaneous endoscopic gastrostomy
# ##et alpers
# died
# laterocollis
# sando
# sando
# syncopal episode
# rrf
# died
# sando
# ##ar
# bilirubinostasis

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio  


MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUT_FILE  = Path("/kaggle/working/bio_outputs/mapped_mentions.jsonl")
MAX_LENGTH = 512 
DEVICE = 0 

# Monarch v3 API & ClinicalTables
MONARCH_BASE = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"


FUZZY_CUTOFF = 85

SIM_THRESH = 65

# === HTTP session with retries ===
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# === Step 1: Load test data ===
print(">> Loading test data")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]
orig_sentences = [ex["text"] for ex in test_data]

# === Step 2: Load model and tokenizer with pipeline ===
print(">> Loading model and tokenizer")
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=DEVICE
)

# === Step 3: Load HPO terms from hp.obo
print(">> Loading HPO terms from obo")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (will still try online normalization): {e}")
    graph = None

hpo_map = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

# === Online normalizers (Monarch v3 -> ClinicalTables) ===
@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None

        best_curie, best_score = None, -1
        for it in items:
            curie = it.get("id") or it.get("curie")
            label = (it.get("label") or it.get("name") or "").strip()
            cats  = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    score = token_set_ratio(q.lower(), label.lower()) if label else 0
                    if score > best_score:
                        best_score, best_curie = score, curie
        return best_curie if best_score >= SIM_THRESH else None
    except Exception:
        return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            best_id, best_score = None, -1
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    score = token_set_ratio(q.lower(), (name or "").lower())
                    if score > best_score:
                        best_score, best_id = score, hp_id
            return best_id if best_score >= SIM_THRESH else None
    except Exception:
        return None
    return None

# === Your original normalize_mention, upgraded with online -> local fallback
def normalize_mention(text: str):
    # 1) Monarch v3
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    # 2) ClinicalTables
    curie = normalize_via_ct(text)
    if curie:
        return curie
    key = text.lower().strip()

    if key in hpo_map:
        score = token_set_ratio(key, key)  
        return hpo_map[key][0] if score >= SIM_THRESH else None

    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        matched_term = match[0]  
        score = token_set_ratio(key, matched_term)
        if score >= SIM_THRESH:
            return hpo_map[matched_term][0]
    return None

# === Step 4: Run NER + Normalize (No Noise Filtering)
print(">> Running NER and normalization")
mapped_mentions = []
unmapped_mentions = []
normalized_mentions = []

for idx, sentence in enumerate(orig_sentences):
    # 按你的要求：不传 truncation/max_length
    results = ner_pipeline(sentence)
    for ent in results:
        if ent["entity_group"] != "HPO_TERM":
            continue
        mention = ent["word"].strip()
        hpo_id = normalize_mention(mention)
        (mapped_mentions if hpo_id else unmapped_mentions).append((mention, hpo_id))
        normalized_mentions.append({
            "sentence_id": idx,
            "mention": mention,
            "hpo_id": hpo_id
        })

total  = len(normalized_mentions)
mapped = sum(1 for r in normalized_mentions if r["hpo_id"] is not None)
print(f"\nTotal mentions:  {total}")
print(f"Mapped to HP ID: {mapped} ({mapped/total:.1%})" if total else "Mapped to HP ID: 0 (n/a)")
print(f"Failed to map:   {total - mapped} ({(total - mapped)/total:.1%})" if total else "Failed to map: 0 (n/a)")

OUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with OUT_FILE.open("w", encoding="utf-8") as fout:
    for rec in normalized_mentions:
        fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"\n Mapped Mentions ({len(mapped_mentions)}):")
for mention, hpo_id in mapped_mentions:
    print(f"{mention} --> {hpo_id}")

print(f"\n Unmapped Mentions ({len(unmapped_mentions)}):")
for mention, _ in unmapped_mentions:
    print(mention)
# Out:
# Device set to use cuda:0
# >> Loading test data
# >> Loading model and tokenizer
# >> Loading HPO terms from obo
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Running NER and normalization
#
# Total mentions:  644
# Mapped to HP ID: 447 (69.4%)
# Failed to map:   197 (30.6%)
#
#  Mapped Mentions (447):
# cytochrome c oxidase negative muscle fibers --> HP:0003688
# polyneuropathy --> HP:0001271
# neuropathic pain --> HP:6000040
# ragged - red fibers --> HP:0003200
# dyskinesia --> HP:0100660
# severe stand - ing tremor --> HP:0001337
# dysphagia --> HP:0002015
# loss of weight --> HP:0001824
# malnutrition --> HP:0004395
# mechanical ventilation --> HP:0004887
# t2 hyperintensities in the --> HP:6000416
# cerebellar white matter --> HP:0007033
# neurological deterioration --> HP:0002344
# tetraparesis --> HP:0002273
# hypotonia --> HP:0001252
# cognitive impairment --> HP:0100543
# multifocal myoclonus --> HP:0040148
# bilateral cerebellum --> HP:0012832
# frontal cortex --> HP:0031421
# bilateral parietal cortex --> HP:0012832
# elevated lactate concentration --> HP:0002151
# partial status epilepticus --> HP:0032662
# progressive cognitive dysfunction --> HP:0003676
# psychotic features --> HP:0000725
# progressive external ophthalmoplegia --> HP:0000590
# resting tremor --> HP:0002322
# myoclonic jerks --> HP:0007000
# bilateral foot drop --> HP:0009027
# cerebellar and cerebral atrophy --> HP:0002059
# white matter spongiosis of the cerebellum --> HP:6001166
# mtdna depletion --> HP:0003387
# intermittent facial and jaw opening dystonia --> HP:0001332
# postural instability --> HP:0002172
# trunk ataxia --> HP:0002078
# severe dysarthria --> HP:0001260
# incomplete horizontal and vertical external ophthalmoplegia --> HP:0000544
# ataxia --> HP:0001251
# stand assisted --> HP:0004887
# sensory ataxic neuropathy --> HP:0003434
# cerebellar --> HP:0001251
# weakness --> HP:0031108
# diplopia --> HP:0000651
# dysarthria --> HP:0001260
# multiple deletions of mitochondrial dna --> HP:0003689
# dorsal spinocerebellar tract degeneration --> HP:0002503
# nucleus --> HP:0002339
# sensory peripheral neuropathy --> HP:0007067
# neuronal loss --> HP:0200147
# gliosis in substantia nigra --> HP:0011960
# 3 - methylglutaconic acid --> HP:0003535
# myopathic --> HP:0002058
# muscles --> HP:0000211
# axonal neuropathy --> HP:0007002
# cortical atrophy --> HP:0007112
# hypoketotic hypoglycaemia --> HP:0001985
# lethargy --> HP:0001254
# epilepsia partialis continua --> HP:0012847
# right - sided hemiparesis --> HP:0001269
# disoriented --> HP:0025237
# acalculia --> HP:0002442
# cortical occipital lesions --> HP:0000803
# leftsided pulvinar thalamic abnormalities --> HP:0000078
# syndrome --> HP:0000012
# tremor --> HP:0001337
# hyperglycemia --> HP:0003074
# progressively blurred vision --> HP:0000622
# diplopia --> HP:0000651
# bilateral ptosis --> HP:0001488
# choking episodes --> HP:0030842
# fatigue --> HP:0012378
# shortness of breath --> HP:0002094
# serum creatine kinase was mildly elevated --> HP:0003236
# axonal, and sensory polyneuropathy --> HP:0001271
# myopathic --> HP:0002058
# neuropathic --> HP:0002821
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# nuclear cl --> HP:0100018
# fiber type grouping --> HP:0033685
# progressive balance disturbance --> HP:0003676
# hopping --> HP:5200134
# reduced vibration sensation --> HP:0000217
# supranuclear vertical gaze paresis --> HP:0000511
# right internuclear ophthalmoparesis --> HP:0000597
# chronic denervation in distal muscles --> HP:0011010
# had worsened --> HP:0025286
# denervation --> HP:0009109
# hypotonia --> HP:0001252
# developmental delay --> HP:0001263
# hepatopathy --> HP:0001410
# seizures --> HP:0001250
# micronodular cirrhosis --> HP:0001413
# bile ductular proliferation --> HP:0001408
# nasogastric feeding --> HP:0040288
# psychomotor regression --> HP:0002376
# hepatopathy --> HP:0001410
# acute liver failure --> HP:0006554
# elevated csf protein --> HP:6000205
# abnormal eeg --> HP:0010846
# polyspike discharges --> HP:0025644
# bradykinesia --> HP:0002067
# cognitive impairment --> HP:0100543
# executive dysfunction --> HP:0100639
# language domain impairment --> HP:0002463
# moderate --> HP:0012826
# diffuse brain atrophy --> HP:0002283
# bilateral striatal dopamine deﬁciency --> HP:0012832
# multiple mtdna deletions --> HP:0003689
# fatigue --> HP:0012378
# bilateral eyelid drooping --> HP:0001488
# numbness in both feet --> HP:0033748
# left - sided ptosis --> HP:0000508
# complete ophthalmoplegia --> HP:0007824
# proximal muscle weakness --> HP:0003701
# parkinsonian --> HP:0001300
# rigidity --> HP:0002063
# tremor --> HP:0001337
# bradykinesia --> HP:0002067
# difficulty performing fine motor tasks --> HP:0000019
# cognitive impairment --> HP:0100543
# increasing dysphagia --> HP:0002015
# dysarthria --> HP:0001260
# dysphonia --> HP:0001618
# proximal myopathy --> HP:0003198
# sensorimotor neuropathy --> HP:0007141
# dysphagia --> HP:0002015
# peg tube --> HP:0011471
# recurrent aspiration --> HP:0002100
# pneumonia --> HP:0002090
# sensory – ataxic neuropathy --> HP:0003434
# ophthalmoplegia --> HP:0000602
# dysarthria --> HP:0001260
# gastroparesis --> HP:0002578
# epileptic event --> HP:0033346
# severe epilepsy --> HP:0001250
# insect bite --> HP:0410339
# secondarily generalized focal crisis --> HP:0012837
# hypertonia --> HP:0001276
# myoclonus --> HP:0001336
# secondarily generalized focal crisis --> HP:0012837
# motor deterioration --> HP:0002333
# increase of the subarachnoid space --> HP:0012704
# atrophy of the left hemisphere --> HP:0012835
# motor focal seizures --> HP:0032665
# upper extremity myoclonus --> HP:0001336
# encephalopathy --> HP:0001298
# inexpressive facies --> HP:0000274
# facial hypomimia --> HP:0000338
# axial hypotonia --> HP:0008936
# hypo / areflexia --> HP:0001284
# distal limb increased tone --> HP:0012839
# right tetraparesis --> HP:0002273
# drooling --> HP:0002307
# frequent paroxysmal outbreaks of highvoltage delta waves --> HP:0040282
# deep cerebral folate deficiency 3 nmol / l ( --> HP:0012446
# peo --> HP:0000544
# bilateral ptosis --> HP:0001488
# dysarthria --> HP:0001260
# ataxia --> HP:0001251
# neuropathy --> HP:0009830
# dysphagia --> HP:0002015
# aspiration pneumonia --> HP:0011951
# bilateral hand contractures --> HP:0012832
# depression --> HP:0000716
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# external ophthalmoplegia --> HP:0000544
# saccadic pursuit --> HP:0001152
# dysarthria --> HP:0001260
# bilateral dysdiadochokinesis --> HP:0002075
# dysmetria --> HP:0001310
# poor --> HP:0004396
# heel - toe walking --> HP:0030051
# tremor --> HP:0001337
# myoclonic --> HP:0033054
# choreic --> HP:0002072
# peripheral neuropathy --> HP:0009830
# electronegative erg --> HP:0007984
# generalized rod on - bipolar dysfunction --> HP:0012837
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# generalized epilepsy --> HP:0001250
# acute liver failure --> HP:0006554
# migraines --> HP:0002076
# epilepsia partialis continua --> HP:0012847
# myoclonic arm jerks --> HP:0001336
# progressive cognitive impairment --> HP:0003676
# intractable epilepsy --> HP:0001250
# liver disease --> HP:0006557
# respiratory chain defect --> HP:0200125
# parkinsonism --> HP:0001300
# sensory ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoparesis --> HP:0000597
# headaches --> HP:0002315
# aphasia --> HP:0002381
# visual aura --> HP:0011165
# lesions in the right striatal area --> HP:0012834
# leigh ’ s encephalopathy --> HP:0001298
# bilateral ptosis --> HP:0001488
# severe external ophthalmoplegia --> HP:0000544
# parkinsonism --> HP:0001300
# peo --> HP:0000544
# ptosis --> HP:0000508
# focal slowing --> HP:0030650
# status epilepticus --> HP:0002133
# delayed ﬁne motor skills --> HP:0002194
# ovarian dysgenesis --> HP:0000138
# seizure like episode --> HP:0001250
# cerebellar atrophy --> HP:0001272
# action tremor --> HP:0002345
# stiffness --> HP:0030965
# parkinsonism --> HP:0001300
# numbness in her feet --> HP:0033748
# parkinsonism --> HP:0001300
# bradykinesia --> HP:0002067
# stooped posture --> HP:0025403
# rigidity --> HP:0002063
# peripheral neuropathy --> HP:0009830
# generalized cerebral and cerebellar atrophy --> HP:0001272
# partial motor status epilepticus --> HP:0032662
# abnormal liver function tests --> HP:0200148
# focal area of restricted diffusion --> HP:0030650
# encephalopathic --> HP:0001298
# focal status --> HP:0032663
# seizures --> HP:0001250
# enlarged mitochondria --> HP:0001427
# myopathy --> HP:0003198
# peo --> HP:0000544
# ptosis --> HP:0000508
# gait instability --> HP:0002317
# proximal arm weakness --> HP:0003701
# ﬁber size variability --> HP:0003557
# central nuclei --> HP:0003687
# increased --> HP:0033373
# anxiety and obsessive disorder --> HP:0000739
# cortical atrophy --> HP:0007112
# bilateral peo --> HP:0012832
# ptosis --> HP:0000508
# myopathic --> HP:0002058
# mitochondrial myopathy --> HP:0003737
# proximal and distal weakness in lower limbs --> HP:0012839
# sensory ataxia --> HP:0010871
# demyelinating sensorymotor neuropathy --> HP:0011402
# anxiety - mood disorders --> HP:0000739
# dystonia --> HP:0001332
# subsarcolemmal accumulation of abnormal mitochondria --> HP:0003548
# multiple mitochondrial dna ( mtdna ) deletions --> HP:0003689
# progressive sensory ataxic neuropathy --> HP:0003434
# ptosis --> HP:0000508
# dysarthria --> HP:0001260
# dysphagia --> HP:0002015
# external ophthalmoparesis --> HP:0000597
# cytochrome oxidase - negative ﬁbres --> HP:0003688
# cytochrome c oxidase --> HP:0003688
# multiple mtdna deletions --> HP:0003689
# mtdna depletion --> HP:0003387
# palatal tremor --> HP:0010530
# early age of onset --> HP:0011152
# fatal --> HP:0006583
# hepatic failure --> HP:0001399
# global neurological deterioration --> HP:0001268
# high signal intensity within occipital and temporal lobes --> HP:0012824
# palatal tremor --> HP:0010530
# facial dyskinesia --> HP:0002310
# decreased complex iii activity --> HP:0011924
# multiple mtdna deletions --> HP:0003689
# dramatic weight loss --> HP:0001824
# gastroparesis --> HP:0002578
# ptosis --> HP:0000508
# ophthalmoplegia --> HP:0000602
# peripheral neuropathy --> HP:0009830
# sensory ataxia --> HP:0010871
# sensory – ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoplegia --> HP:0000602
# hypoxia --> HP:0012418
# ascites --> HP:0001541
# tachycardia --> HP:0001649
# intermittent fevers --> HP:0001954
# sepsis --> HP:0100806
# cirrhosis --> HP:0001394
# steatosis --> HP:0001397
# focal necrosis --> HP:0003338
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# speech disorder --> HP:0006977
# left side weakness --> HP:0012835
# progressive bilateral ptosis --> HP:0000590
# hearing loss --> HP:0000365
# difficulties in swallowing --> HP:0002015
# bilateral ptosis --> HP:0001488
# bilateral hearing loss --> HP:0008619
# myopathic pattern --> HP:0003458
# mild --> HP:0012825
# increase in cholesterol levels --> HP:0031211
# bilateral ptosis --> HP:0001488
# severe ophthalmoparesis --> HP:0000597
# hearing loss --> HP:0000365
# dysarthria --> HP:0001260
# left facial nerve palsy --> HP:0010628
# left side hemiparesis --> HP:0001269
# acute ischaemic lesion --> HP:0011009
# bilateral focal hyperintensities, --> HP:0012832
# lesions --> HP:0002833
# increased level of serum creatine kinase --> HP:0003236
# moderate --> HP:0012826
# sensorimotor bilateral hypoacusia --> HP:0012832
# myopathic --> HP:0002058
# bilateral ptosis --> HP:0001488
# lateral rectus palsies --> HP:0031751
# horizontal diplopia --> HP:0000651
# nasal, ﬂaccid dysarthria --> HP:0001260
# facial weakness --> HP:0030319
# tongue weakness --> HP:0000183
# gliosis --> HP:0002171
# gliosis --> HP:0002171
# nucleus --> HP:0002339
# loss of the purkinje cells in the superior cerebellar vermis --> HP:0007001
# ptosis --> HP:0000508
# bilateral ptosis --> HP:0001488
# vertical and --> HP:0500074
# horizontal ophthalmoplegia --> HP:0030773
# bifacial weakness --> HP:0030319
# weakness in the proximal and distal upper --> HP:0012839
# lower --> HP:0000178
# left - sided intention tremor --> HP:0001337
# myopathy --> HP:0003198
# moderate ﬁber size --> HP:0012826
# increased internal nuclei --> HP:0008151
# dehydrogenase --> HP:0002928
# reduced --> HP:0031851
# demyelination --> HP:0011096
# cataracts --> HP:0000518
# ovarian dysgenesis --> HP:0000138
# - onset --> HP:0003674
# distal muscle weakness --> HP:0002460
# microvesicular steatosis --> HP:0001414
# multiple mtdna deletions --> HP:0003689
# progressive cognitive deﬁcits --> HP:0003676
# cognitive deﬁcits --> HP:0100543
# epileptic seizures --> HP:0033052
# recurrent headaches --> HP:0002331
# mild --> HP:0012825
# personality changes --> HP:0000751
# movement disorder --> HP:0007153
# action - triggered myoclonus --> HP:0001336
# progressive cerebellar ataxia --> HP:0002073
# incomplete --> HP:0010861
# chronic progressive external ophthalmoplegia --> HP:0000544
# peo --> HP:0000544
# severe axonal sensorimotor neuropathy --> HP:0007141
# ragged red fibers --> HP:0003200
# lower limb --> HP:0007210
# dystonia --> HP:0001332
# peripheral neuropathy --> HP:0009830
# dystonia --> HP:0001332
# accumulation of lipids --> HP:0034787
# complete horizontal gaze palsy --> HP:0000511
# severe ataxia --> HP:0001251
# reflexes were absent --> HP:0001284
# choreoathetotic --> HP:0001266
# somnolent --> HP:0005335
# loss of extraocular movement --> HP:0000597
# spasticity --> HP:0001257
# hyperreflexia --> HP:0001347
# genu of the corpus callosum --> HP:0006989
# genu of the right internal capsule --> HP:0012834
# bilateral cerebellar hemispheres --> HP:0012832
# bilateral cerebellar peduncles --> HP:0012832
# putamen --> HP:0031982
# elevated lactate level --> HP:0012707
# elevated choline level in --> HP:0012706
# basal ganglia --> HP:0012697
# foamy histiocytes --> HP:0003651
# cells --> HP:0001404
# loss of myelin --> HP:0003380
# glial fibrillary acidic protein --> HP:0032650
# adult - onset --> HP:0003581
# progressive external ophthalmoplegia --> HP:0000590
# peo --> HP:0000544
# progressive encephalopathy --> HP:0002448
# cox - deficient --> HP:0003213
# ragged - red fibres --> HP:0003200
# coagulopathy --> HP:0003256
# elevated liver enzymes --> HP:0002910
# seizures --> HP:0001250
# hepatic failure --> HP:0001399
# hand tremor --> HP:0002378
# hand tremor --> HP:0002378
# slurred speech --> HP:0001350
# epilepsy --> HP:0001250
# electromyography was myopathic --> HP:0002058
# myopathic --> HP:0002058
# microvesicular --> HP:0001414
# cholestasis --> HP:0001396
# chronic myopathy --> HP:0009071
# severe sensory neuropathy --> HP:0000763
# hypogonadism --> HP:0000135
# hypothyroidism --> HP:0000821
# osteopenia --> HP:0000938
# ragged - red fibers --> HP:0003200
# reduced --> HP:0031851
# mtdna depletion --> HP:0003387
# hypomimia --> HP:0000338
# bilateral bradykinesia --> HP:0002067
# right - sided resting tremor --> HP:0001337
# reduced cox activity --> HP:0008321
# focal convulsions --> HP:0030650
# convulsions --> HP:0002069
# focal occipital epileptic discharges --> HP:0030650
# irregular menstrual cycles --> HP:0000858
# portal tracts were enlarged --> HP:0000040
# bile plugs --> HP:0034294
# decreased sensory and motor nerve conduct velocity --> HP:0003448
# progressive proximal limb weakness --> HP:0003676
# asymmetric ptosis --> HP:0000508
# muscle atrophy --> HP:0003202
# pectus excavatum ( --> HP:0000767
# muscle atrophy --> HP:0003202
# ragged red fibers --> HP:0003200
# mitochondrial myopathy --> HP:0003737
# multiple mtdna deletions --> HP:0003689
# extra - pyramidal rigidity --> HP:0002063
# postural instability --> HP:0002172
# hypomimic face --> HP:0000338
# hypophonia --> HP:0001621
# bilateral ptosis --> HP:0001488
# ophthalmoplegia --> HP:0000602
# proximal muscle weak - ness --> HP:0003701
# oligomenorrhea --> HP:0000876
# subsarcolemmal accumulation of mitochondria --> HP:0003548
#
#  Unmapped Mentions (197):
# reduction of activities of complex i and iv
# lower extremities were diffusely thin
# power to be 0 / 5 at wrist ﬂexors and extensors
# 0 / 5 at biceps
# 5 / 5 at deltoid muscles
# / 5 at
# was 5 / 5 in
# / 5 at tibialis anterior
# absent reﬂexes in upper extremities
# percutaneous endoscopic gastrostomy
# ventilatory failure
# serum ck level remains high
# high serum pyruvate and lactate levels
# low vitamin b12 and 25 - hydroxyvitamin d levels
# atrophy of the left parieto - occipital lobe
# refractory partial seizures
# t2 / flair hyperintensities
# hypersignals in thalami
# lactate doublet peak
# absence of sensory response in both arms and legs
# neurogenic motor units
# spongiform changes in the cerebrum
# brainstem bleeding
# multiple lacunar ischaemic cortical infarcts
# cox - negative areas
# dystonic ulnar deviation
# visual disturbances
# dysphasia
# degeneration of dorsal root ganglia
# cox - negative ﬁbres
# ragged - red ” ﬁbres
# cytochrome c oxidase ( cox ) - negative fibres
# blood pyruvate was 172 μmol / litre
# glycaemia
# mild ketonuria
# non - syndromic ovarian dysfunction
# elevation of cerebrospinal ﬂuid ( csf ) lactate
# content of mtdna was slightly reduced in muscle
# alpers syndrome
# right - sided focal motor seizures
# mental status deteriorated
# dysphasia
# ##et alpers
# upper limb mixed rest and
# percutaneous gastrostomy tube
# died
# baseline lactate was high
# cox - negative muscle fibers
# lumbosacral radiculopathy
# trouble walking heel - to - toe
# pinprick sensation ( reduced to the mid - calves
# reduced sensory amplitudes
# elevated csf lactate
# ##v
# refractory mixed type seizures
# high amplitude slow wave activity
# liver enzymatic respiratory chain defects
# complex iv showed a decreased activity
# mild apraxia
# enlargement of the ventricles
# ragged red ﬁbres
# infectious process
# igm antiborrellia titers were high
# high blood lactate value
# pale eye fundus
# motor disturbances
# lost deambulation
# difficulties in handling objects
# electroencephalogram disclosed spontaneously slow and poorly organized trace
# right predominance activated during sleep
# myofibers were abnormally small
# subsarcolemmal collections of mitochondria
# cox - negative ﬁbres
# raggedred ﬁbres
# stage atrophy in gastrocnemius
# basal ganglia show hyperintense and swollen deep grey matter nuclei
# hyperintensity and swelling of the cortical grey and subcortical white matter
# fed through a
# g - tube
# wheelchair bound
# failing to thrive
# selective rod on - bipolar cell dysfunction
# writhing tongue movements
# laterocollis
# dystonic posturing
# striatal toes
# sando
# long - standing learning difﬁculties
# pancerebellar syndrome
# sando syndrome
# sando
# t2 - hyperintense, oedemic lesions in the left thalamus
# parieto - occipital region
# homonymous right - sided visual ﬁeld defect
# inferior colliculi
# epileptic spikes
# vision problems
# bilateral cataracts
# inability to use both of her hands
# atrophy of arm and hand muscles
# absent menarche
# syncopal episode
# hyperintense lesions in left inferior olivary nucleus
# dystonic toe curling
# facial masking
# sensorimotor, predominantly sensory
# subtle gyral swelling
# continuous paroxysmal lateralizing epileptiform discharges
# mitochondria with tubular cristae formations
# alpers syndrome
# near falls
# ragged red
# ragged blue ( succinate dehydrogenase – positive ) ﬁbers
# cytochrome c oxidase ( cox ) - negative ﬁbers
# abnormally swollen mitochondria and paracrystalline inclusions
# cytochrome - c - oxidase ( cox - ) activity was deficient
# cognition was mildly affected
# creatine kinase levels were 217 u / l
# myoglobin was 360 u / l
# ragged blue
# cortical and subcortical hyperintensities
# dystonic ulnar deviation
# jerky wrist and ﬁnger movements
# polymini - myoclonus
# cox - deficient fibers
# ragged - red ” ﬁbres
# rrf
# inferior olivary nuclei
# reduced dopamine transporter levels in the putamen
# alpers syndrome
# intractable seizures
# complex iii deﬁciency
# severely cytochrome oxidase - deﬁcient muscle
# deﬁciencies in all etc complexes
# distance visual acuity was 0. 50 and 0. 40 logmar
# mild dysphagia
# right pre - rolandic hyperintensity
# power was reduced in both deltoid muscles
# loss of pigmented neurons in the substantia nigra
# ventrolateral posterior nuclei of the thalamus
# electromyography
# ##illation potentials
# atrophic and hypertrophic ﬁbers
# fatty replacement of endomysial connective tissue
# ragged red ﬁbers
# ﬁbers
# ragged blue
# absent cytochrome c oxidase ( cox ) activity
# cerebral cortex showing activated astrocytes
# dystonic ulnar deviation
# wheel - chair bound
# cox - negative fibers
# hepat
# mitochondria were enlarged
# irregular cristae of a tubular
# complete absence of proprioceptive sensation
# t2 prolongation
# frontoparietal subcortical white matter
# anterior thalamus
# subacute hemorrhage
# thalamus
# showed an
# depressed n - acetylaspartate level
# gliotic white matter
# reactive astrocytes
# active demyelinating process
# died
# abnormalities in thalamus and basal ganglia
# alpers syndrome
# sando
# increase in vanillate levels
# myelin basic protein level was higher than 1000 ng / ml
# oligoclonal bands were present
# serum lactate level was slightly high
# eeg showed sharp and slow wave focus in the right posterior quadrant
# serum ck level was 1. 5 normal
# cox - negative ragged red fibers
# lactate peak in cerebrospinal fluid detected on spectroscopy
# fat deposition was prominent in superficial muscles
# ##ar
# dysm
# variation of fiber caliber
# nuclear centralization
# absent reactivity to cytochrome c oxidase
# alpers syndrome
# forced anteroflexion of
# post - ) ictal paresis
# dysphasia
# bilirubinostasis
# proliferation of bile ductules
# brainstem auditory evoked potential showed increased i – iii latency
# continuous 2 hz polyspike - and - slow waves
# funnel breast
# deficient in the mtdna - encoded cytochrome c oxidase ( cox
# cogwheel sign
# mitochondria with abnormal concentric cristae
# depletion of mtdna

# %%
import json
from pathlib import Path
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline

# ====== CONFIG ======
MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")      
OUTPUT_XLSX = Path("/kaggle/working/hpo_spans_dual.xlsx")     

LIGATURE_MAP = {
    "ﬁ": "fi",
    "ﬂ": "fl",
    "ﬀ": "ff",
    "ﬃ": "ffi",
    "ﬄ": "ffl",
}

def clean_with_map(orig_text: str):
    clean_chars = []
    c2o = []
    i = 0
    while i < len(orig_text):
        ch = orig_text[i]
        if ch in LIGATURE_MAP:
            repl = LIGATURE_MAP[ch]
            for rc in repl:
                clean_chars.append(rc)
                c2o.append(i) 
            i += 1
        else:
            clean_chars.append(ch)
            c2o.append(i)
            i += 1
    return "".join(clean_chars), c2o

device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple", 
    device=device
)

# ====== READ TEST DATA ======
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]

rows = []
for rec in test_data:
    orig_text = rec["text"]
    clean_text, c2o = clean_with_map(orig_text)

    ents = ner_pipeline(clean_text)

    for ent in ents:
        if ent.get("entity_group") != "HPO_TERM":
            continue

        clean_start = ent.get("start")
        clean_end = ent.get("end")
        if clean_start is None or clean_end is None:
            continue
        if clean_start < 0 or clean_end > len(clean_text) or clean_start >= clean_end:
            continue

        clean_span = clean_text[clean_start:clean_end]

        orig_start = c2o[clean_start]
        orig_end   = c2o[clean_end - 1] + 1 
        original_span = orig_text[orig_start:orig_end]

        rows.append({
            "original_text": orig_text,
            "original_span": original_span,
            "original_start": int(orig_start),
            "original_end": int(orig_end),
            "clean_text": clean_text,
            "clean_span": clean_span,
            "clean_start": int(clean_start),
            "clean_end": int(clean_end),
        })

if rows:
    df = pd.DataFrame(rows).sort_values(by=["original_start", "original_end"]).reset_index(drop=True)
else:
    df = pd.DataFrame(columns=[
        "original_text","original_span","original_start","original_end",
        "clean_text","clean_span","clean_start","clean_end"
    ])

df.to_excel(OUTPUT_XLSX, index=False, engine="openpyxl")
print(f"Saved {len(df)} rows to: {OUTPUT_XLSX.resolve()}")
# Out:
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Saved 658 rows to: /kaggle/working/hpo_spans_dual.xlsx

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache
import unicodedata

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio 

# ========== CONFIG ==========
MODEL_DIR   = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE   = Path("/kaggle/working/bio_outputs/test.jsonl")  
OUTPUT_XLSX = Path("/kaggle/working/hpo_for_thiloka.xlsx")

SIM_THRESH   = 50
FUZZY_CUTOFF = 85

# Monarch v3 API & ClinicalTables
MONARCH_BASE  = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"

LIGATURE_MAP = {
    "ﬁ": "fi",
    "ﬂ": "fl",
    "ﬀ": "ff",
    "ﬃ": "ffi",
    "ﬄ": "ffl",
}
def clean_with_map(orig_text: str):
    clean_chars, c2o = [], []
    i = 0
    while i < len(orig_text):
        ch = orig_text[i]
        if ch in LIGATURE_MAP:
            repl = LIGATURE_MAP[ch]
            for _ in repl:
                clean_chars.append(_)    
                c2o.append(i)         
            i += 1
        else:
            clean_chars.append(ch)
            c2o.append(i)
            i += 1
    return "".join(clean_chars), c2o

# ========== HTTP session with retries ==========
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

print(">> Loading HPO terms from hp.obo …")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (we'll still try online normalization): {e}")
    graph = None

hpo_map = {}
id_to_label = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if node_id and name:
            id_to_label[node_id] = name
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None
        best_curie, best_score = None, -1
        for it in items:
            curie  = it.get("id") or it.get("curie")
            label  = (it.get("label") or it.get("name") or "").strip()
            cats   = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    score = token_set_ratio(q.lower(), label.lower()) if label else 0
                    if score > best_score:
                        best_score, best_curie = score, curie
        return best_curie if best_score >= SIM_THRESH else None
    except Exception:
        return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            best_id, best_score = None, -1
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    score = token_set_ratio(q.lower(), (name or "").lower())
                    if score > best_score:
                        best_score, best_id = score, hp_id
            return best_id if best_score >= SIM_THRESH else None
    except Exception:
        return None
    return None

def normalize_mention(text: str) -> Optional[str]:
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    curie = normalize_via_ct(text)
    if curie:
        return curie
    key = text.lower().strip()
    if key in hpo_map:
        return hpo_map[key][0]
    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        matched_term = match[0]
        score = token_set_ratio(key, matched_term)
        if score >= SIM_THRESH:
            return hpo_map[matched_term][0]
    return None

def label_for(hpo_id: Optional[str]) -> str:
    if not hpo_id:
        return "no_match"
    return id_to_label.get(hpo_id, "no_match")

print(">> Loading NER model …")
device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model     = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple", 
    device=device
)

print(">> Loading test set …")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]

rows = []
print(">> Extracting spans and normalising …")
for rec in test_data:
    orig_text = rec["text"]
    clean_text, c2o = clean_with_map(orig_text)

    ents = ner_pipeline(clean_text)
    for ent in ents:
        if ent.get("entity_group") != "HPO_TERM":
            continue

        c_start = ent.get("start")
        c_end   = ent.get("end")
        if c_start is None or c_end is None:
            continue
        if c_start < 0 or c_end > len(clean_text) or c_start >= c_end:
            continue


        o_start = c2o[c_start]
        o_end   = c2o[c_end - 1] + 1
        span_text = orig_text[o_start:o_end]


        span_for_norm = clean_text[c_start:c_end]
        hp_id = normalize_mention(span_for_norm)
        hp_label = label_for(hp_id)


        rows.append({
            "Span": span_text,
            "Predicted standardised HPO term": hp_label if hp_id else "no_match",
            "Predicted HPO ID": hp_id if hp_id else "no_match",
            "Correct label? (Y/N/YN)": "",
            "Correct HPO term": "",
            "Correct HPO ID": ""
        })


df = pd.DataFrame(
    rows,
    columns=[
        "Span",
        "Predicted standardised HPO term",
        "Predicted HPO ID",
        "Correct label? (Y/N/YN)",
        "Correct HPO term",
        "Correct HPO ID",
    ]
)
df.to_excel(OUTPUT_XLSX, index=False, engine="openpyxl")
print(f">> Wrote {len(df)} rows to {OUTPUT_XLSX.resolve()}")
# Out:
# >> Loading HPO terms from hp.obo …
# Device set to use cuda:0
# >> Loading NER model …
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Loading test set …
# >> Extracting spans and normalising …
# >> Wrote 658 rows to /kaggle/working/hpo_for_thiloka.xlsx

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache
import unicodedata

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

import torch
import pandas as pd
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio  

# ========== CONFIG ==========
MODEL_DIR   = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE   = Path("/kaggle/working/bio_outputs/test.jsonl")  
OUTPUT_XLSX = Path("/kaggle/working/hpo_for_thiloka_process.xlsx")


SIM_THRESH   = 50
FUZZY_CUTOFF = 85

# Monarch v3 API & ClinicalTables
MONARCH_BASE  = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"


LIGATURE_MAP = {
    "ﬁ": "fi",
    "ﬂ": "fl",
    "ﬀ": "ff",
    "ﬃ": "ffi",
    "ﬄ": "ffl",
}
def clean_with_map(orig_text: str):

    clean_chars, c2o = [], []
    i = 0
    while i < len(orig_text):
        ch = orig_text[i]
        if ch in LIGATURE_MAP:
            repl = LIGATURE_MAP[ch]
            for rc in repl:
                clean_chars.append(rc)
                c2o.append(i)
            i += 1
        else:
            clean_chars.append(ch)
            c2o.append(i)
            i += 1
    return "".join(clean_chars), c2o


def clean_text(m: str) -> str:
    if not m:
        return m
    m = unicodedata.normalize("NFKC", m)
    m = m.replace("–", "-").replace("—", "-")
    m = m.translate(str.maketrans({
        "“": '"', "”": '"', "„": '"', "‟": '"',
        "’": "'", "‘": "'", "‚": "'", "‛": "'"
    }))
    m = re.sub(r"\s+", " ", m).strip()
    return m

_ABBR_PATTERNS = [
    (re.compile(r"\brrf\b", flags=re.I), "ragged red fibers"),
    (re.compile(r"\bragged[-\s]?red\b", flags=re.I), "ragged red"),
    (re.compile(r"\bcox\b", flags=re.I), "cytochrome c oxidase"),
    (re.compile(r"\bsdh\b", flags=re.I), "succinate dehydrogenase"),
    (re.compile(r"\bg[-\s]?tube\b", flags=re.I), "gastrostomy tube"),
]
def expand_abbrev(m: str) -> str:
    t = m
    for pat, rep in _ABBR_PATTERNS:
        t = pat.sub(rep, t)
    return t

_CANON_SUBS = [
    (re.compile(r"\bdysphasia\b", re.I), "aphasia"),
    (re.compile(r"\bwheel[-\s]?chair\s*bound\b", re.I), "wheelchair dependence"),
    (re.compile(r"\bfailing\s+to\s+thrive\b", re.I), "failure to thrive"),
    (re.compile(r"\bsyncopal\s+episode\b", re.I), "syncope"),
    (re.compile(r"\blumbosacral\s+radiculopathy\b", re.I), "radiculopathy"),
    (re.compile(r"\bragged\s+blue\b(?!\s*fib)", re.I), "ragged blue fibers"),
    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*negative", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*deficien\w*", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b.*\b(csfs?|cerebrospinal\s+fluid)\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bjerky\s+\w+(\s+and\s+\w+)?\s+movements\b", re.I), "myoclonus"),
    (re.compile(r"\bcomplete\s+absence\s+of\s+proprioceptive\s+sensation\b", re.I),
     "loss of proprioception"),
    (re.compile(r"\bpolymini\W*myoclonus\b", re.I), "polyminimyoclonus"),
    (re.compile(r"\bdystonic\s+toe\s+curling\b", re.I), "dystonia of toes"),
    (re.compile(r"\bstriatal\s+toes?\b", re.I), "striatal toe"),
    (re.compile(r"\bnear\s+falls?\b", re.I), "recurrent falls"),
]
def canonicalize_synonyms(m: str) -> str:
    s = m
    for pat, rep in _CANON_SUBS:
        s = pat.sub(rep, s)
    return s

_REGION_PATTERNS = [
    (re.compile(r"\bcortical\s+gr[ae]y(?:\s+matter)?\b", re.I), "cortical gray matter"),
    (re.compile(r"\bsubcortical\s+white\s+matter\b", re.I), "subcortical white matter"),
    (re.compile(r"\bbasal\s+ganglia\b", re.I), "basal ganglia"),
    (re.compile(r"\bthalam(?:us|i)\b", re.I), "thalamus"),
    (re.compile(r"\bparieto[-\s]?occipital\b", re.I), "parieto-occipital region"),
    (re.compile(r"\bfrontoparietal\s+subcortical\s+white\s+matter\b", re.I), "frontoparietal subcortical white matter"),
    (re.compile(r"\bpre[-\s]?rolandic\b", re.I), "pre-rolandic cortex"),
    (re.compile(r"\binferior\s+olivary\s+nucleus\b", re.I), "inferior olivary nucleus"),
]
_FINDING_PATTERNS = [
    (re.compile(r"\bt2\s*[- ]?\s*hyperintens\w*\b", re.I), "T2 hyperintensity"),
    (re.compile(r"\bhypersignal(s)?\b", re.I), "T2 hyperintensity"),
    (re.compile(r"\bhyperintens\w*\b", re.I), "T2 hyperintensity"),
    (re.compile(r"\bhemorrhag\w*\b", re.I), "hemorrhage"),
    (re.compile(r"\bswell\w*\b", re.I), "swelling"),
    (re.compile(r"\batroph\w*\b", re.I), "atrophy"),
    (re.compile(r"\bglios\w*\b", re.I), "gliosis"),
    (re.compile(r"\blesion\w*\b", re.I), "lesion"),
    (re.compile(r"\bprolongation\b", re.I), "T2 prolongation"),
    (re.compile(r"\bhypointens\w*\b", re.I), "T2 hypointensity"),
]
_PATHO_TEMPLATES = [
    (re.compile(r"\bcytochrome\s+c\s+oxidase\b.*\bnegative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?negative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?deficien\w*\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\bragged\s+blue\b.*\bfib(er|re)s\b", re.I),
     "ragged blue fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bvariation\s+of\s+fiber\s+calib(er|re)\b", re.I),
     "variation in skeletal muscle fiber size"),
    (re.compile(r"\bnuclear\s+centralization\b", re.I),
     "increased central nuclei in skeletal muscle fibers"),
    (re.compile(r"\bfatty\s+replacement\b.*\bendomysial\b", re.I),
     "fatty infiltration of skeletal muscle"),
    (re.compile(r"\bparacrystalline\s+inclusion\w*\b", re.I),
     "mitochondrial paracrystalline inclusions"),
    (re.compile(r"\bswollen\s+mitochondria\b|\babnormally\s+swollen\s+mitochondria\b", re.I),
     "swollen mitochondria"),
    (re.compile(r"\b(concentric|tubular|irregular)\s+cristae\b", re.I),
     "abnormal mitochondrial cristae morphology"),
    (re.compile(r"\b(poly)?spike\s*-\s*(and\s*-\s*)?slow\s*waves?\b", re.I),
     "EEG with epileptiform discharges"),
    (re.compile(r"\bsharp\s+and\s+slow\s+wave(s)?\b", re.I),
     "EEG with epileptiform discharges"),
]
def rewrite_imaging_pathology(m: str) -> Optional[str]:
    s = m
    for pat, rep in _PATHO_TEMPLATES:
        if pat.search(s):
            return rep
    found_region = None
    for pat, norm in _REGION_PATTERNS:
        if pat.search(s):
            found_region = norm
            break
    found_finding = None
    for pat, norm in _FINDING_PATTERNS:
        if pat.search(s):
            found_finding = norm
            break
    if found_finding and found_region:
        return f"{found_finding} of {found_region}"
    if found_finding:
        return found_finding
    return None

def rewrite_numeric_to_qualitative(m: str) -> Optional[str]:
    s = m.lower()
    if re.search(r"\b(vitamin\s*b12|b\s*12)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating vitamin B12"
    if re.search(r"\b(25[-\s]?hydroxyvitamin\s*d|25ohd|25\W*oh\W*d)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating 25-hydroxyvitamin D"
    if re.search(r"\b(csfs?|cerebrospinal\s+fluid)\b.*\blactate\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased cerebrospinal fluid lactate"
    if re.search(r"\blactate\b.*\b(spectroscop\w*|mrs)\b", s):
        return "increased brain lactate on magnetic resonance spectroscopy"
    if re.search(r"\b(serum\s+)?ck\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high|above\s+normal|x\s*normal)\b", s) or re.search(r"\b\d+(\.\d+)?\s*x\s*normal\b", s):
            return "elevated serum creatine kinase"
    if re.search(r"\bmyoglobin\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
            return "elevated myoglobin"
    if re.search(r"\b(pyruvate)\b", s) and (re.search(r"\b(blood|serum)\b", s) or re.search(r"\b\du?mol\b", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s) or re.search(r"\d", s):
            return "increased blood pyruvate"
    if re.search(r"\bvanillat\w*\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased vanillate level"
    if re.search(r"\bdopamine\s+transporter\b", s) and re.search(r"\b(reduc\w*|decreas\w*|low)\b", s):
        return "decreased dopamine transporter level"
    if re.search(r"\blogmar\b", s):
        return "decreased visual acuity"
    if re.search(r"\bketonuria\b", s):
        return "ketonuria"
    if re.search(r"\bvisual\s+disturbance(s)?\b", s):
        return "visual impairment"
    return None

def apply_templates(m: str) -> str:
    img = rewrite_imaging_pathology(m)
    if img:
        return img
    numq = rewrite_numeric_to_qualitative(m)
    if numq:
        return numq
    return m

def dedup_adjacent_words(s: str) -> str:
    return re.sub(r'\b(\w+)(\s+\1\b)+', r'\1', s, flags=re.I)

_MRC = re.compile(r"\b\d+\s*/\s*\d+\b")  # 例如 5/5, 0/5
_STOPWORDS = {"in", "at", "of", "was", "to", "is", "are", "be", "the", "and"}
_BAD_START = re.compile(r"^##")
_BAD_FRAGMENTS = [
    re.compile(r"\bfed\s+through\s+a\b", re.I),
    re.compile(r"\bshowed\s+an\b", re.I),
    re.compile(r"^\s*(hepat|dysm|##ar|##et)\b", re.I),
]
def is_noise(m: str) -> bool:
    if not m:
        return True
    m_strip = m.strip()
    if _BAD_START.search(m_strip):
        return True
    for pat in _BAD_FRAGMENTS:
        if pat.search(m_strip):
            return True
    alpha = sum(c.isalpha() for c in m_strip)
    if alpha < 2 or len(m_strip) < 3:
        return True
    if _MRC.search(m_strip):
        return True
    toks = re.findall(r"[a-z]+", m_strip.lower())
    if toks and all(t in _STOPWORDS for t in toks):
        return True
    return False

# ========== HTTP session with retries ==========
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

print(">> Loading HPO terms from hp.obo …")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (we'll still try online normalization): {e}")
    graph = None

hpo_map = {}
id_to_label = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if node_id and name:
            id_to_label[node_id] = name
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None
        best_curie, best_score = None, -1
        for it in items:
            curie  = it.get("id") or it.get("curie")
            label  = (it.get("label") or it.get("name") or "").strip()
            cats   = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    score = token_set_ratio(q.lower(), label.lower()) if label else 0
                    if score > best_score:
                        best_score, best_curie = score, curie
        return best_curie if best_score >= SIM_THRESH else None
    except Exception:
        return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            best_id, best_score = None, -1
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    score = token_set_ratio(q.lower(), (name or "").lower())
                    if score > best_score:
                        best_score, best_id = score, hp_id
            return best_id if best_score >= SIM_THRESH else None
    except Exception:
        return None
    return None

def normalize_mention(text: str) -> Optional[str]:
    # 优先在线
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    curie = normalize_via_ct(text)
    if curie:
        return curie
    # 本地兜底
    key = text.lower().strip()
    if key in hpo_map:
        return hpo_map[key][0]
    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        matched_term = match[0]
        score = token_set_ratio(key, matched_term)
        if score >= SIM_THRESH:
            return hpo_map[matched_term][0]
    return None

def label_for(hpo_id: Optional[str]) -> str:
    if not hpo_id:
        return "no_match"
    return id_to_label.get(hpo_id, "no_match")

print(">> Loading NER model …")
device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model     = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=device
)

print(">> Loading test set …")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]

rows = []
print(">> Extracting spans and normalising …")
for rec in test_data:
    orig_text = rec["text"]
    clean_text_mapped, c2o = clean_with_map(orig_text)

    ents = ner_pipeline(clean_text_mapped)
    for ent in ents:
        if ent.get("entity_group") != "HPO_TERM":
            continue

        c_start = ent.get("start")
        c_end   = ent.get("end")
        if c_start is None or c_end is None:
            continue
        if c_start < 0 or c_end > len(clean_text_mapped) or c_start >= c_end:
            continue

        o_start = c2o[c_start]
        o_end   = c2o[c_end - 1] + 1
        span_text = orig_text[o_start:o_end]

        span_for_norm = clean_text(clean_text_mapped[c_start:c_end])
        span_for_norm = expand_abbrev(span_for_norm)
        span_for_norm = canonicalize_synonyms(span_for_norm)
        span_for_norm = apply_templates(span_for_norm)
        span_for_norm = dedup_adjacent_words(span_for_norm)
        if is_noise(span_for_norm):
            hp_id = None
        else:
            hp_id = normalize_mention(span_for_norm)

        hp_label = label_for(hp_id)

        rows.append({
            "Span": span_text,
            "Predicted standardised HPO term": hp_label if hp_id else "no_match",
            "Predicted HPO ID": hp_id if hp_id else "no_match",
            "Correct label? (Y/N/YN)": "",
            "Correct HPO term": "",
            "Correct HPO ID": ""
        })

df = pd.DataFrame(
    rows,
    columns=[
        "Span",
        "Predicted standardised HPO term",
        "Predicted HPO ID",
        "Correct label? (Y/N/YN)",
        "Correct HPO term",
        "Correct HPO ID",
    ]
)
df.to_excel(OUTPUT_XLSX, index=False, engine="openpyxl")
print(f">> Wrote {len(df)} rows to {OUTPUT_XLSX.resolve()}")
# Out:
# >> Loading HPO terms from hp.obo …
# Device set to use cuda:0
# >> Loading NER model …
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Loading test set …
# >> Extracting spans and normalising …
# >> Wrote 658 rows to /kaggle/working/hpo_for_thiloka_process.xlsx

# %%
import json
from pathlib import Path
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
import re
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio

import unicodedata 
import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
from typing import Optional
from functools import lru_cache

MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUTPUT_XLSX = Path("/kaggle/working/hpo_compare.xlsx")


FUZZY_CUTOFF = 85    
SIM_THRESH   = 70    

LIGATURE_MAP = {
    "ﬁ": "fi",
    "ﬂ": "fl",
    "ﬀ": "ff",
    "ﬃ": "ffi",
    "ﬄ": "ffl",
}

def clean_with_map(orig_text: str):
    clean_chars, c2o = [], []
    for i, ch in enumerate(orig_text):
        if ch in LIGATURE_MAP:
            repl = LIGATURE_MAP[ch]
            for _ in repl:
                clean_chars.append(_)
                c2o.append(i)
        else:
            clean_chars.append(ch)
            c2o.append(i)
    return "".join(clean_chars), c2o

def clean_text(m: str) -> str:
    if not m:
        return m
    m = unicodedata.normalize("NFKC", m)
    m = m.replace("–", "-").replace("—", "-")
    m = m.translate(str.maketrans({
        "“": '"', "”": '"', "„": '"', "‟": '"',
        "’": "'", "‘": "'", "‚": "'", "‛": "'"
    }))
    m = re.sub(r"\s+", " ", m).strip()
    return m


gold_spans_by_text = []
with TEST_FILE.open(encoding="utf-8") as f:
    for line in f:
        rec = json.loads(line)
        text = rec["text"]
        spans = rec.get("spans", [])
        gold_hpo = []
        for sp in spans:
            if sp.get("label") == "HPO_TERM":
                start, end = sp["start"], sp["end"]
                gold_hpo.append((start, end, text[start:end]))
        gold_spans_by_text.append({"text": text, "gold_spans": gold_hpo})


print(">> Loading hp.obo for local HPO normalization")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo: {e}")
    graph = None

hpo_keys = []
term2ids = {}
id2label = {}

if graph is not None:
    for node_id, data in graph.nodes(data=True):
        if not isinstance(node_id, str) or not node_id.startswith("HP:"):
            continue
        label = (data.get("name") or "").strip()
        if label:
            id2label[node_id] = label
            term2ids.setdefault(label.lower(), set()).add(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                syn_txt = m.group(1).strip()
                if syn_txt:
                    term2ids.setdefault(syn_txt.lower(), set()).add(node_id)
    hpo_keys = list(term2ids.keys())

# ====== Online standardization via Monarch and ClinicalTables ======
MONARCH_BASE = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"

# === Session creation for retries ===
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

STOPWORDS = {"a","an","the","to","of","in","on","for","and","or","with","at","by","from","is","are","was","were"}
KEY_HEADWORDS = {"sensation","sense","vibration","pinprick","pain","touch","temperature",
                 "proprioception","hearing","vision","taste","smell"}

def _content_tokens(s: str):
    toks = re.findall(r"[a-z]+", (s or "").lower())
    return [t for t in toks if t not in STOPWORDS]

def _overlap_ratio(mention: str, label: str):
    m = set(_content_tokens(mention))
    l = set(_content_tokens(label))
    if not m or not l:
        return 0.0, 0.0, 0
    inter = m & l
    return (len(inter)/max(1,len(m))), (len(inter)/max(1,len(l))), len(inter)

def _headword_bonus(mention: str, label: str):
    m = set(_content_tokens(mention))
    l = set(_content_tokens(label))
    return 1.1 if (m & KEY_HEADWORDS) and (l & KEY_HEADWORDS) else 1.0

def _contextual_score(mention: str, sent_text: str, label: str):
    s1 = token_set_ratio((mention or "").lower(), (label or "").lower())
    s2 = token_set_ratio((sent_text or "").lower(), (label or "").lower())
    return 0.7 * s1 + 0.3 * s2

@lru_cache(maxsize=10000)
def normalize_via_monarch_full(q: str):
    q = (q or "").strip()
    if not q:
        return []
    try:
        r = SESSION.get(
            f"{MONARCH_BASE}/autocomplete",
            params={"q": q, "category": "biolink:PhenotypicFeature", "limit": 15},
            timeout=6
        )
        if r.status_code != 200:
            return []
        data = r.json()
        items = data.get("items") or data.get("results") or data
        out = []
        if isinstance(items, list):
            for it in items:
                hp = it.get("id") or it.get("curie")
                lab = (it.get("label") or it.get("name") or "").strip()
                if isinstance(hp, str) and hp.startswith("HP:") and lab:
                    out.append((hp, lab))
        return out
    except Exception:
        return []

@lru_cache(maxsize=10000)
def normalize_via_ct_full(q: str):
    q = (q or "").strip()
    if not q:
        return []
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 20}, timeout=6)
        if r.status_code != 200:
            return []
        data = r.json()
        out = []
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:") and name:
                    out.append((hp_id, name))
        return out
    except Exception:
        return []

def _local_candidates(q: str):
    key = (q or "").lower().strip()
    cands = []
    if key in term2ids: 
        for hp in term2ids[key]:
            cands.append((hp, id2label.get(hp, key)))
    if hpo_keys:

        match = process.extract(key, hpo_keys, limit=15, score_cutoff=max(70, FUZZY_CUTOFF-10))
        for cand, _score, _ in match:
            for hp in term2ids.get(cand, []):
                cands.append((hp, id2label.get(hp, cand)))
    seen, uniq = set(), []
    for hp, lab in cands:
        if (hp, lab) not in seen:
            uniq.append((hp, lab))
            seen.add((hp, lab))
    return uniq

def normalize_mention(mention: str, sent_text: str):

    cands = []
    cands += normalize_via_monarch_full(mention)
    cands += normalize_via_ct_full(mention)


    seen, uniq = set(), []
    for hp, lab in cands:
        if (hp, lab) not in seen:
            uniq.append((hp, lab))
            seen.add((hp, lab))

    if not uniq:
        uniq = _local_candidates(mention)

    best = (None, None, -1.0)  # (hp, lab, score)
    for hp, lab in uniq:
        if not lab:
            continue
        base = _contextual_score(mention, sent_text, lab)
        m_overlap, l_overlap, inter = _overlap_ratio(mention, lab)
        if m_overlap < 0.5 or l_overlap < 0.3 or inter == 0:
            continue
        bonus = _headword_bonus(mention, lab)
        score = base * bonus
        if score > best[2]:
            best = (hp, lab, score)

    hp_id, hp_lab, score = best
    if hp_id is None:
        return None, None
    if score < max(65, SIM_THRESH):
        return None, None
    return hp_id, hp_lab

device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)
ner_pipeline = pipeline("ner", model=model, tokenizer=tokenizer,
                        aggregation_strategy="simple", device=device)

rows = []
for rec in gold_spans_by_text:
    orig_text = rec["text"]
    gold_spans = rec["gold_spans"] 
    clean_txt, c2o = clean_with_map(orig_text)

    preds = ner_pipeline(clean_txt)

    for ent in preds:
        if ent.get("entity_group") != "HPO_TERM":
            continue

        clean_start, clean_end = ent["start"], ent["end"]
        orig_start = c2o[clean_start]
        orig_end = c2o[clean_end - 1] + 1
        pred_span_text = orig_text[orig_start:orig_end]

        clean_span_text = clean_txt[clean_start:clean_end]
        pred_id, pred_label = normalize_mention(clean_span_text, orig_text)

        predicted_hpo_term = pred_label if pred_label else "no_match"
        predicted_hpo_id   = pred_id if pred_id else "no_match"

        gold_term = ""

        for gs in gold_spans:
            if gs[0] == orig_start and gs[1] == orig_end:
                gold_term = gs[2]
                break
        if not gold_term:
            overlapped = None
            for gs in gold_spans:
                gs_start, gs_end = gs[0], gs[1]
                if gs_start <= orig_end and gs_end >= orig_start:
                    overlapped = gs
                    break
            if overlapped:
                gold_term = overlapped[2]
            else:
                gold_term = "; ".join([gs[2] for gs in gold_spans]) if gold_spans else ""

        rows.append({
            "Gold HPO term": gold_term,                           
            "Span": pred_span_text,                              
            "Predicted standardised HPO term": predicted_hpo_term,
            "Predicted HPO ID": predicted_hpo_id,                 
            "Correct label? (Y/N/YN)": "",                        
            "Correct HPO term": "",                               
            "Correct HPO ID": ""
        })

df = pd.DataFrame(rows)
df.to_excel(OUTPUT_XLSX, index=False, engine="openpyxl")
print(f"Saved comparison file to {OUTPUT_XLSX.resolve()}")
# Out:
# >> Loading hp.obo for local HPO normalization
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Saved comparison file to /kaggle/working/hpo_compare.xlsx

# %%
import json
from pathlib import Path
import pandas as pd
import torch
from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline


MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")   
OUTPUT_XLSX = Path("/kaggle/working/hpo_pred_vs_gold.xlsx")


LIGATURE_MAP = {
    "ﬁ": "fi",
    "ﬂ": "fl",
    "ﬀ": "ff",
    "ﬃ": "ffi",
    "ﬄ": "ffl",
}
def clean_with_map(orig_text: str):
    clean_chars, c2o = [], []
    i = 0
    while i < len(orig_text):
        ch = orig_text[i]
        if ch in LIGATURE_MAP:
            repl = LIGATURE_MAP[ch]
            for rc in repl:
                clean_chars.append(rc)
                c2o.append(i)  
            i += 1
        else:
            clean_chars.append(ch)
            c2o.append(i)
            i += 1
    return "".join(clean_chars), c2o


device = 0 if torch.cuda.is_available() else -1
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)
ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=device
)


data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]


def format_spans(spans):
    # spans: list of dict with text/start/end
    return "; ".join([f"{s['text']}[{s['start']}:{s['end']}]" for s in spans])

def relaxed_match(pred, gold, text_len, tol=1):

    ps, pe = max(0, pred['start'] - tol), min(text_len, pred['end'] + tol)
    gs, ge = max(0, gold['start'] - tol), min(text_len, gold['end'] + tol)
    inter = max(0, min(pe, ge) - max(ps, gs))
    denom = max(pred['end'] - pred['start'], gold['end'] - gold['start'])
    if denom <= 0:
        return False, 0.0
    frac = inter / denom
    return (frac >= 0.5), frac


per_sentence_rows = []
detail_rows = []

for sid, rec in enumerate(data):
    orig_text = rec["text"]
    gold_spans = []
    for s in rec.get("spans", []):
        if s.get("label") == "HPO_TERM":
            gold_spans.append({
                "text": s.get("text", orig_text[s["start"]:s["end"]]),
                "start": int(s["start"]),
                "end": int(s["end"]),
            })

   
    clean_text, c2o = clean_with_map(orig_text)
    preds = []
    for ent in ner_pipeline(clean_text):
        if ent.get("entity_group") != "HPO_TERM":
            continue
        cs, ce = int(ent["start"]), int(ent["end"])
        if cs < 0 or ce > len(clean_text) or cs >= ce:
            continue
        os, oe = c2o[cs], c2o[ce - 1] + 1
        preds.append({
            "text": orig_text[os:oe],
            "start": os,
            "end": oe,
        })

    gold_used = [False] * len(gold_spans)
    pred_used = [False] * len(preds)

    for pi, p in enumerate(preds):
        best_g, best_frac = -1, 0.0
        for gi, g in enumerate(gold_spans):
            if gold_used[gi]:
                continue
            ok, frac = relaxed_match(p, g, len(orig_text), tol=1)
            if ok and frac > best_frac:
                best_frac, best_g = frac, gi
        if best_g >= 0:
            pred_used[pi] = True
            gold_used[best_g] = True
            g = gold_spans[best_g]
            detail_rows.append({
                "sent_id": sid,
                "type": "TP",
                "text": orig_text,
                "pred_text": p["text"], "pred_start": p["start"], "pred_end": p["end"],
                "gold_text": g["text"], "gold_start": g["start"], "gold_end": g["end"],
                "overlap_frac": round(best_frac, 3),
            })

    for pi, p in enumerate(preds):
        if not pred_used[pi]:
            detail_rows.append({
                "sent_id": sid,
                "type": "FP",
                "text": orig_text,
                "pred_text": p["text"], "pred_start": p["start"], "pred_end": p["end"],
                "gold_text": "", "gold_start": -1, "gold_end": -1,
                "overlap_frac": 0.0,
            })

    for gi, g in enumerate(gold_spans):
        if not gold_used[gi]:
            detail_rows.append({
                "sent_id": sid,
                "type": "FN",
                "text": orig_text,
                "pred_text": "", "pred_start": -1, "pred_end": -1,
                "gold_text": g["text"], "gold_start": g["start"], "gold_end": g["end"],
                "overlap_frac": 0.0,
            })

    TP = sum(1 for r in detail_rows if r["sent_id"] == sid and r["type"] == "TP")
    FP = sum(1 for r in detail_rows if r["sent_id"] == sid and r["type"] == "FP")
    FN = sum(1 for r in detail_rows if r["sent_id"] == sid and r["type"] == "FN")

    per_sentence_rows.append({
        "sent_id": sid,
        "text": orig_text,
        "gold_spans": format_spans(gold_spans),
        "pred_spans": format_spans(preds),
        "TP": TP, "FP": FP, "FN": FN
    })
with pd.ExcelWriter(OUTPUT_XLSX, engine="openpyxl") as writer:
    pd.DataFrame(per_sentence_rows).to_excel(writer, index=False, sheet_name="per_sentence")
    pd.DataFrame(detail_rows).to_excel(writer, index=False, sheet_name="details")

print(f"Saved comparison to: {OUTPUT_XLSX.resolve()}")
# Out:
# Device set to use cuda:0
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Saved comparison to: /kaggle/working/hpo_pred_vs_gold.xlsx

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache
import unicodedata

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio 

# === Config ===
MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUT_FILE  = Path("/kaggle/working/bio_outputs/mapped_mentions.jsonl")
MAX_LENGTH = 512 
DEVICE = 0  # use -1 for CPU

# Monarch v3 API & ClinicalTables
MONARCH_BASE = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"


FUZZY_CUTOFF = 85


SIM_THRESH = 65


def clean_text(m: str) -> str:
    if not m:
        return m
    m = unicodedata.normalize("NFKC", m)
    m = m.replace("–", "-").replace("—", "-")
    m = m.translate(str.maketrans({
        "“": '"', "”": '"', "„": '"', "‟": '"',
        "’": "'", "‘": "'", "‚": "'", "‛": "'"
    }))
    m = re.sub(r"\s+", " ", m).strip()
    return m

_ABBR_PATTERNS = [
    (re.compile(r"\brrf\b", flags=re.I), "ragged red fibers"),
    (re.compile(r"\bragged[-\s]?red\b", flags=re.I), "ragged red"),
    (re.compile(r"\bcox\b", flags=re.I), "cytochrome c oxidase"),
    (re.compile(r"\bsdh\b", flags=re.I), "succinate dehydrogenase"),
    (re.compile(r"\bg[-\s]?tube\b", flags=re.I), "gastrostomy tube"),
]
def expand_abbrev(m: str) -> str:
    t = m
    for pat, rep in _ABBR_PATTERNS:
        t = pat.sub(rep, t)
    return t


_CANON_SUBS = [
    (re.compile(r"\bdysphasia\b", re.I), "aphasia"),
    (re.compile(r"\bwheel[-\s]?chair\s*bound\b", re.I), "wheelchair dependence"),
    (re.compile(r"\bfailing\s+to\s+thrive\b", re.I), "failure to thrive"),
    (re.compile(r"\bsyncopal\s+episode\b", re.I), "syncope"),
    (re.compile(r"\blumbosacral\s+radiculopathy\b", re.I), "radiculopathy"),
    (re.compile(r"\bragged\s+blue\b(?!\s*fib)", re.I), "ragged blue fibers"),

    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*negative", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*deficien\w*", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b.*\b(csfs?|cerebrospinal\s+fluid)\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bjerky\s+\w+(\s+and\s+\w+)?\s+movements\b", re.I), "myoclonus"),
    (re.compile(r"\bcomplete\s+absence\s+of\s+proprioceptive\s+sensation\b", re.I),
     "loss of proprioception"),
]
def canonicalize_synonyms(m: str) -> str:
    s = m
    for pat, rep in _CANON_SUBS:
        s = pat.sub(rep, s)
    return s

_MRC = re.compile(r"\b\d+\s*/\s*\d+\b")  # e.g., 5/5, 0/5
_STOPWORDS = {"in", "at", "of", "was", "to", "is", "are", "be", "the", "and"}
def is_noise(m: str) -> bool:
    if not m:
        return True
    m_strip = m.strip()
    alpha = sum(c.isalpha() for c in m_strip)
    if alpha < 2 or len(m_strip) < 3:
        return True
    if _MRC.search(m_strip):
        return True
    toks = re.findall(r"[a-z]+", m_strip.lower())
    if toks and all(t in _STOPWORDS for t in toks):
        return True
    return False

_PHENOTYPE_HINTS = {
    "weakness","atrophy","pain","tremor","paralysis","dystonia","rigidity",
    "contracture","spasm","edema","hyperintensity","hypointensity","lesion",
    "defect","deficiency","deficient","absence","loss","dysphagia","apraxia",
    "seizure","myoclonus","dysarthria","ataxia","paresis","dysesthesia",
    "fibers","fibres","ragged","ragged-red","cox-negative","sdh-positive",
    "aphasia","syncope","radiculopathy","gliosis","proprioception","wheelchair"
}
def looks_like_phenotype(m: str) -> bool:
    toks = set(re.findall(r"[a-z]+", m.lower()))
    return bool(toks & _PHENOTYPE_HINTS)

_REGION_PATTERNS = [
    (re.compile(r"\bcortical\s+gr[ae]y(?:\s+matter)?\b", re.I), "cortical gray matter"),
    (re.compile(r"\bsubcortical\s+white\s+matter\b", re.I), "subcortical white matter"),
    (re.compile(r"\bbasal\s+ganglia\b", re.I), "basal ganglia"),
    (re.compile(r"\bthalam(?:us|i)\b", re.I), "thalamus"),
    (re.compile(r"\bparieto[-\s]?occipital\b", re.I), "parieto-occipital region"),
    (re.compile(r"\bfrontoparietal\s+subcortical\s+white\s+matter\b", re.I), "frontoparietal subcortical white matter"),
    (re.compile(r"\bpre[-\s]?rolandic\b", re.I), "pre-rolandic cortex"),
    (re.compile(r"\binferior\s+olivary\s+nucleus\b", re.I), "inferior olivary nucleus"),
]

_FINDING_PATTERNS = [
    (re.compile(r"\bt2\s*[- ]?\s*hyperintens\w*\b", re.I), "T2 hyperintensity"),
    (re.compile(r"\bhyperintens\w*\b", re.I), "T2 hyperintensity"),  # 默认归一到 T2 hyperintensity
    (re.compile(r"\bhemorrhag\w*\b", re.I), "hemorrhage"),
    (re.compile(r"\bswell\w*\b", re.I), "swelling"),
    (re.compile(r"\batroph\w*\b", re.I), "atrophy"),
    (re.compile(r"\bglios\w*\b", re.I), "gliosis"),
    (re.compile(r"\blesion\w*\b", re.I), "lesion"),
    (re.compile(r"\bprolongation\b", re.I), "T2 prolongation"),
    (re.compile(r"\bhypointens\w*\b", re.I), "T2 hypointensity"),
]

_PATHO_TEMPLATES = [
    (re.compile(r"\bcytochrome\s+c\s+oxidase\b.*\bnegative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?negative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?deficien\w*\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\bragged\s+blue\b.*\bfib(er|re)s\b", re.I),
     "ragged blue fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bvariation\s+of\s+fiber\s+calib(er|re)\b", re.I),
     "variation in skeletal muscle fiber size"),
    (re.compile(r"\bnuclear\s+centralization\b", re.I),
     "increased central nuclei in skeletal muscle fibers"),
    (re.compile(r"\bfatty\s+replacement\b.*\bendomysial\b", re.I),
     "fatty infiltration of skeletal muscle"),
]

def rewrite_imaging_pathology(m: str) -> Optional[str]:
    s = m
    for pat, rep in _PATHO_TEMPLATES:
        if pat.search(s):
            return rep

    found_region = None
    for pat, norm in _REGION_PATTERNS:
        if pat.search(s):
            found_region = norm
            break

    found_finding = None
    for pat, norm in _FINDING_PATTERNS:
        if pat.search(s):
            found_finding = norm
            break

    if found_finding and found_region:
        return f"{found_finding} of {found_region}"
    if found_finding:
        return found_finding
    return None

def rewrite_numeric_to_qualitative(m: str) -> Optional[str]:
    s = m.lower()


    if re.search(r"\b(vitamin\s*b12|b\s*12)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating vitamin B12"


    if re.search(r"\b(25[-\s]?hydroxyvitamin\s*d|25ohd|25\W*oh\W*d)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating 25-hydroxyvitamin D"


    if re.search(r"\b(csfs?|cerebrospinal\s+fluid)\b.*\blactate\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased cerebrospinal fluid lactate"


    if re.search(r"\blactate\b.*\b(spectroscop\w*|mrs)\b", s):
        return "increased brain lactate on magnetic resonance spectroscopy"

    if re.search(r"\b(serum\s+)?ck\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high|above\s+normal|x\s*normal)\b", s) or re.search(r"\b\d+(\.\d+)?\s*x\s*normal\b", s):
            return "elevated serum creatine kinase"


    if re.search(r"\bmyoglobin\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
            return "elevated myoglobin"


    if re.search(r"\b(pyruvate)\b", s) and (re.search(r"\b(blood|serum)\b", s) or re.search(r"\b\du?mol\b", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s) or re.search(r"\d", s):
            return "increased blood pyruvate"

    if re.search(r"\bvanillat\w*\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased vanillate level"

    if re.search(r"\bdopamine\s+transporter\b", s) and re.search(r"\b(reduc\w*|decreas\w*|low)\b", s):
        return "decreased dopamine transporter level"

    if re.search(r"\blogmar\b", s):
        return "decreased visual acuity"

    if re.search(r"\bketonuria\b", s):
        return "ketonuria"

    if re.search(r"\bvisual\s+disturbance(s)?\b", s):
        return "visual impairment"

    return None

def apply_templates(m: str) -> str:
    img = rewrite_imaging_pathology(m)
    if img:
        return img
    numq = rewrite_numeric_to_qualitative(m)
    if numq:
        return numq
    return m

def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# === Step 1: Load test data ===
print(">> Loading test data")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]
orig_sentences = [ex["text"] for ex in test_data]

# === Step 2: Load model and tokenizer with pipeline ===
print(">> Loading model and tokenizer")
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=DEVICE
)

# === Step 3: Load HPO terms from hp.obo
print(">> Loading HPO terms from obo")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (will still try online normalization): {e}")
    graph = None

hpo_map = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

# === Online normalizers (Monarch v3 -> ClinicalTables) ===
@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None
        best_curie, best_score = None, -1
        for it in items:
            curie = it.get("id") or it.get("curie")
            label = (it.get("label") or it.get("name") or "").strip()
            cats  = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    score = token_set_ratio(q.lower(), label.lower()) if label else 0
                    if score > best_score:
                        best_score, best_curie = score, curie
        return best_curie if best_score >= SIM_THRESH else None
    except Exception:
        return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            best_id, best_score = None, -1
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    score = token_set_ratio(q.lower(), (name or "").lower())
                    if score > best_score:
                        best_score, best_id = score, hp_id
            return best_id if best_score >= SIM_THRESH else None
    except Exception:
        return None
    return None

# === normalize_mention：
def normalize_mention(text: str):
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    curie = normalize_via_ct(text)
    if curie:
        return curie
    key = text.lower().strip()
    if key in hpo_map:
        score = token_set_ratio(key, key)
        return hpo_map[key][0] if score >= SIM_THRESH else None
    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        matched_term = match[0]
        score = token_set_ratio(key, matched_term)
        if score >= SIM_THRESH:
            return hpo_map[matched_term][0]
    return None

# === Step 4: Run NER + Normalize ===
print(">> Running NER and normalization")
mapped_mentions = []
unmapped_mentions = []
normalized_mentions = []

for idx, sentence in enumerate(orig_sentences):
    results = ner_pipeline(sentence)
    for ent in results:
        if ent["entity_group"] != "HPO_TERM":
            continue
        mention = ent["word"].strip()

        mention = clean_text(mention)
        mention = expand_abbrev(mention)
        mention = canonicalize_synonyms(mention)
        mention = apply_templates(mention)
        if is_noise(mention):
            continue
        # if not looks_like_phenotype(mention):
        #     continue

        hpo_id = normalize_mention(mention)
        (mapped_mentions if hpo_id else unmapped_mentions).append((mention, hpo_id))
        normalized_mentions.append({
            "sentence_id": idx,
            "mention": mention,
            "hpo_id": hpo_id
        })

total  = len(normalized_mentions)
mapped = sum(1 for r in normalized_mentions if r["hpo_id"] is not None)
print(f"\nTotal mentions:  {total}")
print(f"Mapped to HP ID: {mapped} ({mapped/total:.1%})" if total else "Mapped to HP ID: 0 (n/a)")
print(f"Failed to map:   {total - mapped} ({(total - mapped)/total:.1%})" if total else "Failed to map: 0 (n/a)")

OUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with OUT_FILE.open("w", encoding="utf-8") as fout:
    for rec in normalized_mentions:
        fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"\n Mapped Mentions ({len(mapped_mentions)}):")
for mention, hpo_id in mapped_mentions:
    print(f"{mention} --> {hpo_id}")

print(f"\n Unmapped Mentions ({len(unmapped_mentions)}):")
for mention, _ in unmapped_mentions:
    print(mention)
# Out:
# Device set to use cuda:0
# >> Loading test data
# >> Loading model and tokenizer
# >> Loading HPO terms from obo
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Running NER and normalization
#
# Total mentions:  638
# Mapped to HP ID: 496 (77.7%)
# Failed to map:   142 (22.3%)
#
#  Mapped Mentions (496):
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# absent reflexes in upper extremities --> HP:0001284
# polyneuropathy --> HP:0001271
# neuropathic pain --> HP:6000040
# ragged - red fibers --> HP:0003200
# dyskinesia --> HP:0100660
# severe stand - ing tremor --> HP:0001337
# dysphagia --> HP:0002015
# loss of weight --> HP:0001824
# malnutrition --> HP:0004395
# mechanical ventilation --> HP:0004887
# elevated serum creatine kinase --> HP:0008180
# increased blood pyruvate --> HP:0003542
# decreased circulating vitamin B12 --> HP:0100502
# T2 hyperintensity --> HP:0031206
# cerebellar white matter --> HP:0007033
# atrophy --> HP:0000029
# neurological deterioration --> HP:0002344
# tetraparesis --> HP:0002273
# hypotonia --> HP:0001252
# cognitive impairment --> HP:0100543
# multifocal myoclonus --> HP:0040148
# T2 hyperintensity --> HP:0031206
# bilateral cerebellum --> HP:0012832
# frontal cortex --> HP:0031421
# bilateral parietal cortex --> HP:0012832
# elevated lactate concentration --> HP:0002151
# partial status epilepticus --> HP:0032662
# progressive cognitive dysfunction --> HP:0003676
# psychotic features --> HP:0000725
# progressive external ophthalmoplegia --> HP:0000590
# resting tremor --> HP:0002322
# myoclonic jerks --> HP:0007000
# bilateral foot drop --> HP:0009027
# atrophy --> HP:0000029
# white matter spongiosis of the cerebellum --> HP:6001166
# mtdna depletion --> HP:0003387
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# intermittent facial and jaw opening dystonia --> HP:0001332
# postural instability --> HP:0002172
# trunk ataxia --> HP:0002078
# severe dysarthria --> HP:0001260
# incomplete horizontal and vertical external ophthalmoplegia --> HP:0000544
# ataxia --> HP:0001251
# stand assisted --> HP:0004887
# sensory ataxic neuropathy --> HP:0003434
# cerebellar --> HP:0001251
# weakness --> HP:0031108
# visual impairment --> HP:0000505
# diplopia --> HP:0000651
# dysarthria --> HP:0001260
# aphasia --> HP:0002381
# multiple deletions of mitochondrial dna --> HP:0003689
# dorsal spinocerebellar tract degeneration --> HP:0002503
# nucleus --> HP:0002339
# sensory peripheral neuropathy --> HP:0007067
# neuronal loss --> HP:0200147
# gliosis --> HP:0002171
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged - red " fibres --> HP:0003200
# 3 - methylglutaconic acid --> HP:0003535
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# myopathic --> HP:0002058
# muscles --> HP:0000211
# axonal neuropathy --> HP:0007002
# increased blood pyruvate --> HP:0003542
# atrophy --> HP:0000029
# hypoketotic hypoglycaemia --> HP:0001985
# lethargy --> HP:0001254
# ketonuria --> HP:0002919
# increased cerebrospinal fluid lactate --> HP:0002490
# epilepsia partialis continua --> HP:0012847
# right - sided hemiparesis --> HP:0001269
# disoriented --> HP:0025237
# aphasia --> HP:0002381
# acalculia --> HP:0002442
# lesion --> HP:0000700
# leftsided pulvinar thalamic abnormalities --> HP:0000078
# syndrome --> HP:0000012
# tremor --> HP:0001337
# hyperglycemia --> HP:0003074
# progressively blurred vision --> HP:0000622
# diplopia --> HP:0000651
# bilateral ptosis --> HP:0001488
# choking episodes --> HP:0030842
# fatigue --> HP:0012378
# shortness of breath --> HP:0002094
# serum creatine kinase was mildly elevated --> HP:0003236
# axonal, and sensory polyneuropathy --> HP:0001271
# myopathic --> HP:0002058
# neuropathic --> HP:0002821
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# nuclear cl --> HP:0100018
# fiber type grouping --> HP:0033685
# progressive balance disturbance --> HP:0003676
# hopping --> HP:5200134
# reduced vibration sensation --> HP:0000217
# supranuclear vertical gaze paresis --> HP:0000511
# right internuclear ophthalmoparesis --> HP:0000597
# chronic denervation in distal muscles --> HP:0011010
# had worsened --> HP:0025286
# denervation --> HP:0009109
# hypotonia --> HP:0001252
# developmental delay --> HP:0001263
# hepatopathy --> HP:0001410
# increased cerebrospinal fluid lactate --> HP:0002490
# seizures --> HP:0001250
# micronodular cirrhosis --> HP:0001413
# bile ductular proliferation --> HP:0001408
# nasogastric feeding --> HP:0040288
# psychomotor regression --> HP:0002376
# hepatopathy --> HP:0001410
# acute liver failure --> HP:0006554
# elevated csf protein --> HP:6000205
# abnormal eeg --> HP:0010846
# polyspike discharges --> HP:0025644
# bradykinesia --> HP:0002067
# cognitive impairment --> HP:0100543
# executive dysfunction --> HP:0100639
# language domain impairment --> HP:0002463
# moderate --> HP:0012826
# atrophy --> HP:0000029
# bilateral striatal dopamine deficiency --> HP:0012832
# ragged red fibres --> HP:0003200
# multiple mtdna deletions --> HP:0003689
# fatigue --> HP:0012378
# bilateral eyelid drooping --> HP:0001488
# numbness in both feet --> HP:0033748
# left - sided ptosis --> HP:0000508
# complete ophthalmoplegia --> HP:0007824
# proximal muscle weakness --> HP:0003701
# parkinsonian --> HP:0001300
# rigidity --> HP:0002063
# tremor --> HP:0001337
# bradykinesia --> HP:0002067
# difficulty performing fine motor tasks --> HP:0000019
# cognitive impairment --> HP:0100543
# increasing dysphagia --> HP:0002015
# dysarthria --> HP:0001260
# dysphonia --> HP:0001618
# proximal myopathy --> HP:0003198
# sensorimotor neuropathy --> HP:0007141
# dysphagia --> HP:0002015
# peg tube --> HP:0011471
# recurrent aspiration --> HP:0002100
# pneumonia --> HP:0002090
# sensory - ataxic neuropathy --> HP:0003434
# ophthalmoplegia --> HP:0000602
# dysarthria --> HP:0001260
# gastroparesis --> HP:0002578
# epileptic event --> HP:0033346
# severe epilepsy --> HP:0001250
# insect bite --> HP:0410339
# secondarily generalized focal crisis --> HP:0012837
# hypertonia --> HP:0001276
# myoclonus --> HP:0001336
# secondarily generalized focal crisis --> HP:0012837
# motor deterioration --> HP:0002333
# increase of the subarachnoid space --> HP:0012704
# atrophy --> HP:0000029
# motor focal seizures --> HP:0032665
# upper extremity myoclonus --> HP:0001336
# encephalopathy --> HP:0001298
# inexpressive facies --> HP:0000274
# facial hypomimia --> HP:0000338
# axial hypotonia --> HP:0008936
# hypo / areflexia --> HP:0001284
# distal limb increased tone --> HP:0012839
# right tetraparesis --> HP:0002273
# drooling --> HP:0002307
# frequent paroxysmal outbreaks of highvoltage delta waves --> HP:0040282
# deep cerebral folate deficiency 3 nmol / l ( --> HP:0012446
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged red fibres --> HP:0003200
# atrophy --> HP:0000029
# peo --> HP:0000544
# bilateral ptosis --> HP:0001488
# dysarthria --> HP:0001260
# ataxia --> HP:0001251
# neuropathy --> HP:0009830
# T2 hyperintensity of basal ganglia --> HP:0007183
# dysphagia --> HP:0002015
# aspiration pneumonia --> HP:0011951
# bilateral hand contractures --> HP:0012832
# failure to thrive --> HP:0001508
# depression --> HP:0000716
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# external ophthalmoplegia --> HP:0000544
# saccadic pursuit --> HP:0001152
# dysarthria --> HP:0001260
# bilateral dysdiadochokinesis --> HP:0002075
# dysmetria --> HP:0001310
# poor --> HP:0004396
# heel - toe walking --> HP:0030051
# tremor --> HP:0001337
# myoclonic --> HP:0033054
# choreic --> HP:0002072
# peripheral neuropathy --> HP:0009830
# electronegative erg --> HP:0007984
# generalized rod on - bipolar dysfunction --> HP:0012837
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# generalized epilepsy --> HP:0001250
# acute liver failure --> HP:0006554
# migraines --> HP:0002076
# epilepsia partialis continua --> HP:0012847
# myoclonic arm jerks --> HP:0001336
# progressive cognitive impairment --> HP:0003676
# intractable epilepsy --> HP:0001250
# liver disease --> HP:0006557
# respiratory chain defect --> HP:0200125
# parkinsonism --> HP:0001300
# sensory ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoparesis --> HP:0000597
# T2 hyperintensity of thalamus --> HP:0012692
# headaches --> HP:0002315
# aphasia --> HP:0002381
# visual aura --> HP:0011165
# homonymous right - sided visual field defect --> HP:0001123
# lesion --> HP:0000700
# leigh ' s encephalopathy --> HP:0001298
# bilateral ptosis --> HP:0001488
# severe external ophthalmoplegia --> HP:0000544
# parkinsonism --> HP:0001300
# peo --> HP:0000544
# ptosis --> HP:0000508
# focal slowing --> HP:0030650
# status epilepticus --> HP:0002133
# delayed fine motor skills --> HP:0002194
# atrophy --> HP:0000029
# ovarian dysgenesis --> HP:0000138
# syncope --> HP:0001279
# seizure like episode --> HP:0001250
# atrophy --> HP:0000029
# action tremor --> HP:0002345
# stiffness --> HP:0030965
# parkinsonism --> HP:0001300
# numbness in her feet --> HP:0033748
# parkinsonism --> HP:0001300
# bradykinesia --> HP:0002067
# stooped posture --> HP:0025403
# rigidity --> HP:0002063
# peripheral neuropathy --> HP:0009830
# atrophy --> HP:0000029
# partial motor status epilepticus --> HP:0032662
# abnormal liver function tests --> HP:0200148
# focal area of restricted diffusion --> HP:0030650
# swelling --> HP:0030774
# encephalopathic --> HP:0001298
# focal status --> HP:0032663
# seizures --> HP:0001250
# enlarged mitochondria --> HP:0001427
# myopathy --> HP:0003198
# peo --> HP:0000544
# ptosis --> HP:0000508
# gait instability --> HP:0002317
# proximal arm weakness --> HP:0003701
# fiber size variability --> HP:0003557
# central nuclei --> HP:0003687
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# increased --> HP:0033373
# anxiety and obsessive disorder --> HP:0000739
# atrophy --> HP:0000029
# bilateral peo --> HP:0012832
# ptosis --> HP:0000508
# myopathic --> HP:0002058
# mitochondrial myopathy --> HP:0003737
# proximal and distal weakness in lower limbs --> HP:0012839
# sensory ataxia --> HP:0010871
# demyelinating sensorymotor neuropathy --> HP:0011402
# anxiety - mood disorders --> HP:0000739
# T2 hyperintensity --> HP:0031206
# dystonia --> HP:0001332
# myoclonus --> HP:0001336
# subsarcolemmal accumulation of abnormal mitochondria --> HP:0003548
# multiple mitochondrial dna ( mtdna ) deletions --> HP:0003689
# progressive sensory ataxic neuropathy --> HP:0003434
# ptosis --> HP:0000508
# dysarthria --> HP:0001260
# dysphagia --> HP:0002015
# external ophthalmoparesis --> HP:0000597
# ragged - red " fibres --> HP:0003200
# cytochrome oxidase - negative fibres --> HP:0003688
# cytochrome c oxidase --> HP:0003688
# ragged red fibers --> HP:0003200
# multiple mtdna deletions --> HP:0003689
# mtdna depletion --> HP:0003387
# palatal tremor --> HP:0010530
# early age of onset --> HP:0011152
# fatal --> HP:0006583
# hepatic failure --> HP:0001399
# global neurological deterioration --> HP:0001268
# high signal intensity within occipital and temporal lobes --> HP:0012824
# palatal tremor --> HP:0010530
# facial dyskinesia --> HP:0002310
# decreased complex iii activity --> HP:0011924
# multiple mtdna deletions --> HP:0003689
# dramatic weight loss --> HP:0001824
# gastroparesis --> HP:0002578
# ptosis --> HP:0000508
# ophthalmoplegia --> HP:0000602
# peripheral neuropathy --> HP:0009830
# sensory ataxia --> HP:0010871
# sensory - ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoplegia --> HP:0000602
# hypoxia --> HP:0012418
# ascites --> HP:0001541
# tachycardia --> HP:0001649
# intermittent fevers --> HP:0001954
# sepsis --> HP:0100806
# cirrhosis --> HP:0001394
# steatosis --> HP:0001397
# focal necrosis --> HP:0003338
# complex iii deficiency --> HP:0011924
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# decreased visual acuity --> HP:0007924
# speech disorder --> HP:0006977
# left side weakness --> HP:0012835
# progressive bilateral ptosis --> HP:0000590
# hearing loss --> HP:0000365
# difficulties in swallowing --> HP:0002015
# bilateral ptosis --> HP:0001488
# bilateral hearing loss --> HP:0008619
# myopathic pattern --> HP:0003458
# mild --> HP:0012825
# increase in cholesterol levels --> HP:0031211
# bilateral ptosis --> HP:0001488
# severe ophthalmoparesis --> HP:0000597
# hearing loss --> HP:0000365
# dysarthria --> HP:0001260
# left facial nerve palsy --> HP:0010628
# left side hemiparesis --> HP:0001269
# T2 hyperintensity --> HP:0031206
# lesion --> HP:0000700
# T2 hyperintensity --> HP:0031206
# lesion --> HP:0000700
# increased level of serum creatine kinase --> HP:0003236
# moderate --> HP:0012826
# sensorimotor bilateral hypoacusia --> HP:0012832
# myopathic --> HP:0002058
# bilateral ptosis --> HP:0001488
# lateral rectus palsies --> HP:0031751
# horizontal diplopia --> HP:0000651
# nasal, flaccid dysarthria --> HP:0001260
# facial weakness --> HP:0030319
# tongue weakness --> HP:0000183
# gliosis --> HP:0002171
# gliosis --> HP:0002171
# nucleus --> HP:0002339
# loss of the purkinje cells in the superior cerebellar vermis --> HP:0007001
# ptosis --> HP:0000508
# bilateral ptosis --> HP:0001488
# vertical and --> HP:0500074
# horizontal ophthalmoplegia --> HP:0030773
# bifacial weakness --> HP:0030319
# weakness in the proximal and distal upper --> HP:0012839
# lower --> HP:0000178
# left - sided intention tremor --> HP:0001337
# myopathy --> HP:0003198
# moderate fiber size --> HP:0012826
# atrophy --> HP:0000029
# increased internal nuclei --> HP:0008151
# fatty infiltration of skeletal muscle --> HP:0012548
# ragged red fibers --> HP:0003200
# fibers --> HP:0100305
# dehydrogenase --> HP:0002928
# reduced --> HP:0031851
# demyelination --> HP:0011096
# cataracts --> HP:0000518
# ovarian dysgenesis --> HP:0000138
# - onset --> HP:0003674
# distal muscle weakness --> HP:0002460
# microvesicular steatosis --> HP:0001414
# multiple mtdna deletions --> HP:0003689
# progressive cognitive deficits --> HP:0003676
# cognitive deficits --> HP:0100543
# epileptic seizures --> HP:0033052
# recurrent headaches --> HP:0002331
# mild --> HP:0012825
# personality changes --> HP:0000751
# movement disorder --> HP:0007153
# action - triggered myoclonus --> HP:0001336
# progressive cerebellar ataxia --> HP:0002073
# incomplete --> HP:0010861
# chronic progressive external ophthalmoplegia --> HP:0000544
# peo --> HP:0000544
# severe axonal sensorimotor neuropathy --> HP:0007141
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged red fibers --> HP:0003200
# lower limb --> HP:0007210
# dystonia --> HP:0001332
# peripheral neuropathy --> HP:0009830
# dystonia --> HP:0001332
# accumulation of lipids --> HP:0034787
# complete horizontal gaze palsy --> HP:0000511
# severe ataxia --> HP:0001251
# reflexes were absent --> HP:0001284
# choreoathetotic --> HP:0001266
# loss of proprioception --> HP:0010831
# somnolent --> HP:0005335
# loss of extraocular movement --> HP:0000597
# spasticity --> HP:0001257
# hyperreflexia --> HP:0001347
# genu of the corpus callosum --> HP:0006989
# genu of the right internal capsule --> HP:0012834
# bilateral cerebellar hemispheres --> HP:0012832
# bilateral cerebellar peduncles --> HP:0012832
# hemorrhage --> HP:0002239
# putamen --> HP:0031982
# elevated lactate level --> HP:0012707
# elevated choline level in --> HP:0012706
# basal ganglia --> HP:0012697
# foamy histiocytes --> HP:0003651
# cells --> HP:0001404
# loss of myelin --> HP:0003380
# glial fibrillary acidic protein --> HP:0032650
# adult - onset --> HP:0003581
# progressive external ophthalmoplegia --> HP:0000590
# peo --> HP:0000544
# progressive encephalopathy --> HP:0002448
# cytochrome c oxidase-deficient muscle fibers --> HP:0003688
# ragged - red fibres --> HP:0003200
# coagulopathy --> HP:0003256
# elevated liver enzymes --> HP:0002910
# seizures --> HP:0001250
# hepatic failure --> HP:0001399
# hand tremor --> HP:0002378
# hand tremor --> HP:0002378
# slurred speech --> HP:0001350
# oligoclonal bands in cerebrospinal fluid --> HP:6000397
# epilepsy --> HP:0001250
# electromyography was myopathic --> HP:0002058
# myopathic --> HP:0002058
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# increased brain lactate on magnetic resonance spectroscopy --> HP:0001900
# microvesicular --> HP:0001414
# cholestasis --> HP:0001396
# chronic myopathy --> HP:0009071
# severe sensory neuropathy --> HP:0000763
# hypogonadism --> HP:0000135
# hypothyroidism --> HP:0000821
# osteopenia --> HP:0000938
# ragged - red fibers --> HP:0003200
# variation in skeletal muscle fiber size --> HP:0003557
# increased central nuclei in skeletal muscle fibers --> HP:0003687
# reduced --> HP:0031851
# mtdna depletion --> HP:0003387
# hypomimia --> HP:0000338
# bilateral bradykinesia --> HP:0002067
# right - sided resting tremor --> HP:0001337
# focal convulsions --> HP:0030650
# convulsions --> HP:0002069
# aphasia --> HP:0002381
# focal occipital epileptic discharges --> HP:0030650
# irregular menstrual cycles --> HP:0000858
# portal tracts were enlarged --> HP:0000040
# bile plugs --> HP:0034294
# decreased sensory and motor nerve conduct velocity --> HP:0003448
# progressive proximal limb weakness --> HP:0003676
# asymmetric ptosis --> HP:0000508
# atrophy --> HP:0000029
# pectus excavatum ( --> HP:0000767
# atrophy --> HP:0000029
# ragged red fibers --> HP:0003200
# mitochondrial myopathy --> HP:0003737
# multiple mtdna deletions --> HP:0003689
# extra - pyramidal rigidity --> HP:0002063
# postural instability --> HP:0002172
# hypomimic face --> HP:0000338
# hypophonia --> HP:0001621
# bilateral ptosis --> HP:0001488
# ophthalmoplegia --> HP:0000602
# proximal muscle weak - ness --> HP:0003701
# oligomenorrhea --> HP:0000876
# subsarcolemmal accumulation of mitochondria --> HP:0003548
#
#  Unmapped Mentions (142):
# reduction of activities of complex i and iv
# lower extremities were diffusely thin
# / 5 at tibialis anterior
# percutaneous endoscopic gastrostomy
# ventilatory failure
# refractory partial seizures
# hypersignals in thalami
# lactate doublet peak
# absence of sensory response in both arms and legs
# neurogenic motor units
# spongiform changes in the cerebrum
# brainstem bleeding
# multiple lacunar ischaemic cortical infarcts
# dystonic ulnar deviation
# degeneration of dorsal root ganglia
# glycaemia
# non - syndromic ovarian dysfunction
# content of mtdna was slightly reduced in muscle
# alpers syndrome
# right - sided focal motor seizures
# mental status deteriorated
# ##et alpers
# upper limb mixed rest and
# percutaneous gastrostomy tube
# died
# baseline lactate was high
# radiculopathy
# trouble walking heel - to - toe
# pinprick sensation ( reduced to the mid - calves
# reduced sensory amplitudes
# refractory mixed type seizures
# high amplitude slow wave activity
# liver enzymatic respiratory chain defects
# complex iv showed a decreased activity
# mild apraxia
# enlargement of the ventricles
# infectious process
# igm antiborrellia titers were high
# high blood lactate value
# pale eye fundus
# motor disturbances
# lost deambulation
# difficulties in handling objects
# electroencephalogram disclosed spontaneously slow and poorly organized trace
# right predominance activated during sleep
# myofibers were abnormally small
# subsarcolemmal collections of mitochondria
# T2 hyperintensity of cortical gray matter
# fed through a
# g - tube
# wheelchair dependence
# selective rod on - bipolar cell dysfunction
# writhing tongue movements
# laterocollis
# dystonic posturing
# striatal toes
# sando
# long - standing learning difficulties
# pancerebellar syndrome
# sando syndrome
# sando
# parieto - occipital region
# inferior colliculi
# epileptic spikes
# vision problems
# bilateral cataracts
# inability to use both of her hands
# absent menarche
# T2 hyperintensity of inferior olivary nucleus
# dystonic toe curling
# facial masking
# sensorimotor, predominantly sensory
# continuous paroxysmal lateralizing epileptiform discharges
# mitochondria with tubular cristae formations
# alpers syndrome
# near falls
# ragged red
# ragged blue fibers
# abnormally swollen mitochondria and paracrystalline inclusions
# cytochrome - c - oxidase ( cytochrome c oxidase - ) activity was deficient
# cognition was mildly affected
# creatine kinase levels were 217 u / l
# myoglobin was 360 u / l
# ragged blue fibers
# dystonic ulnar deviation
# polymini - myoclonus
# cytochrome c oxidase-deficient muscle fibers fibers
# inferior olivary nuclei
# decreased dopamine transporter level
# alpers syndrome
# intractable seizures
# severely cytochrome oxidase - deficient muscle
# deficiencies in all etc complexes
# mild dysphagia
# power was reduced in both deltoid muscles
# loss of pigmented neurons in the substantia nigra
# ventrolateral posterior nuclei of the thalamus
# electromyography
# ##illation potentials
# ragged blue fibers
# absent cytochrome c oxidase ( cytochrome c oxidase ) activity
# cerebral cortex showing activated astrocytes
# dystonic ulnar deviation
# wheel - chair bound
# hepat
# mitochondria were enlarged
# irregular cristae of a tubular
# T2 prolongation
# frontoparietal subcortical white matter
# anterior thalamus
# thalamus
# showed an
# depressed n - acetylaspartate level
# gliotic white matter
# reactive astrocytes
# active demyelinating process
# died
# abnormalities in thalamus and basal ganglia
# alpers syndrome
# sando
# increased vanillate level
# myelin basic protein level was higher than 1000 ng / ml
# serum lactate level was slightly high
# eeg showed sharp and slow wave focus in the right posterior quadrant
# serum ck level was 1. 5 normal
# fat deposition was prominent in superficial muscles
# ##ar
# dysm
# absent reactivity to cytochrome c oxidase
# alpers syndrome
# forced anteroflexion of
# reduced cytochrome c oxidase activity
# post - ) ictal paresis
# bilirubinostasis
# proliferation of bile ductules
# brainstem auditory evoked potential showed increased i - iii latency
# continuous 2 hz polyspike - and - slow waves
# funnel breast
# deficient in the mtdna - encoded cytochrome c oxidase ( cytochrome c oxidase
# cogwheel sign
# mitochondria with abnormal concentric cristae
# depletion of mtdna

# %%
import re
import json
from pathlib import Path
from typing import Optional
from functools import lru_cache
import unicodedata  

import requests
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry

from transformers import AutoTokenizer, AutoModelForTokenClassification, pipeline
import obonet
from rapidfuzz import process
from rapidfuzz.fuzz import token_set_ratio 

# === Config ===
MODEL_DIR = "/kaggle/input/ner-pubmedbert-saved-hpo/ner_pubmedbert_saved_HPO"
TEST_FILE = Path("/kaggle/working/bio_outputs/test.jsonl")
OUT_FILE  = Path("/kaggle/working/bio_outputs/mapped_mentions.jsonl")
MAX_LENGTH = 512  
DEVICE = 0  # use -1 for CPU


MONARCH_BASE = "https://api-v3.monarchinitiative.org/v3/api"
CT_HPO_SEARCH = "https://clinicaltables.nlm.nih.gov/api/hpo/v3/search"


FUZZY_CUTOFF = 85


SIM_THRESH = 50


def clean_text(m: str) -> str:
    if not m:
        return m
    m = unicodedata.normalize("NFKC", m)
    m = m.replace("–", "-").replace("—", "-")
    m = m.translate(str.maketrans({
        "“": '"', "”": '"', "„": '"', "‟": '"',
        "’": "'", "‘": "'", "‚": "'", "‛": "'"
    }))
    m = re.sub(r"\s+", " ", m).strip()
    return m

_ABBR_PATTERNS = [
    (re.compile(r"\brrf\b", flags=re.I), "ragged red fibers"),
    (re.compile(r"\bragged[-\s]?red\b", flags=re.I), "ragged red"),
    (re.compile(r"\bcox\b", flags=re.I), "cytochrome c oxidase"),
    (re.compile(r"\bsdh\b", flags=re.I), "succinate dehydrogenase"),
    (re.compile(r"\bg[-\s]?tube\b", flags=re.I), "gastrostomy tube"),
]
def expand_abbrev(m: str) -> str:
    t = m
    for pat, rep in _ABBR_PATTERNS:
        t = pat.sub(rep, t)
    return t


_CANON_SUBS = [
    (re.compile(r"\bdysphasia\b", re.I), "aphasia"),
    (re.compile(r"\bwheel[-\s]?chair\s*bound\b", re.I), "wheelchair dependence"),
    (re.compile(r"\bfailing\s+to\s+thrive\b", re.I), "failure to thrive"),
    (re.compile(r"\bsyncopal\s+episode\b", re.I), "syncope"),
    (re.compile(r"\blumbosacral\s+radiculopathy\b", re.I), "radiculopathy"),
    (re.compile(r"\bragged\s+blue\b(?!\s*fib)", re.I), "ragged blue fibers"),

    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*negative", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"cytochrome\s+c\s+oxidase\s*[-–—]?\s*deficien\w*", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b.*\b(csfs?|cerebrospinal\s+fluid)\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bjerky\s+\w+(\s+and\s+\w+)?\s+movements\b", re.I), "myoclonus"),
    (re.compile(r"\bcomplete\s+absence\s+of\s+proprioceptive\s+sensation\b", re.I),
     "loss of proprioception"),


    (re.compile(r"\bpolymini\W*myoclonus\b", re.I), "polyminimyoclonus"),
    (re.compile(r"\bdystonic\s+toe\s+curling\b", re.I), "dystonia of toes"),
    (re.compile(r"\bstriatal\s+toes?\b", re.I), "striatal toe"),
    (re.compile(r"\blaterocollis\b", re.I), "laterocollis"),
    (re.compile(r"\bnear\s+falls?\b", re.I), "recurrent falls"),
    (re.compile(r"\bdifficulties\s+in\s+handling\s+objects\b", re.I), "apraxia"),
]
def canonicalize_synonyms(m: str) -> str:
    s = m
    for pat, rep in _CANON_SUBS:
        s = pat.sub(rep, s)
    return s

_MRC = re.compile(r"\b\d+\s*/\s*\d+\b")  # e.g., 5/5, 0/5
_STOPWORDS = {"in", "at", "of", "was", "to", "is", "are", "be", "the", "and"}


_BAD_START = re.compile(r"^##")
_BAD_FRAGMENTS = [
    re.compile(r"\bfed\s+through\s+a\b", re.I),
    re.compile(r"\bshowed\s+an\b", re.I),
    re.compile(r"^\s*(hepat|dysm|##ar|##et)\b", re.I),
]
def is_noise(m: str) -> bool:
    if not m:
        return True
    m_strip = m.strip()
    if _BAD_START.search(m_strip):
        return True
    for pat in _BAD_FRAGMENTS:
        if pat.search(m_strip):
            return True
    alpha = sum(c.isalpha() for c in m_strip)
    if alpha < 2 or len(m_strip) < 3:
        return True
    if _MRC.search(m_strip):
        return True
    toks = re.findall(r"[a-z]+", m_strip.lower())
    if toks and all(t in _STOPWORDS for t in toks):
        return True
    return False


_PHENOTYPE_HINTS = {
    "weakness","atrophy","pain","tremor","paralysis","dystonia","rigidity",
    "contracture","spasm","edema","hyperintensity","hypointensity","lesion",
    "defect","deficiency","deficient","absence","loss","dysphagia","apraxia",
    "seizure","myoclonus","dysarthria","ataxia","paresis","dysesthesia",
    "fibers","fibres","ragged","ragged-red","cox-negative","sdh-positive",
    "aphasia","syncope","radiculopathy","gliosis","proprioception","wheelchair"
}
def looks_like_phenotype(m: str) -> bool:
    toks = set(re.findall(r"[a-z]+", m.lower()))
    return bool(toks & _PHENOTYPE_HINTS)


_REGION_PATTERNS = [
    (re.compile(r"\bcortical\s+gr[ae]y(?:\s+matter)?\b", re.I), "cortical gray matter"),
    (re.compile(r"\bsubcortical\s+white\s+matter\b", re.I), "subcortical white matter"),
    (re.compile(r"\bbasal\s+ganglia\b", re.I), "basal ganglia"),
    (re.compile(r"\bthalam(?:us|i)\b", re.I), "thalamus"),
    (re.compile(r"\bparieto[-\s]?occipital\b", re.I), "parieto-occipital region"),
    (re.compile(r"\bfrontoparietal\s+subcortical\s+white\s+matter\b", re.I), "frontoparietal subcortical white matter"),
    (re.compile(r"\bpre[-\s]?rolandic\b", re.I), "pre-rolandic cortex"),
    (re.compile(r"\binferior\s+olivary\s+nucleus\b", re.I), "inferior olivary nucleus"),
]

_FINDING_PATTERNS = [
    (re.compile(r"\bt2\s*[- ]?\s*hyperintens\w*\b", re.I), "T2 hyperintensity"),
    (re.compile(r"\bhypersignal(s)?\b", re.I), "T2 hyperintensity"),  # 新增：支持 hypersignal(s)
    (re.compile(r"\bhyperintens\w*\b", re.I), "T2 hyperintensity"),  # 默认归一到 T2 hyperintensity
    (re.compile(r"\bhemorrhag\w*\b", re.I), "hemorrhage"),
    (re.compile(r"\bswell\w*\b", re.I), "swelling"),
    (re.compile(r"\batroph\w*\b", re.I), "atrophy"),
    (re.compile(r"\bglios\w*\b", re.I), "gliosis"),
    (re.compile(r"\blesion\w*\b", re.I), "lesion"),
    (re.compile(r"\bprolongation\b", re.I), "T2 prolongation"),
    (re.compile(r"\bhypointens\w*\b", re.I), "T2 hypointensity"),
]


_PATHO_TEMPLATES = [
    (re.compile(r"\bcytochrome\s+c\s+oxidase\b.*\bnegative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?negative\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-negative muscle fibers"),
    (re.compile(r"\bcox[-\s]?deficien\w*\b.*\bfib(er|re)s\b", re.I),
     "cytochrome c oxidase-deficient muscle fibers"),
    (re.compile(r"\bragged\s+blue\b.*\bfib(er|re)s\b", re.I),
     "ragged blue fibers"),
    (re.compile(r"\boligoclonal\s+bands?\b", re.I),
     "oligoclonal bands in cerebrospinal fluid"),
    (re.compile(r"\bvariation\s+of\s+fiber\s+calib(er|re)\b", re.I),
     "variation in skeletal muscle fiber size"),
    (re.compile(r"\bnuclear\s+centralization\b", re.I),
     "increased central nuclei in skeletal muscle fibers"),
    (re.compile(r"\bfatty\s+replacement\b.*\bendomysial\b", re.I),
     "fatty infiltration of skeletal muscle"),


    (re.compile(r"\bparacrystalline\s+inclusion\w*\b", re.I),
     "mitochondrial paracrystalline inclusions"),
    (re.compile(r"\bswollen\s+mitochondria\b|\babnormally\s+swollen\s+mitochondria\b", re.I),
     "swollen mitochondria"),
    (re.compile(r"\b(concentric|tubular|irregular)\s+cristae\b", re.I),
     "abnormal mitochondrial cristae morphology"),
    (re.compile(r"\b(poly)?spike\s*-\s*(and\s*-\s*)?slow\s*waves?\b", re.I),
     "EEG with epileptiform discharges"),
    (re.compile(r"\bsharp\s+and\s+slow\s+wave(s)?\b", re.I),
     "EEG with epileptiform discharges"),
]

def rewrite_imaging_pathology(m: str) -> Optional[str]:
    s = m

    for pat, rep in _PATHO_TEMPLATES:
        if pat.search(s):
            return rep

    found_region = None
    for pat, norm in _REGION_PATTERNS:
        if pat.search(s):
            found_region = norm
            break

    found_finding = None
    for pat, norm in _FINDING_PATTERNS:
        if pat.search(s):
            found_finding = norm
            break

    if found_finding and found_region:
        return f"{found_finding} of {found_region}"
    if found_finding:
        return found_finding
    return None


def rewrite_numeric_to_qualitative(m: str) -> Optional[str]:
    s = m.lower()


    if re.search(r"\b(vitamin\s*b12|b\s*12)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating vitamin B12"


    if re.search(r"\b(25[-\s]?hydroxyvitamin\s*d|25ohd|25\W*oh\W*d)\b", s) and re.search(r"\b(low|decreas\w*|deficien\w*)\b", s):
        return "decreased circulating 25-hydroxyvitamin D"


    if re.search(r"\b(csfs?|cerebrospinal\s+fluid)\b.*\blactate\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased cerebrospinal fluid lactate"


    if re.search(r"\blactate\b.*\b(spectroscop\w*|mrs)\b", s):
        return "increased brain lactate on magnetic resonance spectroscopy"


    if re.search(r"\b(serum\s+)?ck\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high|above\s+normal|x\s*normal)\b", s) or re.search(r"\b\d+(\.\d+)?\s*x\s*normal\b", s):
            return "elevated serum creatine kinase"


    if re.search(r"\bmyoglobin\b", s) and (re.search(r"\blevel\b", s) or re.search(r"\d", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
            return "elevated myoglobin"

    if re.search(r"\b(pyruvate)\b", s) and (re.search(r"\b(blood|serum)\b", s) or re.search(r"\b\du?mol\b", s)):
        if re.search(r"\b(increas\w*|elevat\w*|high)\b", s) or re.search(r"\d", s):
            return "increased blood pyruvate"

    if re.search(r"\bvanillat\w*\b", s) and re.search(r"\b(increas\w*|elevat\w*|high)\b", s):
        return "increased vanillate level"


    if re.search(r"\bdopamine\s+transporter\b", s) and re.search(r"\b(reduc\w*|decreas\w*|low)\b", s):
        return "decreased dopamine transporter level"


    if re.search(r"\blogmar\b", s):
        return "decreased visual acuity"


    if re.search(r"\bketonuria\b", s):
        return "ketonuria"


    if re.search(r"\bvisual\s+disturbance(s)?\b", s):
        return "visual impairment"

    return None

def apply_templates(m: str) -> str:
    img = rewrite_imaging_pathology(m)
    if img:
        return img
    numq = rewrite_numeric_to_qualitative(m)
    if numq:
        return numq
    return m

def dedup_adjacent_words(s: str) -> str:
    return re.sub(r'\b(\w+)(\s+\1\b)+', r'\1', s, flags=re.I)

# === HTTP session with retries ===
def make_session() -> requests.Session:
    s = requests.Session()
    retries = Retry(
        total=3,
        backoff_factor=0.3,
        status_forcelist=(429, 500, 502, 503, 504),
        allowed_methods=frozenset(["GET"])
    )
    s.mount("https://", HTTPAdapter(max_retries=retries))
    s.mount("http://", HTTPAdapter(max_retries=retries))
    return s

SESSION = make_session()

# === Step 1: Load test data ===
print(">> Loading test data")
test_data = [json.loads(line) for line in TEST_FILE.open(encoding="utf-8")]
orig_sentences = [ex["text"] for ex in test_data]

# === Step 2: Load model and tokenizer with pipeline ===
print(">> Loading model and tokenizer")
tokenizer = AutoTokenizer.from_pretrained(MODEL_DIR, use_fast=True, local_files_only=True)
model = AutoModelForTokenClassification.from_pretrained(MODEL_DIR, local_files_only=True)

ner_pipeline = pipeline(
    "ner",
    model=model,
    tokenizer=tokenizer,
    aggregation_strategy="simple",
    device=DEVICE
)

# === Step 3: Load HPO terms from hp.obo
print(">> Loading HPO terms from obo")
obo_url = "http://purl.obolibrary.org/obo/hp.obo"
try:
    graph = obonet.read_obo(obo_url)
except Exception as e:
    print(f">> Failed to fetch hp.obo (will still try online normalization): {e}")
    graph = None

hpo_map = {}
if graph is not None:
    for node_id, data in graph.nodes(data=True):
        name = data.get("name")
        if name:
            hpo_map.setdefault(name.lower(), []).append(node_id)
        for syn in data.get("synonym", []):
            m = re.search(r'"(.+?)"', syn)
            if m:
                hpo_map.setdefault(m.group(1).lower(), []).append(node_id)
hpo_keys = list(hpo_map.keys())

# === Online normalizers (Monarch v3 -> ClinicalTables) ===
@lru_cache(maxsize=10000)
def normalize_via_monarch(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    params = {"q": q, "category": "biolink:PhenotypicFeature", "limit": 5}
    try:
        r = SESSION.get(f"{MONARCH_BASE}/autocomplete", params=params, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        items = data.get("items") or data.get("results") or data
        if not isinstance(items, list):
            return None
        best_curie, best_score = None, -1
        for it in items:
            curie = it.get("id") or it.get("curie")
            label = (it.get("label") or it.get("name") or "").strip()
            cats  = it.get("category") or it.get("categories") or []
            if isinstance(cats, str):
                cats = [cats]
            if curie and str(curie).startswith("HP:"):
                if not cats or any("PhenotypicFeature" in c for c in cats):
                    score = token_set_ratio(q.lower(), label.lower()) if label else 0
                    if score > best_score:
                        best_score, best_curie = score, curie
        return best_curie if best_score >= SIM_THRESH else None
    except Exception:
        return None

@lru_cache(maxsize=10000)
def normalize_via_ct(text: str) -> Optional[str]:
    q = text.strip()
    if not q:
        return None
    try:
        r = SESSION.get(CT_HPO_SEARCH, params={"terms": q, "maxList": 10}, timeout=6)
        if r.status_code != 200:
            return None
        data = r.json()
        if isinstance(data, list) and len(data) >= 2:
            ids, names = data[0], data[1]
            best_id, best_score = None, -1
            for hp_id, name in zip(ids, names):
                if isinstance(hp_id, str) and hp_id.startswith("HP:"):
                    score = token_set_ratio(q.lower(), (name or "").lower())
                    if score > best_score:
                        best_score, best_id = score, hp_id
            return best_id if best_score >= SIM_THRESH else None
    except Exception:
        return None
    return None

def normalize_mention(text: str):
    curie = normalize_via_monarch(text)
    if curie:
        return curie
    curie = normalize_via_ct(text)
    if curie:
        return curie
    key = text.lower().strip()
    if key in hpo_map:
        score = token_set_ratio(key, key)
        return hpo_map[key][0] if score >= SIM_THRESH else None
    match = process.extractOne(key, hpo_keys, score_cutoff=FUZZY_CUTOFF) if hpo_keys else None
    if match:
        matched_term = match[0]
        score = token_set_ratio(key, matched_term)
        if score >= SIM_THRESH:
            return hpo_map[matched_term][0]
    return None

print(">> Running NER and normalization")
mapped_mentions = []
unmapped_mentions = []
normalized_mentions = []

for idx, sentence in enumerate(orig_sentences):
    results = ner_pipeline(sentence)
    for ent in results:
        if ent["entity_group"] != "HPO_TERM":
            continue
        mention = ent["word"].strip()

        mention = clean_text(mention)
        mention = expand_abbrev(mention)
        mention = canonicalize_synonyms(mention)
        mention = apply_templates(mention)
        mention = dedup_adjacent_words(mention)
        if is_noise(mention):
            continue
        # if not looks_like_phenotype(mention):
        #     continue

        hpo_id = normalize_mention(mention)
        (mapped_mentions if hpo_id else unmapped_mentions).append((mention, hpo_id))
        normalized_mentions.append({
            "sentence_id": idx,
            "mention": mention,
            "hpo_id": hpo_id
        })

total  = len(normalized_mentions)
mapped = sum(1 for r in normalized_mentions if r["hpo_id"] is not None)
print(f"\nTotal mentions:  {total}")
print(f"Mapped to HP ID: {mapped} ({mapped/total:.1%})" if total else "Mapped to HP ID: 0 (n/a)")
print(f"Failed to map:   {total - mapped} ({(total - mapped)/total:.1%})" if total else "Failed to map: 0 (n/a)")

OUT_FILE.parent.mkdir(parents=True, exist_ok=True)
with OUT_FILE.open("w", encoding="utf-8") as fout:
    for rec in normalized_mentions:
        fout.write(json.dumps(rec, ensure_ascii=False) + "\n")

print(f"\n Mapped Mentions ({len(mapped_mentions)}):")
for mention, hpo_id in mapped_mentions:
    print(f"{mention} --> {hpo_id}")

print(f"\n Unmapped Mentions ({len(unmapped_mentions)}):")
for mention, _ in unmapped_mentions:
    print(mention)
# Out:
# Device set to use cuda:0
# >> Loading test data
# >> Loading model and tokenizer
# >> Loading HPO terms from obo
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# >> Running NER and normalization
#
# Total mentions:  631
# Mapped to HP ID: 556 (88.1%)
# Failed to map:   75 (11.9%)
#
#  Mapped Mentions (556):
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# absent reflexes in upper extremities --> HP:0001284
# polyneuropathy --> HP:0001271
# neuropathic pain --> HP:6000040
# ragged - red fibers --> HP:0003200
# dyskinesia --> HP:0100660
# severe stand - ing tremor --> HP:0001337
# dysphagia --> HP:0002015
# loss of weight --> HP:0001824
# malnutrition --> HP:0004395
# ventilatory failure --> HP:0000198
# mechanical ventilation --> HP:0004887
# elevated serum creatine kinase --> HP:0008180
# increased blood pyruvate --> HP:0003542
# decreased circulating vitamin B12 --> HP:0100502
# T2 hyperintensity --> HP:0031206
# cerebellar white matter --> HP:0007033
# atrophy --> HP:0000029
# neurological deterioration --> HP:0002344
# tetraparesis --> HP:0002273
# hypotonia --> HP:0001252
# cognitive impairment --> HP:0100543
# multifocal myoclonus --> HP:0040148
# T2 hyperintensity --> HP:0031206
# bilateral cerebellum --> HP:0012832
# frontal cortex --> HP:0031421
# bilateral parietal cortex --> HP:0012832
# T2 hyperintensity of thalamus --> HP:0012692
# lactate doublet peak --> HP:0000349
# elevated lactate concentration --> HP:0002151
# partial status epilepticus --> HP:0032662
# progressive cognitive dysfunction --> HP:0003676
# psychotic features --> HP:0000725
# progressive external ophthalmoplegia --> HP:0000590
# resting tremor --> HP:0002322
# myoclonic jerks --> HP:0007000
# bilateral foot drop --> HP:0009027
# neurogenic motor units --> HP:0001270
# atrophy --> HP:0000029
# white matter spongiosis of the cerebellum --> HP:6001166
# brainstem bleeding --> HP:0000132
# multiple lacunar ischaemic cortical infarcts --> HP:0000191
# mtdna depletion --> HP:0003387
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# dystonic ulnar deviation --> HP:0000497
# intermittent facial and jaw opening dystonia --> HP:0001332
# postural instability --> HP:0002172
# trunk ataxia --> HP:0002078
# severe dysarthria --> HP:0001260
# incomplete horizontal and vertical external ophthalmoplegia --> HP:0000544
# ataxia --> HP:0001251
# stand assisted --> HP:0004887
# sensory ataxic neuropathy --> HP:0003434
# cerebellar --> HP:0001251
# weakness --> HP:0031108
# visual impairment --> HP:0000505
# diplopia --> HP:0000651
# dysarthria --> HP:0001260
# aphasia --> HP:0002381
# multiple deletions of mitochondrial dna --> HP:0003689
# dorsal spinocerebellar tract degeneration --> HP:0002503
# nucleus --> HP:0002339
# sensory peripheral neuropathy --> HP:0007067
# neuronal loss --> HP:0200147
# gliosis --> HP:0002171
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged - red " fibres --> HP:0003200
# 3 - methylglutaconic acid --> HP:0003535
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# myopathic --> HP:0002058
# muscles --> HP:0000211
# axonal neuropathy --> HP:0007002
# increased blood pyruvate --> HP:0003542
# atrophy --> HP:0000029
# hypoketotic hypoglycaemia --> HP:0001985
# lethargy --> HP:0001254
# ketonuria --> HP:0002919
# non - syndromic ovarian dysfunction --> HP:0000137
# increased cerebrospinal fluid lactate --> HP:0002490
# epilepsia partialis continua --> HP:0012847
# right - sided hemiparesis --> HP:0001269
# mental status deteriorated --> HP:0001249
# disoriented --> HP:0025237
# aphasia --> HP:0002381
# acalculia --> HP:0002442
# lesion --> HP:0000700
# leftsided pulvinar thalamic abnormalities --> HP:0000078
# syndrome --> HP:0000012
# tremor --> HP:0001337
# hyperglycemia --> HP:0003074
# progressively blurred vision --> HP:0000622
# diplopia --> HP:0000651
# bilateral ptosis --> HP:0001488
# choking episodes --> HP:0030842
# fatigue --> HP:0012378
# shortness of breath --> HP:0002094
# serum creatine kinase was mildly elevated --> HP:0003236
# baseline lactate was high --> HP:0000218
# axonal, and sensory polyneuropathy --> HP:0007131
# myopathic --> HP:0002058
# neuropathic --> HP:0002821
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# nuclear cl --> HP:0100018
# fiber type grouping --> HP:0033685
# progressive balance disturbance --> HP:0003676
# hopping --> HP:5200134
# reduced vibration sensation --> HP:0000217
# supranuclear vertical gaze paresis --> HP:0000511
# right internuclear ophthalmoparesis --> HP:0000597
# reduced sensory amplitudes --> HP:0000654
# chronic denervation in distal muscles --> HP:0011010
# had worsened --> HP:0025286
# denervation --> HP:0009109
# hypotonia --> HP:0001252
# developmental delay --> HP:0001263
# hepatopathy --> HP:0001410
# increased cerebrospinal fluid lactate --> HP:0002490
# seizures --> HP:0001250
# micronodular cirrhosis --> HP:0001413
# bile ductular proliferation --> HP:0001408
# nasogastric feeding --> HP:0040288
# psychomotor regression --> HP:0002376
# hepatopathy --> HP:0001410
# acute liver failure --> HP:0006554
# elevated csf protein --> HP:6000205
# abnormal eeg --> HP:0010846
# high amplitude slow wave activity --> HP:0000218
# polyspike discharges --> HP:0025644
# liver enzymatic respiratory chain defects --> HP:0000078
# bradykinesia --> HP:0002067
# cognitive impairment --> HP:0100543
# executive dysfunction --> HP:0100639
# language domain impairment --> HP:0002463
# moderate --> HP:0012826
# enlargement of the ventricles --> HP:0001714
# atrophy --> HP:0000029
# bilateral striatal dopamine deficiency --> HP:0012832
# ragged red fibres --> HP:0003200
# multiple mtdna deletions --> HP:0003689
# fatigue --> HP:0012378
# bilateral eyelid drooping --> HP:0001488
# numbness in both feet --> HP:0033748
# left - sided ptosis --> HP:0000508
# complete ophthalmoplegia --> HP:0007824
# proximal muscle weakness --> HP:0003701
# parkinsonian --> HP:0001300
# rigidity --> HP:0002063
# tremor --> HP:0001337
# bradykinesia --> HP:0002067
# difficulty performing fine motor tasks --> HP:0000019
# cognitive impairment --> HP:0100543
# increasing dysphagia --> HP:0002015
# dysarthria --> HP:0001260
# dysphonia --> HP:0001618
# proximal myopathy --> HP:0003198
# sensorimotor neuropathy --> HP:0007141
# dysphagia --> HP:0002015
# peg tube --> HP:0011471
# recurrent aspiration --> HP:0002100
# pneumonia --> HP:0002090
# sensory - ataxic neuropathy --> HP:0003434
# ophthalmoplegia --> HP:0000602
# dysarthria --> HP:0001260
# gastroparesis --> HP:0002578
# epileptic event --> HP:0033346
# severe epilepsy --> HP:0001250
# infectious process --> HP:0000264
# igm antiborrellia titers were high --> HP:0000218
# insect bite --> HP:0410339
# secondarily generalized focal crisis --> HP:0012837
# hypertonia --> HP:0001276
# myoclonus --> HP:0001336
# secondarily generalized focal crisis --> HP:0012837
# motor deterioration --> HP:0002333
# high blood lactate value --> HP:0000218
# increase of the subarachnoid space --> HP:0012704
# atrophy --> HP:0000029
# pale eye fundus --> HP:0000286
# motor focal seizures --> HP:0032665
# upper extremity myoclonus --> HP:0001336
# encephalopathy --> HP:0001298
# inexpressive facies --> HP:0000274
# facial hypomimia --> HP:0000338
# axial hypotonia --> HP:0008936
# hypo / areflexia --> HP:0001284
# distal limb increased tone --> HP:0012839
# right tetraparesis --> HP:0002273
# lost deambulation --> HP:0000458
# apraxia --> HP:0002186
# drooling --> HP:0002307
# frequent paroxysmal outbreaks of highvoltage delta waves --> HP:0040282
# deep cerebral folate deficiency 3 nmol / l ( --> HP:0012446
# myofibers were abnormally small --> HP:0000013
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged red fibres --> HP:0003200
# atrophy --> HP:0000029
# peo --> HP:0000544
# bilateral ptosis --> HP:0001488
# dysarthria --> HP:0001260
# ataxia --> HP:0001251
# neuropathy --> HP:0009830
# T2 hyperintensity of basal ganglia --> HP:0007183
# dysphagia --> HP:0002015
# wheelchair dependence --> HP:0004878
# aspiration pneumonia --> HP:0011951
# bilateral hand contractures --> HP:0012832
# failure to thrive --> HP:0001508
# depression --> HP:0000716
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# external ophthalmoplegia --> HP:0000544
# saccadic pursuit --> HP:0001152
# writhing tongue movements --> HP:0000157
# dysarthria --> HP:0001260
# bilateral dysdiadochokinesis --> HP:0002075
# dysmetria --> HP:0001310
# poor --> HP:0004396
# heel - toe walking --> HP:0030051
# tremor --> HP:0001337
# myoclonic --> HP:0033054
# choreic --> HP:0002072
# dystonic posturing --> HP:0007166
# striatal toe --> HP:0001459
# peripheral neuropathy --> HP:0009830
# electronegative erg --> HP:0007984
# generalized rod on - bipolar dysfunction --> HP:0012837
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# ophthalmoplegia --> HP:0000602
# ptosis --> HP:0000508
# generalized epilepsy --> HP:0001250
# long - standing learning difficulties --> HP:0000040
# acute liver failure --> HP:0006554
# migraines --> HP:0002076
# epilepsia partialis continua --> HP:0012847
# myoclonic arm jerks --> HP:0001336
# progressive cognitive impairment --> HP:0003676
# intractable epilepsy --> HP:0001250
# liver disease --> HP:0006557
# respiratory chain defect --> HP:0200125
# parkinsonism --> HP:0001300
# sensory ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoparesis --> HP:0000597
# T2 hyperintensity of thalamus --> HP:0012692
# headaches --> HP:0002315
# aphasia --> HP:0002381
# visual aura --> HP:0011165
# homonymous right - sided visual field defect --> HP:0001123
# lesion --> HP:0000700
# inferior colliculi --> HP:0000915
# leigh ' s encephalopathy --> HP:0001298
# bilateral ptosis --> HP:0001488
# severe external ophthalmoplegia --> HP:0000544
# parkinsonism --> HP:0001300
# peo --> HP:0000544
# ptosis --> HP:0000508
# focal slowing --> HP:0030650
# epileptic spikes --> HP:0001351
# status epilepticus --> HP:0002133
# vision problems --> HP:0000529
# bilateral cataracts --> HP:0000518
# delayed fine motor skills --> HP:0002194
# atrophy --> HP:0000029
# absent menarche --> HP:0000042
# ovarian dysgenesis --> HP:0000138
# syncope --> HP:0001279
# seizure like episode --> HP:0002401
# atrophy --> HP:0000029
# dystonia of toes --> HP:0001332
# action tremor --> HP:0002345
# facial masking --> HP:0000276
# stiffness --> HP:0030965
# parkinsonism --> HP:0001300
# numbness in her feet --> HP:0033748
# parkinsonism --> HP:0001300
# bradykinesia --> HP:0002067
# stooped posture --> HP:0025403
# rigidity --> HP:0002063
# peripheral neuropathy --> HP:0009830
# sensorimotor, predominantly sensory --> HP:0000738
# atrophy --> HP:0000029
# partial motor status epilepticus --> HP:0032662
# abnormal liver function tests --> HP:0200148
# focal area of restricted diffusion --> HP:0030650
# swelling --> HP:0030774
# continuous paroxysmal lateralizing epileptiform discharges --> HP:0000740
# encephalopathic --> HP:0001298
# focal status --> HP:0032663
# seizures --> HP:0001250
# enlarged mitochondria --> HP:0001427
# abnormal mitochondrial cristae morphology --> HP:0008322
# myopathy --> HP:0003198
# peo --> HP:0000544
# ptosis --> HP:0000508
# gait instability --> HP:0002317
# proximal arm weakness --> HP:0003701
# fiber size variability --> HP:0003557
# central nuclei --> HP:0003687
# ragged red --> HP:0003200
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# mitochondrial paracrystalline inclusions --> HP:0001427
# increased --> HP:0033373
# anxiety and obsessive disorder --> HP:0000739
# creatine kinase levels were 217 u / l --> HP:0002720
# atrophy --> HP:0000029
# bilateral peo --> HP:0012832
# ptosis --> HP:0000508
# myopathic --> HP:0002058
# mitochondrial myopathy --> HP:0003737
# proximal and distal weakness in lower limbs --> HP:0012839
# sensory ataxia --> HP:0010871
# demyelinating sensorymotor neuropathy --> HP:0011402
# anxiety - mood disorders --> HP:0000739
# T2 hyperintensity --> HP:0031206
# dystonia --> HP:0001332
# dystonic ulnar deviation --> HP:0000497
# myoclonus --> HP:0001336
# polyminimyoclonus --> HP:0031986
# cytochrome c oxidase-deficient muscle fibers --> HP:0003688
# subsarcolemmal accumulation of abnormal mitochondria --> HP:0003548
# multiple mitochondrial dna ( mtdna ) deletions --> HP:0003689
# progressive sensory ataxic neuropathy --> HP:0003434
# ptosis --> HP:0000508
# dysarthria --> HP:0001260
# dysphagia --> HP:0002015
# external ophthalmoparesis --> HP:0000597
# ragged - red " fibres --> HP:0003200
# cytochrome oxidase - negative fibres --> HP:0003688
# cytochrome c oxidase --> HP:0003688
# ragged red fibers --> HP:0003200
# multiple mtdna deletions --> HP:0003689
# mtdna depletion --> HP:0003387
# palatal tremor --> HP:0010530
# inferior olivary nuclei --> HP:0000915
# early age of onset --> HP:0011152
# fatal --> HP:0006583
# intractable seizures --> HP:0001250
# hepatic failure --> HP:0001399
# global neurological deterioration --> HP:0001268
# high signal intensity within occipital and temporal lobes --> HP:0012824
# palatal tremor --> HP:0010530
# facial dyskinesia --> HP:0002310
# decreased complex iii activity --> HP:0011924
# multiple mtdna deletions --> HP:0003689
# dramatic weight loss --> HP:0001824
# gastroparesis --> HP:0002578
# ptosis --> HP:0000508
# ophthalmoplegia --> HP:0000602
# peripheral neuropathy --> HP:0009830
# sensory ataxia --> HP:0010871
# sensory - ataxic neuropathy --> HP:0003434
# dysarthria --> HP:0001260
# ophthalmoplegia --> HP:0000602
# hypoxia --> HP:0012418
# ascites --> HP:0001541
# tachycardia --> HP:0001649
# intermittent fevers --> HP:0001954
# sepsis --> HP:0100806
# cirrhosis --> HP:0001394
# steatosis --> HP:0001397
# focal necrosis --> HP:0003338
# complex iii deficiency --> HP:0011924
# seizures --> HP:0001250
# headaches --> HP:0002315
# areflexia --> HP:0001284
# hypotonia --> HP:0001252
# myopathy --> HP:0003198
# vomiting --> HP:0002013
# decreased visual acuity --> HP:0007924
# speech disorder --> HP:0006977
# left side weakness --> HP:0012835
# progressive bilateral ptosis --> HP:0000590
# hearing loss --> HP:0000365
# difficulties in swallowing --> HP:0002015
# bilateral ptosis --> HP:0001488
# bilateral hearing loss --> HP:0008619
# myopathic pattern --> HP:0003458
# mild --> HP:0012825
# increase in cholesterol levels --> HP:0031211
# bilateral ptosis --> HP:0001488
# severe ophthalmoparesis --> HP:0000597
# hearing loss --> HP:0000365
# dysarthria --> HP:0001260
# left facial nerve palsy --> HP:0010628
# left side hemiparesis --> HP:0001269
# T2 hyperintensity --> HP:0031206
# lesion --> HP:0000700
# T2 hyperintensity --> HP:0031206
# lesion --> HP:0000700
# increased level of serum creatine kinase --> HP:0003236
# moderate --> HP:0012826
# sensorimotor bilateral hypoacusia --> HP:0012832
# myopathic --> HP:0002058
# bilateral ptosis --> HP:0001488
# lateral rectus palsies --> HP:0031751
# horizontal diplopia --> HP:0000651
# nasal, flaccid dysarthria --> HP:0001260
# facial weakness --> HP:0030319
# tongue weakness --> HP:0000183
# gliosis --> HP:0002171
# gliosis --> HP:0002171
# nucleus --> HP:0002339
# loss of the purkinje cells in the superior cerebellar vermis --> HP:0007001
# ptosis --> HP:0000508
# bilateral ptosis --> HP:0001488
# vertical and --> HP:0500074
# horizontal ophthalmoplegia --> HP:0030773
# bifacial weakness --> HP:0030319
# weakness in the proximal and distal upper --> HP:0012839
# lower --> HP:0000178
# left - sided intention tremor --> HP:0001337
# myopathy --> HP:0003198
# moderate fiber size --> HP:0012826
# atrophy --> HP:0000029
# increased internal nuclei --> HP:0031237
# fatty infiltration of skeletal muscle --> HP:0012548
# ragged red fibers --> HP:0003200
# fibers --> HP:0100305
# dehydrogenase --> HP:0002928
# reduced --> HP:0031851
# demyelination --> HP:0011096
# cataracts --> HP:0000518
# ovarian dysgenesis --> HP:0000138
# - onset --> HP:0003674
# distal muscle weakness --> HP:0002460
# microvesicular steatosis --> HP:0001414
# cerebral cortex showing activated astrocytes --> HP:0000935
# multiple mtdna deletions --> HP:0003689
# progressive cognitive deficits --> HP:0003676
# cognitive deficits --> HP:0100543
# epileptic seizures --> HP:0033052
# recurrent headaches --> HP:0002331
# mild --> HP:0012825
# personality changes --> HP:0000751
# movement disorder --> HP:0007153
# action - triggered myoclonus --> HP:0001336
# dystonic ulnar deviation --> HP:0000497
# progressive cerebellar ataxia --> HP:0002073
# incomplete --> HP:0010861
# chronic progressive external ophthalmoplegia --> HP:0000544
# peo --> HP:0000544
# severe axonal sensorimotor neuropathy --> HP:0007141
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# ragged red fibers --> HP:0003200
# lower limb --> HP:0007210
# dystonia --> HP:0001332
# peripheral neuropathy --> HP:0009830
# dystonia --> HP:0001332
# accumulation of lipids --> HP:0034787
# mitochondria were enlarged --> HP:0001427
# abnormal mitochondrial cristae morphology --> HP:0008322
# complete horizontal gaze palsy --> HP:0000511
# severe ataxia --> HP:0001251
# reflexes were absent --> HP:0001284
# choreoathetotic --> HP:0001266
# loss of proprioception --> HP:0010831
# somnolent --> HP:0005335
# loss of extraocular movement --> HP:0000597
# spasticity --> HP:0001257
# hyperreflexia --> HP:0001347
# genu of the corpus callosum --> HP:0006989
# genu of the right internal capsule --> HP:0012834
# anterior thalamus --> HP:0000236
# bilateral cerebellar hemispheres --> HP:0012832
# bilateral cerebellar peduncles --> HP:0012832
# hemorrhage --> HP:0002239
# putamen --> HP:0031982
# elevated lactate level --> HP:0012707
# depressed n - acetylaspartate level --> HP:0000272
# elevated choline level in --> HP:0012706
# basal ganglia --> HP:0012697
# foamy histiocytes --> HP:0003651
# cells --> HP:0001404
# loss of myelin --> HP:0003380
# reactive astrocytes --> HP:0003203
# glial fibrillary acidic protein --> HP:0032650
# adult - onset --> HP:0003581
# progressive external ophthalmoplegia --> HP:0000590
# peo --> HP:0000544
# progressive encephalopathy --> HP:0002448
# cytochrome c oxidase-deficient muscle fibers --> HP:0003688
# ragged - red fibres --> HP:0003200
# coagulopathy --> HP:0003256
# elevated liver enzymes --> HP:0002910
# seizures --> HP:0001250
# hepatic failure --> HP:0001399
# hand tremor --> HP:0002378
# hand tremor --> HP:0002378
# slurred speech --> HP:0001350
# increased vanillate level --> HP:0000016
# myelin basic protein level was higher than 1000 ng / ml --> HP:0000093
# oligoclonal bands in cerebrospinal fluid --> HP:6000397
# serum lactate level was slightly high --> HP:0000218
# epilepsy --> HP:0001250
# EEG with epileptiform discharges --> HP:0011198
# electromyography was myopathic --> HP:0002058
# myopathic --> HP:0002058
# cytochrome c oxidase-negative muscle fibers --> HP:0003688
# increased brain lactate on magnetic resonance spectroscopy --> HP:0001900
# microvesicular --> HP:0001414
# cholestasis --> HP:0001396
# chronic myopathy --> HP:0009071
# severe sensory neuropathy --> HP:0000763
# hypogonadism --> HP:0000135
# hypothyroidism --> HP:0000821
# osteopenia --> HP:0000938
# ragged - red fibers --> HP:0003200
# variation in skeletal muscle fiber size --> HP:0003557
# increased central nuclei in skeletal muscle fibers --> HP:0003687
# reduced --> HP:0031851
# mtdna depletion --> HP:0003387
# hypomimia --> HP:0000338
# bilateral bradykinesia --> HP:0002067
# right - sided resting tremor --> HP:0001337
# reduced cytochrome c oxidase activity --> HP:0003688
# focal convulsions --> HP:0030650
# convulsions --> HP:0002069
# post - ) ictal paresis --> HP:0001604
# aphasia --> HP:0002381
# focal occipital epileptic discharges --> HP:0030650
# irregular menstrual cycles --> HP:0000858
# portal tracts were enlarged --> HP:0000040
# bile plugs --> HP:0034294
# decreased sensory and motor nerve conduct velocity --> HP:0003448
# progressive proximal limb weakness --> HP:0003676
# EEG with epileptiform discharges --> HP:0011198
# asymmetric ptosis --> HP:0000508
# atrophy --> HP:0000029
# pectus excavatum ( --> HP:0000767
# funnel breast --> HP:0000769
# atrophy --> HP:0000029
# ragged red fibers --> HP:0003200
# mitochondrial myopathy --> HP:0003737
# multiple mtdna deletions --> HP:0003689
# extra - pyramidal rigidity --> HP:0002063
# postural instability --> HP:0002172
# hypomimic face --> HP:0000338
# hypophonia --> HP:0001621
# bilateral ptosis --> HP:0001488
# ophthalmoplegia --> HP:0000602
# proximal muscle weak - ness --> HP:0003701
# oligomenorrhea --> HP:0000876
# subsarcolemmal accumulation of mitochondria --> HP:0003548
# abnormal mitochondrial cristae morphology --> HP:0008322
#
#  Unmapped Mentions (75):
# reduction of activities of complex i and iv
# lower extremities were diffusely thin
# / 5 at tibialis anterior
# percutaneous endoscopic gastrostomy
# refractory partial seizures
# absence of sensory response in both arms and legs
# spongiform changes in the cerebrum
# degeneration of dorsal root ganglia
# glycaemia
# content of mtdna was slightly reduced in muscle
# alpers syndrome
# right - sided focal motor seizures
# upper limb mixed rest and
# percutaneous gastrostomy tube
# died
# radiculopathy
# trouble walking heel - to - toe
# pinprick sensation ( reduced to the mid - calves
# refractory mixed type seizures
# complex iv showed a decreased activity
# mild apraxia
# motor disturbances
# electroencephalogram disclosed spontaneously slow and poorly organized trace
# right predominance activated during sleep
# subsarcolemmal collections of mitochondria
# T2 hyperintensity of cortical gray matter
# g - tube
# selective rod on - bipolar cell dysfunction
# laterocollis
# sando
# pancerebellar syndrome
# sando syndrome
# sando
# parieto - occipital region
# inability to use both of her hands
# T2 hyperintensity of inferior olivary nucleus
# alpers syndrome
# recurrent falls
# ragged blue fibers
# cytochrome - c - oxidase ( cytochrome c oxidase - ) activity was deficient
# cognition was mildly affected
# myoglobin was 360 u / l
# ragged blue fibers
# decreased dopamine transporter level
# alpers syndrome
# severely cytochrome oxidase - deficient muscle
# deficiencies in all etc complexes
# mild dysphagia
# power was reduced in both deltoid muscles
# loss of pigmented neurons in the substantia nigra
# ventrolateral posterior nuclei of the thalamus
# electromyography
# ragged blue fibers
# absent cytochrome c oxidase ( cytochrome c oxidase ) activity
# wheel - chair bound
# T2 prolongation
# frontoparietal subcortical white matter
# thalamus
# gliotic white matter
# active demyelinating process
# died
# abnormalities in thalamus and basal ganglia
# alpers syndrome
# sando
# serum ck level was 1. 5 normal
# fat deposition was prominent in superficial muscles
# absent reactivity to cytochrome c oxidase
# alpers syndrome
# forced anteroflexion of
# bilirubinostasis
# proliferation of bile ductules
# brainstem auditory evoked potential showed increased i - iii latency
# deficient in the mtdna - encoded cytochrome c oxidase ( cytochrome c oxidase
# cogwheel sign
# depletion of mtdna
